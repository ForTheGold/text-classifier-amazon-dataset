# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine, func

# %%
#read in json file with groceries data
#nrows=10 for testing code
Grocery_json = pd.read_json('Resources/Grocery_and_Gourmet_Food.json',lines=True, nrows=500)

# %%
Grocery_json
# Out:
#      overall  verified   reviewTime      reviewerID        asin  \
# 0          5      True   06 4, 2013   ALP49FBWT4I7V  1888861614
# 1          4      True  05 23, 2014  A1KPIZOCLB9FZ8  1888861614
# 2          4      True   05 9, 2014  A2W0FA06IYAYQE  1888861614
# 3          5      True  04 20, 2014  A2PTZTCH2QUYBC  1888861614
# 4          4      True  04 16, 2014  A2VNHGJ59N4Z90  1888861614
# ..       ...       ...          ...             ...         ...
# 495        5      True  10 13, 2015  A3AAPTA7ADEXC9  9742356831
# 496        5      True   10 9, 2015   A69643EIL0ZDC  9742356831
# 497        5      True  09 28, 2015  A1T9SJTTRD2K5D  9742356831
# 498        4      True  09 22, 2015  A1ECWZ09Y4I934  9742356831
# 499        5     False  09 19, 2015   AR25ISECQJJ36  9742356831
#
#            reviewerName                                         reviewText  \
# 0                  Lori  Very pleased with my purchase. Looks exactly l...
# 1            BK Shopper  Very nicely crafted but too small. Am going to...
# 2        daninethequeen  still very pretty and well made...i am super p...
# 3               Tammara  I got this for our wedding cake, and it was ev...
# 4    LaQuinta Alexander  It was just what I want to put at the top of m...
# ..                  ...                                                ...
# 495        One Fine Day  Great flavor! I purchased this after being fru...
# 496        David Miller                                      Good product.
# 497       Angela Waters  Love this curry! I used to live in Hawaii & th...
# 498          Aijing Lin  The taste is really great, similar to those cu...
# 499           Monica S.  I'm a terrible cook, and this always comes out...
#
#                                                summary  unixReviewTime  vote  \
# 0                                              Love it      1370304000   NaN
# 1                                       Nice but small      1400803200   NaN
# 2                         the "s" looks like a 5, kina      1399593600   NaN
# 3                    Would recommend this to a friend!      1397952000   NaN
# 4                                               Topper      1397606400   NaN
# ..                                                 ...             ...   ...
# 495  Keep this one up your sleeve for a quick and f...      1444694400   NaN
# 496                                         Five Stars      1444348800   NaN
# 497                                    Love this curry      1443398400   NaN
# 498  The taste is really great, similar to those cu...      1442880000   NaN
# 499                                     Mmmmmmae Ploy!      1442620800   NaN
#
#     image
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 495   NaN
# 496   NaN
# 497   NaN
# 498   NaN
# 499   NaN
#
# [500 rows x 11 columns]

# %%
#read labeled csv, will be used to count words in each review to generate review length column. 
labeled_df = pd.read_csv('Resources/labeled.csv')
labeled_df
# Out:
#                                                     words sentiment
# 0       ['comforting', 'know', 'processed', 'like', 's...       pos
# 1       ['never', 'disappointed', 'cup', 'cider', 'lik...       neg
# 2       ['never', 'ever', 'write', 'reviews', 'product...       neg
# 3       ['tasty', 'package', 'arrived', 'neatly', 'pac...       pos
# 4       ['gonna', 'buy', 'future', 'ate', 'completely'...       pos
# ...                                                   ...       ...
# 809635  ['great', 'tasting', 'tuna', 'easy', 'open', '...       pos
# 809636  ['addicted', 'product', 'grocer', 'quit', 'car...       neg
# 809637  ['sure', 'happened', 'box', 'arrived', 'comple...       neg
# 809638  ['put', 'water', 'bottle', 'done', 'working', ...       pos
# 809639  ['delicious', 'remember', 'kid', '90', 'fresh'...       pos
#
# [809640 rows x 2 columns]

# %%
#count the number of words in a review and add a review length column
Grocery_json["reviewlength"] = labeled_df["words"].apply(lambda x: len(x))
Grocery_json.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   06 4, 2013   ALP49FBWT4I7V  1888861614
# 1        4      True  05 23, 2014  A1KPIZOCLB9FZ8  1888861614
# 2        4      True   05 9, 2014  A2W0FA06IYAYQE  1888861614
# 3        5      True  04 20, 2014  A2PTZTCH2QUYBC  1888861614
# 4        4      True  04 16, 2014  A2VNHGJ59N4Z90  1888861614
#
#          reviewerName                                         reviewText  \
# 0                Lori  Very pleased with my purchase. Looks exactly l...
# 1          BK Shopper  Very nicely crafted but too small. Am going to...
# 2      daninethequeen  still very pretty and well made...i am super p...
# 3             Tammara  I got this for our wedding cake, and it was ev...
# 4  LaQuinta Alexander  It was just what I want to put at the top of m...
#
#                              summary  unixReviewTime  vote image  reviewlength
# 0                            Love it      1370304000   NaN   NaN           270
# 1                     Nice but small      1400803200   NaN   NaN           287
# 2       the "s" looks like a 5, kina      1399593600   NaN   NaN          1156
# 3  Would recommend this to a friend!      1397952000   NaN   NaN           126
# 4                             Topper      1397606400   NaN   NaN            92

# %%
#create groceries_df with the relevant columns
groceries_df = Grocery_json[['asin','overall','reviewerID', 'reviewTime','unixReviewTime', 'reviewText', "reviewlength"]]
groceries_df
# Out:
#            asin  overall      reviewerID   reviewTime  unixReviewTime  \
# 0    1888861614        5   ALP49FBWT4I7V   06 4, 2013      1370304000
# 1    1888861614        4  A1KPIZOCLB9FZ8  05 23, 2014      1400803200
# 2    1888861614        4  A2W0FA06IYAYQE   05 9, 2014      1399593600
# 3    1888861614        5  A2PTZTCH2QUYBC  04 20, 2014      1397952000
# 4    1888861614        4  A2VNHGJ59N4Z90  04 16, 2014      1397606400
# ..          ...      ...             ...          ...             ...
# 495  9742356831        5  A3AAPTA7ADEXC9  10 13, 2015      1444694400
# 496  9742356831        5   A69643EIL0ZDC   10 9, 2015      1444348800
# 497  9742356831        5  A1T9SJTTRD2K5D  09 28, 2015      1443398400
# 498  9742356831        4  A1ECWZ09Y4I934  09 22, 2015      1442880000
# 499  9742356831        5   AR25ISECQJJ36  09 19, 2015      1442620800
#
#                                             reviewText  reviewlength
# 0    Very pleased with my purchase. Looks exactly l...           270
# 1    Very nicely crafted but too small. Am going to...           287
# 2    still very pretty and well made...i am super p...          1156
# 3    I got this for our wedding cake, and it was ev...           126
# 4    It was just what I want to put at the top of m...            92
# ..                                                 ...           ...
# 495  Great flavor! I purchased this after being fru...             8
# 496                                      Good product.           263
# 497  Love this curry! I used to live in Hawaii & th...           390
# 498  The taste is really great, similar to those cu...           153
# 499  I'm a terrible cook, and this always comes out...            71
#
# [500 rows x 7 columns]

# %%
#drop dupicates (drops duplicates where the whole row is identical)
groceries_df = groceries_df.drop_duplicates()
groceries_df
# Out:
#            asin  overall      reviewerID   reviewTime  unixReviewTime  \
# 0    1888861614        5   ALP49FBWT4I7V   06 4, 2013      1370304000
# 1    1888861614        4  A1KPIZOCLB9FZ8  05 23, 2014      1400803200
# 2    1888861614        4  A2W0FA06IYAYQE   05 9, 2014      1399593600
# 3    1888861614        5  A2PTZTCH2QUYBC  04 20, 2014      1397952000
# 4    1888861614        4  A2VNHGJ59N4Z90  04 16, 2014      1397606400
# ..          ...      ...             ...          ...             ...
# 495  9742356831        5  A3AAPTA7ADEXC9  10 13, 2015      1444694400
# 496  9742356831        5   A69643EIL0ZDC   10 9, 2015      1444348800
# 497  9742356831        5  A1T9SJTTRD2K5D  09 28, 2015      1443398400
# 498  9742356831        4  A1ECWZ09Y4I934  09 22, 2015      1442880000
# 499  9742356831        5   AR25ISECQJJ36  09 19, 2015      1442620800
#
#                                             reviewText  reviewlength
# 0    Very pleased with my purchase. Looks exactly l...           270
# 1    Very nicely crafted but too small. Am going to...           287
# 2    still very pretty and well made...i am super p...          1156
# 3    I got this for our wedding cake, and it was ev...           126
# 4    It was just what I want to put at the top of m...            92
# ..                                                 ...           ...
# 495  Great flavor! I purchased this after being fru...             8
# 496                                      Good product.           263
# 497  Love this curry! I used to live in Hawaii & th...           390
# 498  The taste is really great, similar to those cu...           153
# 499  I'm a terrible cook, and this always comes out...            71
#
# [500 rows x 7 columns]

# %%
#create df of 5 star ratings only
rating_5 = groceries_df.loc[groceries_df['overall'] == 5]
rating_5.head()
# Out:
#          asin  overall      reviewerID   reviewTime  unixReviewTime  \
# 0  1888861614        5   ALP49FBWT4I7V   06 4, 2013      1370304000
# 3  1888861614        5  A2PTZTCH2QUYBC  04 20, 2014      1397952000
# 6  1888861614        5   A94ZG5CWN70E7   12 1, 2013      1385856000
# 8  1888861614        5   AGKW3A1RB1YGO   10 2, 2013      1380672000
# 9  1888861614        5  A1B65IWLUVOUQB   09 6, 2013      1378425600
#
#                                           reviewText  reviewlength
# 0  Very pleased with my purchase. Looks exactly l...           270
# 3  I got this for our wedding cake, and it was ev...           126
# 6  Omg.. The S was inexpensive and EXACTLY what w...            22
# 8  Perfect!!! Can not wait to use on my Wedding c...            57
# 9  This was exactly what we were looking for to m...            44

# %%
rating_5 = rating_5.drop(['asin', 'unixReviewTime'], axis=1)
rating_5.head()
# Out:
#    overall      reviewerID   reviewTime  \
# 0        5   ALP49FBWT4I7V   06 4, 2013
# 3        5  A2PTZTCH2QUYBC  04 20, 2014
# 6        5   A94ZG5CWN70E7   12 1, 2013
# 8        5   AGKW3A1RB1YGO   10 2, 2013
# 9        5  A1B65IWLUVOUQB   09 6, 2013
#
#                                           reviewText  reviewlength
# 0  Very pleased with my purchase. Looks exactly l...           270
# 3  I got this for our wedding cake, and it was ev...           126
# 6  Omg.. The S was inexpensive and EXACTLY what w...            22
# 8  Perfect!!! Can not wait to use on my Wedding c...            57
# 9  This was exactly what we were looking for to m...            44

# %%
#rename columns to fit new database format
rating_5.columns = ['rating_review', 'reviewer_id_review', 'date_review', 'text_review', 'length_review']
rating_5.head()
# Out:
#    rating_review reviewer_id_review  date_review  \
# 0              5      ALP49FBWT4I7V   06 4, 2013
# 3              5     A2PTZTCH2QUYBC  04 20, 2014
# 6              5      A94ZG5CWN70E7   12 1, 2013
# 8              5      AGKW3A1RB1YGO   10 2, 2013
# 9              5     A1B65IWLUVOUQB   09 6, 2013
#
#                                          text_review  length_review
# 0  Very pleased with my purchase. Looks exactly l...            270
# 3  I got this for our wedding cake, and it was ev...            126
# 6  Omg.. The S was inexpensive and EXACTLY what w...             22
# 8  Perfect!!! Can not wait to use on my Wedding c...             57
# 9  This was exactly what we were looking for to m...             44

# %%
#create df with 1 star rating only
rating_1 = groceries_df.loc[groceries_df['overall'] == 1]
rating_1.head()
# Out:
#           asin  overall      reviewerID   reviewTime  unixReviewTime  \
# 5   1888861614        1   ATQL0XOLZNHZ4  02 21, 2014      1392940800
# 22  4639725183        1   AE937MVR5J8OL  12 10, 2016      1481328000
# 27  4639725183        1  A27LF8222OIRRN  09 10, 2016      1473465600
# 37  4639725183        1  A34RH95REHOQFO  09 25, 2015      1443139200
# 69  4639725043        1  A3ELDSSPP9RZPG  03 31, 2017      1490918400
#
#                                            reviewText  reviewlength
# 5   The S is beautiful, however upon checkout it i...            97
# 22                Tasted old and not individually bag           104
# 27  Not the great taste everyone was talking about :(            40
# 37  Terrible. What a waste of money. This is not t...          1391
# 69  The tea is so fine it leaves tea particles flo...           194

# %%
rating_1 = rating_1.drop(['asin', 'unixReviewTime'], axis=1)
rating_1.head()
# Out:
#     overall      reviewerID   reviewTime  \
# 5         1   ATQL0XOLZNHZ4  02 21, 2014
# 22        1   AE937MVR5J8OL  12 10, 2016
# 27        1  A27LF8222OIRRN  09 10, 2016
# 37        1  A34RH95REHOQFO  09 25, 2015
# 69        1  A3ELDSSPP9RZPG  03 31, 2017
#
#                                            reviewText  reviewlength
# 5   The S is beautiful, however upon checkout it i...            97
# 22                Tasted old and not individually bag           104
# 27  Not the great taste everyone was talking about :(            40
# 37  Terrible. What a waste of money. This is not t...          1391
# 69  The tea is so fine it leaves tea particles flo...           194

# %%
#rename columns to fit new database format
rating_1.columns = ['rating_review', 'reviewer_id_review', 'date_review', 'text_review', 'length_review']
rating_1.head()
# Out:
#     rating_review reviewer_id_review  date_review  \
# 5               1      ATQL0XOLZNHZ4  02 21, 2014
# 22              1      AE937MVR5J8OL  12 10, 2016
# 27              1     A27LF8222OIRRN  09 10, 2016
# 37              1     A34RH95REHOQFO  09 25, 2015
# 69              1     A3ELDSSPP9RZPG  03 31, 2017
#
#                                           text_review  length_review
# 5   The S is beautiful, however upon checkout it i...             97
# 22                Tasted old and not individually bag            104
# 27  Not the great taste everyone was talking about :(             40
# 37  Terrible. What a waste of money. This is not t...           1391
# 69  The tea is so fine it leaves tea particles flo...            194

# %%
#choosing every second row of the five star rating for a total of 600,000 to reduce its size from around 3.5 million ratings to a number closer to the 1 star ratings. 
rating_5_trimmed = rating_5[:1200000:2]
rating_5_trimmed
# Out:
#               rating_review reviewer_id_review  date_review  \
# index_review
# 0                         5      ALP49FBWT4I7V   06 4, 2013
# 6                         5      A94ZG5CWN70E7   12 1, 2013
# 9                         5     A1B65IWLUVOUQB   09 6, 2013
# 11                        5     A1QVBUH9E1V6I8  11 19, 2014
# 13                        5     A2CHH5U12THP2D   11 3, 2014
# ...                     ...                ...          ...
# 489                       5     A2KXDR2MTICVNI  10 28, 2015
# 492                       5     A1LC9OU0CWPBRN  10 20, 2015
# 494                       5     A1TIGQEXUGWXR6  10 13, 2015
# 496                       5      A69643EIL0ZDC   10 9, 2015
# 499                       5      AR25ISECQJJ36  09 19, 2015
#
#                                                     text_review  length_review
# index_review
# 0             Very pleased with my purchase. Looks exactly l...            270
# 6             Omg.. The S was inexpensive and EXACTLY what w...             22
# 9             This was exactly what we were looking for to m...             44
# 11                                          No adverse comment.            257
# 13            Best black tea in US.\n\nHighly recommend.\nI ...             33
# ...                                                         ...            ...
# 489           Using Thai Kitchen's red and green curry paste...            628
# 492           Great flavour and a good amount of heat withou...             18
# 494           Love this.  Moderately spicy when compared to ...             98
# 496                                               Good product.            263
# 499           I'm a terrible cook, and this always comes out...             71
#
# [182 rows x 5 columns]

# %%
#merge the data from 1 and 5 star ratings into one df
g1_5 = pd.merge(rating_5_trimmed, rating_1, how='outer')
g1_5
# Out:
#      rating_review reviewer_id_review  date_review  \
# 0                5      ALP49FBWT4I7V   06 4, 2013
# 1                5      A94ZG5CWN70E7   12 1, 2013
# 2                5     A1B65IWLUVOUQB   09 6, 2013
# 3                5     A1QVBUH9E1V6I8  11 19, 2014
# 4                5     A2CHH5U12THP2D   11 3, 2014
# ..             ...                ...          ...
# 208              1      ANJMKELOZ1LKY  05 31, 2017
# 209              1      A9X0YU2HAAI4T  01 31, 2017
# 210              1     A2FZMMOZXACZDR  08 29, 2016
# 211              1      AS039MM100OWE  05 30, 2016
# 212              1      AWUFCPYPWH764  03 21, 2016
#
#                                            text_review  length_review
# 0    Very pleased with my purchase. Looks exactly l...            270
# 1    Omg.. The S was inexpensive and EXACTLY what w...             22
# 2    This was exactly what we were looking for to m...             44
# 3                                  No adverse comment.            257
# 4    Best black tea in US.\n\nHighly recommend.\nI ...             33
# ..                                                 ...            ...
# 208  Where is my curry????? I got someone else's ma...             63
# 209  I don't know much about authentic Thai coockin...            144
# 210  It is too spicy and also very salty. I trashed...            131
# 211  This doesn't taste much like green curry. The ...             84
# 212  I made my first batch of veggie curry today fo...            132
#
# [213 rows x 5 columns]

# %%
g1_5.index.name = 'index_review'
g1_5.head()
# Out:
#               rating_review reviewer_id_review  date_review  \
# index_review
# 0                         5      ALP49FBWT4I7V   06 4, 2013
# 1                         5      A94ZG5CWN70E7   12 1, 2013
# 2                         5     A1B65IWLUVOUQB   09 6, 2013
# 3                         5     A1QVBUH9E1V6I8  11 19, 2014
# 4                         5     A2CHH5U12THP2D   11 3, 2014
#
#                                                     text_review  length_review
# index_review
# 0             Very pleased with my purchase. Looks exactly l...            270
# 1             Omg.. The S was inexpensive and EXACTLY what w...             22
# 2             This was exactly what we were looking for to m...             44
# 3                                           No adverse comment.            257
# 4             Best black tea in US.\n\nHighly recommend.\nI ...             33

# %%
# sqlalchemy's create engine preparing the ability to connect to a sqlite database. then with .connect connecting to the database. 
# sqlite:///groc15trimmed.sqlite
engine = create_engine('sqlite:///reviewdb.db', echo=True)
sqlite_connection = engine.connect()

# %%
#connecting to database and inputting info in from dataframe
sqlite_table = "groceries_review_table"
ALLgroceries=g1_5.to_sql(sqlite_table, sqlite_connection, if_exists='replace')

# %%
#restructured database. No need for this table. Machine learning algorythm will use a subset of the review_table
#MLgroceries_df = g1_5[['asin', 'overall', 'reviewText']]
#MLgroceries_df

# %%
#new database format, no need for this ML table. 
#connecting to database and inputting info in from dataframe
#sqlite_table_2 = "groceriesMLData"
#MLgroceries=MLgroceries_df.to_sql(sqlite_table_2, sqlite_connection, if_exists='replace')

# %%
#select and show data in groceries ALL table
#engine.execute('SELECT * FROM groceriesALL').fetchall()

# %%
#engine.execute('SELECT * FROM groceriesMLData').fetchall()
