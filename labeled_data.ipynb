# %%
import csv
import json
import random
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
from nltk.stem.wordnet import WordNetLemmatizer

# %%
# read and store the file in a list, remove the header
data = []
with open('groceries_trimmed.csv') as f:
    reader = csv.reader(f, delimiter=',')
    for i in reader:
        data.append(i)
f.close()

data = data[1:]

# %%
tokenizer = RegexpTokenizer(r'\w+')
stop_words = set(stopwords.words('english'))

# %%
# Make two lists of positive and negative reviews
# Normalize to lowercase, tokenize and remove stopwords
# Append as a tuple with tags

positive = []
negative = []

regex = re.compile('[^a-zA-Z0-9]')
lemmatizer = WordNetLemmatizer()

for i in data:
    if i[0] == '5':
        filtered = []
        tokens = tokenizer.tokenize(i[1].lower())
        for j in tokens:
            j = regex.sub('', j)
            if len(j) > 2 and j not in stop_words:
                lemma = lemmatizer.lemmatize(j)
                filtered.append(lemma)

        if len(filtered) > 0:
            positive.append((filtered, 'pos'))
    else:
        filtered = []
        tokens = tokenizer.tokenize(i[1].lower())
        for j in tokens:
            j = regex.sub('', j)
            if len(j) > 2 and j not in stop_words:
                lemma = lemmatizer.lemmatize(j)
                filtered.append(lemma)
                
        if len(filtered) > 0:
            negative.append((filtered, 'neg'))

# %%
# There are many more positive than negative reviews, so shuffle for randomness
# make a huge list containing equal numbers of positive and negative labeled reviews
# shuffle the giant list again
random.shuffle(positive)
labeled_reviews = positive[:len(negative)] + negative
random.shuffle(labeled_reviews)

# %%
# Our list
labeled_reviews
# Out:
# [(['disgusting', 'taste', 'bitter', 'ironically'], 'neg'),
#  (['disappointment',
#    'research',
#    'reading',
#    'review',
#    'thought',
#    'knew',
#    'getting',
#    'joke',
#    'ordered',
#    'case',
#    'office',
#    'case',
#    'loose',
#    'coffee',
#    'ground',
#    'throughout',
#    'package',
#    'generic',
#    'silver',
#    'blue',
#    'maxwell',
#    'house',
#    'pictured',
#    'tasted',
#    'extremely',
#    'stale',
#    'yuck',
#    'filter',
#    'pack',
#    'knew',
#    'brewed',
#    'pot',
#    'coffee',
#    'fine',
#    'weak',
#    'others',
#    'stated',
#    'using',
#    'coffee',
#    'pot',
#    'quality',
#    'totally',
#    'unacceptable',
#    'poor',
#    'packaging',
#    'falsely',
#    'individually',
#    'packaged',
#    'little',
#    'hard',
#    'open',
#    'taste',
#    'typical',
#    'maxwell',
#    'house'],
#   'neg'),
#  (['would', 'give', 'zero', 'star', 'option', 'horrible', 'taste'], 'neg'),
#  (['bar', 'real', 'good'], 'pos'),
#  (['family',
#    'favorite',
#    'ship',
#    'quick',
#    'buy',
#    'coffee',
#    'family',
#    'coffee',
#    'drinker',
#    'everyone',
#    'love',
#    'particular',
#    'one'],
#   'pos'),
#  (['ordered',
#    'product',
#    'vendor',
#    'really',
#    'love',
#    'delicious',
#    'however',
#    'vendor',
#    'product',
#    'arrived',
#    'stale',
#    'actually',
#    'yellow',
#    'color',
#    'tasted',
#    'awful',
#    'know',
#    'old',
#    'stale',
#    'overheated',
#    'made',
#    'differently',
#    'imitation',
#    'worth'],
#   'neg'),
#  (['delidious', 'added', 'cake', 'mix'], 'pos'),
#  (['drink',
#    'one',
#    'cup',
#    'regular',
#    'coffee',
#    'daily',
#    'always',
#    'look',
#    'alternative',
#    'tried',
#    'teeccino',
#    'feel',
#    'satisfied',
#    'read',
#    'good',
#    'review',
#    'felt',
#    'motivated',
#    'try',
#    'also',
#    'read',
#    'doctor',
#    'recommended',
#    'unfortunately',
#    'taste',
#    'good',
#    'approximate',
#    'coffee',
#    'taste',
#    'really',
#    'love',
#    'find',
#    'coffee',
#    'alternative',
#    'truly',
#    'taste',
#    'like',
#    'coffee',
#    'weird',
#    'aftertaste',
#    'dislike',
#    'writing',
#    'negative',
#    'review',
#    'must',
#    'honest'],
#   'neg'),
#  (['package',
#    'got',
#    'timely',
#    'fashion',
#    'bag',
#    'open',
#    'inside',
#    'box',
#    'flour',
#    'everywhere',
#    'option',
#    'return'],
#   'neg'),
#  (['like',
#    'dried',
#    'bean',
#    'perfect',
#    'taste',
#    'nutty',
#    'never',
#    'difficult',
#    'find',
#    'grocery',
#    'store'],
#   'pos'),
#  (['enjoying', 'coffee', 'year', 'never', 'disappoints'], 'pos'),
#  (['shipped', 'fast', 'good', 'coffee'], 'pos'),
#  (['still', 'best', 'always', 'best'], 'pos'),
#  (['twinings',
#    'used',
#    'make',
#    'good',
#    'flavorful',
#    'tea',
#    'older',
#    'box',
#    'earl',
#    'gray',
#    'made',
#    'two',
#    'cup',
#    'per',
#    'bag',
#    'new',
#    'version',
#    'awful',
#    'like',
#    'brown',
#    'crayon',
#    'dipped',
#    'warm',
#    'water',
#    'two',
#    'bag',
#    'even',
#    'make',
#    'one',
#    'decent',
#    'cup',
#    'classic',
#    'sham',
#    'ripoff',
#    'cup',
#    'blend',
#    'better',
#    'shame',
#    'twinings',
#    'turning',
#    'great',
#    'product',
#    'junk'],
#   'neg'),
#  (['bought',
#    'recommendation',
#    'health',
#    'care',
#    'practitioner',
#    'plum',
#    'may',
#    'healthy',
#    'flavor',
#    'nasty'],
#   'neg'),
#  (['sugar',
#    'bakes',
#    'well',
#    'mix',
#    'well',
#    'taste',
#    'like',
#    'heaven',
#    'home',
#    'made',
#    'ice',
#    'cream',
#    'use',
#    'almost',
#    'everything',
#    'never',
#    'failed',
#    'cake',
#    'cooky',
#    'ice',
#    'cream',
#    'frosting',
#    'oatmeal',
#    'homemade',
#    'applesauce',
#    'downside',
#    'purely',
#    'cosmetic',
#    'lol',
#    'turn',
#    'everything',
#    'brown',
#    'made',
#    'lemon',
#    'icing',
#    'looked',
#    'like',
#    'caramel',
#    'sauce',
#    'played',
#    'weird',
#    'mental',
#    'trick',
#    'haha',
#    'tasted',
#    'like',
#    'supposed',
#    'brown',
#    'raw',
#    'sugar',
#    'much',
#    'better',
#    'body',
#    'processed',
#    'even',
#    'better',
#    'demererra',
#    'although',
#    'much',
#    'better',
#    'processed',
#    'also',
#    'contrary',
#    'popular',
#    'belief',
#    'body',
#    'need',
#    'sugar',
#    'fat',
#    'salt',
#    'digress',
#    'long',
#    'right',
#    'kind',
#    'sugar',
#    'affect',
#    'body',
#    'way',
#    'processed',
#    'sugar',
#    'much',
#    'gentle',
#    'system',
#    'high',
#    'crash',
#    'also',
#    'contains',
#    'natural',
#    'mineral',
#    'benefit',
#    'sugar',
#    'cane',
#    'actually',
#    'good',
#    'body',
#    'trying',
#    'transition',
#    'healthier',
#    'lifestyle',
#    'changing',
#    'processed',
#    'sugar',
#    'sugar',
#    'great',
#    'first',
#    'step',
#    'kid',
#    'body',
#    'thank',
#    'local',
#    'health',
#    'food',
#    'store',
#    'sell',
#    'exact',
#    'sugar',
#    'price',
#    'better',
#    'amazon'],
#   'pos'),
#  (['best',
#    'honey',
#    'market',
#    'date',
#    'far',
#    'hand',
#    'good',
#    'nothing',
#    'come',
#    'close'],
#   'pos'),
#  (['coffee',
#    'good',
#    'taste',
#    'run',
#    'bold',
#    'french',
#    'roast',
#    'complaint',
#    'ever',
#    'changing',
#    'policy',
#    'amazon',
#    'avoid',
#    'giving',
#    'day',
#    'delivery',
#    'paid',
#    'prime',
#    'membership',
#    'past',
#    'three',
#    'month',
#    'year',
#    'wonderful',
#    'service',
#    'getting',
#    'coffee',
#    'six',
#    'eight',
#    'day',
#    'ordered',
#    'might',
#    'well',
#    'use',
#    'pony',
#    'express',
#    'response',
#    'gotten',
#    'called',
#    'complain',
#    'initially',
#    'provide',
#    'day',
#    'shipping',
#    'first',
#    'order',
#    'month',
#    'guess',
#    'forgot',
#    'mention',
#    'subscribed',
#    'way',
#    'fact',
#    'delivery',
#    'day',
#    'initially',
#    'even',
#    'second',
#    'third',
#    'order',
#    'single',
#    'month',
#    'well',
#    'luck',
#    'look',
#    'like',
#    'luck',
#    'run',
#    'along',
#    'service',
#    'unsubscribing',
#    'service',
#    'probably',
#    'let',
#    'prime',
#    'membership',
#    'expire',
#    'well',
#    'always',
#    'amazon',
#    'biggest',
#    'fan',
#    'singing',
#    'praise',
#    'everyone',
#    'recommending',
#    'stop',
#    'going',
#    'store',
#    'shop',
#    'online',
#    'said',
#    'well',
#    'generous',
#    'current',
#    'viewpoint',
#    'praise',
#    'shame',
#    'amazon',
#    'let',
#    'see',
#    'long',
#    'review',
#    'stay',
#    'visible',
#    'ever',
#    'make',
#    'online'],
#   'neg'),
#  (['dont',
#    'add',
#    'lot',
#    'make',
#    'stuff',
#    'taste',
#    'sweet',
#    'without',
#    'wired',
#    'tasting',
#    'added',
#    'sweetener',
#    'made',
#    'hot',
#    'soy',
#    'milk',
#    'turned',
#    'pretty',
#    'yummy'],
#   'pos'),
#  (['love',
#    'flavor',
#    'right',
#    'overwhelming',
#    'still',
#    'taste',
#    'cheese',
#    'jalapeno',
#    'every',
#    'bite',
#    'think',
#    'better',
#    'cheese',
#    'puff',
#    'back'],
#   'pos'),
#  (['disappointed',
#    'got',
#    'maybe',
#    'three',
#    'good',
#    'bulb',
#    'garlic',
#    'bulb',
#    'rotten',
#    'white',
#    'mold',
#    'growing',
#    'wish',
#    'could',
#    'get',
#    'money',
#    'back',
#    'another',
#    'good',
#    'batch',
#    'sent'],
#   'neg'),
#  (['like',
#    'seaweed',
#    'ended',
#    'throwing',
#    'pack',
#    'away',
#    'taste',
#    'fishy',
#    'force',
#    'give',
#    'star',
#    'could'],
#   'neg'),
#  (['searched',
#    'bonfire',
#    'accessory',
#    'used',
#    'open',
#    'fire',
#    'microwave',
#    'even',
#    'make'],
#   'neg'),
#  (['used', 'cake', 'topper', 'came', 'broken'], 'neg'),
#  (['whole',
#    'wheat',
#    'couscous',
#    'excellent',
#    'going',
#    'say',
#    'taste',
#    'regular',
#    'couscous',
#    'certainly',
#    'taste',
#    'worse',
#    'even',
#    'different',
#    'tempted',
#    'say',
#    'healthier',
#    'regular',
#    'couscous',
#    'since',
#    'use',
#    'butter',
#    'couscous',
#    'going',
#    'pretend',
#    'absolutely',
#    'healthy',
#    'product',
#    'still',
#    'better',
#    'lot',
#    'processed',
#    'carbs',
#    'butter',
#    'moderate',
#    'amount',
#    'fine',
#    'far',
#    'concerned',
#    'quite',
#    'bit',
#    'couscous',
#    'however',
#    'say',
#    'local',
#    'store',
#    'pick',
#    'one',
#    'two',
#    'box',
#    'whatever',
#    'shelf',
#    'think',
#    'able',
#    'use',
#    'box',
#    'reasonable',
#    'period',
#    'time',
#    'main',
#    'downside',
#    'good',
#    'box',
#    'lot',
#    'shopping',
#    'around',
#    'couscous',
#    'found',
#    'one',
#    'best',
#    'term',
#    'price',
#    'performance',
#    'quality',
#    'product',
#    'whole',
#    'wheat',
#    'version',
#    'packaged',
#    'delivered',
#    'good',
#    'cost',
#    'recommended'],
#   'pos'),
#  (['thank', 'great', 'service', 'love', 'soup'], 'pos'),
#  (['bought',
#    'wrong',
#    'pod',
#    'stuck',
#    'dollar',
#    'worth',
#    'pod',
#    'cant',
#    'use',
#    'annoys',
#    'cant',
#    'returned'],
#   'neg'),
#  (['tab',
#    'switch',
#    'indicated',
#    'instruction',
#    'switch',
#    'came',
#    'position',
#    'wouldnt',
#    'light',
#    'assuming',
#    'battery',
#    'dead',
#    'front',
#    'house',
#    'came',
#    'cracked',
#    'disappointing',
#    'recommend',
#    'kit'],
#   'neg'),
#  (['allergic',
#    'many',
#    'thing',
#    'felt',
#    'truly',
#    'denied',
#    'fun',
#    'food',
#    'lucky',
#    'day',
#    'discovered',
#    'yummy',
#    'earth',
#    'organic',
#    'lollipop',
#    'major',
#    'allergen',
#    'category',
#    'corn',
#    'syrup',
#    'gluten',
#    'casein',
#    'artificial',
#    'dye',
#    'gmo',
#    'msg',
#    '100',
#    'vegan',
#    'yet',
#    '100',
#    'tasty',
#    'made',
#    '100',
#    'natural',
#    'flavor',
#    'delicious',
#    'fruity',
#    'pop',
#    'puckering',
#    'sour',
#    'pop',
#    'vitamin',
#    'pop',
#    'hot',
#    'chili',
#    'pop',
#    'even',
#    'organic',
#    'candy',
#    'drop',
#    'little',
#    'le',
#    'calorie',
#    'per',
#    'pop',
#    'feel',
#    'free',
#    'indulge',
#    'tasty',
#    'flavor',
#    'whenever',
#    'yummy',
#    'earth',
#    'pop',
#    'urge',
#    'catch',
#    'yummy',
#    'earth',
#    'lollipop',
#    'stashed',
#    'purse',
#    'desk',
#    'backpack',
#    'candy',
#    'jar',
#    'know',
#    'wherever',
#    'whenever',
#    'enjoy',
#    'delicious',
#    'treat',
#    'body',
#    'truly',
#    'enjoying',
#    'nothing',
#    'harmful',
#    'full',
#    'empty',
#    'calories1',
#    'real',
#    'treat',
#    'know',
#    'love',
#    'much',
#    'happy',
#    'yummy',
#    'earth',
#    'lollipoping'],
#   'pos'),
#  (['delicious',
#    'allergy',
#    'friendly',
#    'snack',
#    'devour',
#    'mood',
#    'something',
#    'sweet'],
#   'pos'),
#  (['poor', 'taste'], 'neg'),
#  (['first',
#    'taste',
#    'week',
#    'ago',
#    'absolutely',
#    'love',
#    'grade',
#    'nutrient',
#    'sweetness',
#    'going',
#    'back',
#    'regular',
#    'maple',
#    'time',
#    'soon'],
#   'pos'),
#  (['read',
#    'fine',
#    'print',
#    'buy',
#    'got',
#    'gift',
#    'friend',
#    'allergic',
#    'gluten',
#    'love',
#    'licorice',
#    'turn',
#    'teeny',
#    'tiny',
#    'barbie',
#    'doll',
#    'sized',
#    'box',
#    'licorice',
#    'look',
#    'like',
#    'juicy',
#    'chewy',
#    'licorice',
#    'bit',
#    'photo',
#    'size',
#    'ice',
#    'cream',
#    'sprinkle',
#    'tiny',
#    'box',
#    'plus',
#    'taste',
#    'terrible',
#    'amazon',
#    'let',
#    'return',
#    'food',
#    'item',
#    'stuck',
#    'bunch',
#    'inedible',
#    'tiny',
#    'box',
#    'licorice',
#    'yuck'],
#   'neg'),
#  (['drink',
#    'stuff',
#    'every',
#    'night',
#    'taste',
#    'better',
#    'bedtime',
#    'chamomile',
#    'tea',
#    'tried',
#    'many',
#    'also',
#    'love',
#    'little',
#    'message',
#    'tea',
#    'bag',
#    'remind',
#    'live',
#    'good',
#    'life'],
#   'pos'),
#  (['lot', 'small', 'bad'], 'neg'),
#  (['would',
#    'buy',
#    'way',
#    'expensive',
#    'notice',
#    'difference',
#    'currently',
#    'back',
#    'using',
#    'himalayan',
#    'fine',
#    'grain',
#    'salt',
#    'love',
#    'use',
#    'much'],
#   'neg'),
#  (['best',
#    'low',
#    'carb',
#    'egg',
#    'fettuccine',
#    'ever',
#    'eaten',
#    'great',
#    'product',
#    'people',
#    'watching',
#    'carbs'],
#   'pos'),
#  (['disappointed',
#    'purchase',
#    'almost',
#    'hard',
#    'coating',
#    'egg',
#    'broken',
#    'fell',
#    'egg',
#    'bottom',
#    'clear',
#    'plastic',
#    'labelless',
#    'bag',
#    'inch',
#    'shell',
#    'chocolate',
#    'crumb'],
#   'neg'),
#  (['appreciate',
#    'good',
#    'dark',
#    'chocolate',
#    'fond',
#    'coconut',
#    'look',
#    'pinnacle',
#    'naughty',
#    'treat',
#    'goodness',
#    'perspective',
#    'store',
#    'fridge',
#    'nice',
#    'cool',
#    'chocolate',
#    'crisp',
#    'bite',
#    'feel',
#    'chocolate',
#    'break',
#    'succulent',
#    'coconut',
#    'massage',
#    'tongue',
#    'sit',
#    'back',
#    'enjoy',
#    'wave',
#    'culinary',
#    'pleasure',
#    'wash',
#    'might',
#    'one'],
#   'pos'),
#  (['great', 'fast', 'shipping'], 'pos'),
#  (['know',
#    'popcorn',
#    'sugar',
#    'since',
#    'fine',
#    'print',
#    'impossible',
#    'read',
#    'buy',
#    'low',
#    'calorie',
#    'product',
#    'would',
#    'want',
#    'sugar',
#    'wish',
#    'could',
#    'return',
#    'manufacturer',
#    'made',
#    'clear',
#    'capital',
#    'bold',
#    'letter',
#    'product',
#    'sugar'],
#   'neg'),
#  (['fresh', 'delicious', 'everyone', 'wedding', 'thought', 'best', 'ever'],
#   'pos'),
#  (['poor', 'taste', 'like', 'dark', 'chocolate', 'like', 'bitter', 'tasting'],
#   'neg'),
#  (['taste',
#    'expected',
#    'nutty',
#    'bold',
#    'addicting',
#    'coupled',
#    'merlot',
#    'grigio',
#    'try',
#    'unsalted'],
#   'pos'),
#  (['always', 'trusting'], 'pos'),
#  (['coffee',
#    'super',
#    'weak',
#    'used',
#    'pack',
#    'still',
#    'tasted',
#    'horrible',
#    'threw',
#    'away',
#    'rest'],
#   'neg'),
#  (['love', 'dove', 'chocolate', 'melted', 'time', 'delivered', 'office'],
#   'neg'),
#  (['eager',
#    'try',
#    'bean',
#    'love',
#    'coffee',
#    'instead',
#    'disappointed',
#    'bean',
#    'arrived',
#    'melted',
#    'condition',
#    'evidenced',
#    'photo'],
#   'neg'),
#  (['one', 'color', 'delivered', 'different', 'vase', 'impressed'], 'neg'),
#  (['issue',
#    'another',
#    'reviewer',
#    'received',
#    'different',
#    'flavor',
#    'instead',
#    'different',
#    'flavor',
#    'missing',
#    'flavor',
#    'ordered'],
#   'neg'),
#  (['nice',
#    'strong',
#    'smell',
#    'cracked',
#    'ground',
#    'fine',
#    'best',
#    'black',
#    'pepper',
#    'used'],
#   'pos'),
#  (['helper',
#    'product',
#    'unbelievably',
#    'gross',
#    'nasty',
#    'smell',
#    'coming',
#    'form',
#    'turn',
#    'stomach',
#    'would',
#    'anyone',
#    'ruin',
#    'perfectly',
#    'good',
#    'hamburger',
#    'chicken',
#    'tuna',
#    'product'],
#   'neg'),
#  (['received',
#    'chip',
#    'try',
#    'influenster',
#    'blossom',
#    'vox',
#    'box',
#    'usually',
#    'big',
#    'chip',
#    'person',
#    'black',
#    'bean',
#    'person',
#    'okay',
#    'boyfriend',
#    'loved',
#    'he',
#    'hooked',
#    'wait',
#    'get'],
#   'pos'),
#  (['product',
#    'give',
#    'great',
#    'result',
#    'took',
#    'little',
#    'experiementing',
#    'get',
#    'right',
#    'mixture',
#    'size',
#    'scoop',
#    'given',
#    'recipe',
#    'bag',
#    'got',
#    'right',
#    'need',
#    'donald',
#    'buy',
#    'anymore'],
#   'pos'),
#  (['bar',
#    'delicious',
#    'contain',
#    'almond',
#    'allergic',
#    'almond',
#    'difficult',
#    'find',
#    'gluten',
#    'free',
#    'cookie',
#    'without',
#    'almond',
#    'almond',
#    'flour',
#    'also',
#    'need',
#    'soy',
#    'free',
#    'house',
#    'snack',
#    'bar',
#    'also',
#    'soy',
#    'free'],
#   'pos'),
#  (['chocolate',
#    'wonderful',
#    'know',
#    'tried',
#    'recommend',
#    'ordering',
#    'way',
#    'chocolate',
#    'arrived',
#    'melted',
#    'said',
#    'amazon',
#    'kindly',
#    'issued',
#    'refund'],
#   'neg'),
#  (['bought',
#    'cooky',
#    'amp',
#    'supply',
#    'going',
#    'back',
#    'work',
#    'essence',
#    'cooky',
#    'job',
#    'creating',
#    'milk',
#    'body',
#    'however',
#    'disgusting',
#    'dry',
#    'fall',
#    'apart',
#    'slightest',
#    'vibration',
#    'towards',
#    'end',
#    'package',
#    'broken',
#    'looked',
#    'like',
#    'granola',
#    'cereal',
#    'cookie',
#    'would',
#    'rather',
#    'trouble',
#    'making',
#    'get',
#    'please',
#    'place',
#    'napkin',
#    'plate',
#    'underneath',
#    'mouth',
#    'catch',
#    'multitude',
#    'crumb',
#    'fall',
#    'save',
#    'time',
#    'vacuuming'],
#   'neg'),
#  (['tasted',
#    'like',
#    'imagine',
#    'cardboard',
#    'would',
#    'taste',
#    'food',
#    'taste',
#    'good',
#    'chip'],
#   'neg'),
#  (['wonderful', 'nicely', 'packaged'], 'pos'),
#  (['chocolate',
#    'almond',
#    'butter',
#    'flavor',
#    'terrible',
#    'hate',
#    'say',
#    'love',
#    'regular',
#    'peanut',
#    'butter',
#    'flavor',
#    'want',
#    'support',
#    'company',
#    'product',
#    'wondering',
#    'bad',
#    'batch',
#    'mine',
#    'say',
#    'expires',
#    '2015',
#    'lot',
#    'ca09',
#    'tried',
#    'give',
#    'away',
#    'work',
#    'hate',
#    'wasting',
#    'money',
#    'everyone',
#    'tried',
#    'like',
#    'well',
#    'try',
#    'peanut',
#    'butter',
#    'flavor',
#    'company',
#    'almond',
#    'butter',
#    'flavor'],
#   'neg'),
#  (['excellent', 'plant'], 'pos'),
#  (['wish',
#    'bought',
#    'two',
#    'guess',
#    'use',
#    'extra',
#    'doorstop',
#    'eating',
#    'dry',
#    'dry',
#    'mean',
#    'every',
#    'drop',
#    'moisture',
#    'mouth',
#    'disappeared',
#    'instantly',
#    'stollen',
#    'entered',
#    'mouth',
#    'like',
#    'magic',
#    'swear',
#    'lite',
#    'flavor',
#    'kinda',
#    'imagine',
#    'sawdust',
#    'sugar',
#    'mix',
#    'would',
#    'taste',
#    'like',
#    'definitely',
#    'dresden',
#    'black',
#    'forrest',
#    'stollen'],
#   'neg'),
#  (['perfect', 'addition', 'paleo', 'snack'], 'pos'),
#  (['good'], 'neg'),
#  (['amazing'], 'pos'),
#  (['low',
#    'sodium',
#    'soup',
#    'incredibly',
#    'bland',
#    'usually',
#    'add',
#    'flavor',
#    'campbell',
#    'low',
#    'sodium',
#    'chicken',
#    'broth',
#    'tasty',
#    'first',
#    'saut',
#    'onion',
#    'pan',
#    'add',
#    'vegetable',
#    'broth',
#    'piece',
#    'chicken',
#    'herb',
#    'simmer',
#    'low',
#    'sodium',
#    'beef',
#    'work',
#    'well',
#    'onion',
#    'veggie',
#    'beef',
#    'mushroom',
#    'soup',
#    'seems',
#    'unfixable',
#    'take',
#    'flavor',
#    'sits',
#    'slippery',
#    'flavorless',
#    'maybe',
#    'adding',
#    'one',
#    'big',
#    'pot',
#    'salty',
#    'soup',
#    'would',
#    'help',
#    'cut',
#    'sodium',
#    'make',
#    'much',
#    'soup',
#    'one',
#    'time',
#    'maybe',
#    'could',
#    'sauce',
#    'base',
#    'cook',
#    'pot',
#    'roast',
#    'anyone',
#    'try',
#    'please',
#    'post',
#    'result',
#    'meanwhile',
#    'stick',
#    'chicken',
#    'beef',
#    'sorry',
#    'campbell'],
#   'neg'),
#  (['taste',
#    'great',
#    'last',
#    'good',
#    'long',
#    'learn',
#    'proper',
#    'amount',
#    'used',
#    'wish',
#    'little',
#    'scoop',
#    'hard',
#    'learn',
#    'best',
#    'amount',
#    'coffee',
#    'visually'],
#   'pos'),
#  (['kid',
#    'throw',
#    'away',
#    'hard',
#    'rock',
#    'son',
#    'upset',
#    'part',
#    'birthday',
#    'party',
#    'favor'],
#   'neg'),
#  (['awful',
#    'taste',
#    'really',
#    'bitter',
#    'also',
#    'incredibly',
#    'overpriced',
#    'tiny',
#    'amount',
#    'send',
#    'photo',
#    'entirely',
#    'misleading'],
#   'neg'),
#  (['half',
#    'cup',
#    'picture',
#    'actually',
#    'box',
#    'seemed',
#    'lot',
#    'christmas',
#    'cup'],
#   'neg'),
#  (['first',
#    'time',
#    'ever',
#    'cooking',
#    'cocoa',
#    'butter',
#    'nothing',
#    'compare',
#    'package',
#    'arrived',
#    'quickly',
#    'looked',
#    'exactly',
#    'pictured',
#    'used',
#    'make',
#    'white',
#    'chocolate',
#    'raspberry',
#    'torte',
#    'birthday',
#    'yes',
#    'want',
#    'birthday',
#    'cake',
#    'make',
#    'taste',
#    'wonderful',
#    'cake',
#    'extremely',
#    'rich',
#    'eat',
#    'small',
#    'slice',
#    'time',
#    'preferably',
#    'strong',
#    'coffee',
#    'balance',
#    'sweetness',
#    'happy',
#    'would',
#    'definitely',
#    'purchase'],
#   'pos'),
#  (['purchased',
#    'kid',
#    'always',
#    'purchasing',
#    'alternative',
#    'chip',
#    'love',
#    'much',
#    'stumbled',
#    'upon',
#    'ordered',
#    'variety',
#    'pack',
#    'kid',
#    'could',
#    'experience',
#    'different',
#    'flavor',
#    'happy',
#    'ate',
#    'usually',
#    'purchase',
#    'pop',
#    'chip',
#    'pop',
#    'corner',
#    'thought',
#    'would',
#    'fun',
#    'change',
#    'kid',
#    'right',
#    'tried',
#    'bag',
#    'immediately',
#    'told',
#    'much',
#    'liked',
#    'almost',
#    'everyday',
#    'christmas',
#    'break',
#    'wanted',
#    'bag',
#    'afternoon',
#    'snack',
#    'tried',
#    'flavor',
#    'variety',
#    'pack',
#    'heard',
#    'objection',
#    'yet',
#    'tried',
#    'sea',
#    'salt',
#    'cheddar',
#    'salt',
#    'vinegar',
#    'variety',
#    'enjoyed',
#    'flavor',
#    'like',
#    'pop',
#    'chip',
#    'chance',
#    'like',
#    'although',
#    'seasoning',
#    'fry',
#    'intense',
#    'flavoring',
#    'pop',
#    'chip',
#    'still',
#    'think',
#    'enjoyable',
#    'snack',
#    'kid',
#    'adult'],
#   'pos'),
#  (['stevia', 'taste', 'seem', 'get', 'used'], 'neg'),
#  (['great',
#    'quick',
#    'cup',
#    'morning',
#    'something',
#    'warm',
#    'cold',
#    'evening',
#    'best',
#    'small',
#    'medium',
#    'setting',
#    'great',
#    'occasional',
#    'treat',
#    'watch',
#    'often',
#    'drink',
#    'saturated',
#    'fat',
#    'content',
#    'pretty',
#    'high',
#    'level',
#    'small',
#    'cup'],
#   'pos'),
#  (['stuff',
#    'god',
#    'suck',
#    'last',
#    'drop',
#    'best',
#    'tasting',
#    'broth',
#    'ever',
#    'found',
#    'concentrated'],
#   'pos'),
#  (['delicious', 'package', 'perfect', 'going', 'order'], 'pos'),
#  (['snapple',
#    'cup',
#    'released',
#    'finally',
#    'reason',
#    'get',
#    'keurig',
#    'coffee',
#    'drinker',
#    'love',
#    'snapple',
#    'peach',
#    'iced',
#    'tea',
#    'made',
#    'first',
#    'cup',
#    'thought',
#    'taste',
#    'really',
#    'thought',
#    'might',
#    'cup',
#    'version',
#    'looked',
#    'box',
#    'found',
#    'contains',
#    'aspartame',
#    'gross',
#    'real',
#    'snapple',
#    'peach',
#    'iced',
#    'tea',
#    'contain',
#    'aspartame',
#    'best',
#    'stuff',
#    'earth',
#    'chemical',
#    'tasting',
#    'peach',
#    'iced',
#    'tea',
#    'snapple',
#    'label'],
#   'neg'),
#  (['good',
#    'product',
#    'great',
#    'price',
#    'arrived',
#    'promptly',
#    'iam',
#    'pastry',
#    'chef',
#    'bake',
#    'diabetic',
#    'pastry',
#    'using',
#    'container',
#    'better',
#    'opening',
#    'equal',
#    'packet',
#    'cup',
#    'sometimes',
#    'need',
#    'cup',
#    'cheaper',
#    'le',
#    'annoying',
#    'opening',
#    '240',
#    'packet'],
#   'pos'),
#  (['ordered',
#    'product',
#    'love',
#    'however',
#    'ordering',
#    'mistake',
#    'pod',
#    'puffy',
#    'top',
#    'every',
#    'time',
#    'brewed',
#    'pod',
#    'ground',
#    'would',
#    'completely',
#    'empty',
#    'coffee',
#    'cup',
#    'first',
#    'thought',
#    'machine',
#    'cleaned',
#    'descaled',
#    'tried',
#    'regular',
#    'pod',
#    'worked',
#    'fine',
#    'bought',
#    'half',
#    'caff',
#    'pod',
#    'grocery',
#    'store',
#    'fine',
#    'one',
#    'left',
#    'still',
#    'continue',
#    'dump',
#    'ground',
#    'cup',
#    'guessing',
#    'stored',
#    'heat',
#    'something',
#    'avoid'],
#   'neg'),
#  (['chia',
#    'seed',
#    'truly',
#    'super',
#    'food',
#    'chia',
#    'ancient',
#    'mayan',
#    'word',
#    'strength',
#    'full',
#    'antioxidant',
#    'high',
#    'fiber',
#    'high',
#    'protein',
#    'increase',
#    'feeling',
#    'fullness',
#    'omega',
#    'put',
#    'chia',
#    'seed',
#    'everything',
#    'favorite',
#    'late',
#    'night',
#    'cup',
#    'hot',
#    'tea',
#    'couple',
#    'spoon',
#    'full',
#    'chia',
#    'seed',
#    'sprinkle',
#    'bean',
#    'salad',
#    'protein',
#    'shake',
#    'even',
#    'taco',
#    'ever',
#    'think',
#    'throw',
#    'healthy',
#    'happy',
#    'little',
#    'seed',
#    'yes',
#    'chia',
#    'seed',
#    'got',
#    'kick',
#    'order',
#    'silly',
#    'chia',
#    'pet',
#    'kid',
#    'friend',
#    'eat',
#    'without',
#    'singing',
#    'jingle',
#    'cha',
#    'cha',
#    'cha',
#    'chia',
#    'enjoy',
#    'eat',
#    'healthy',
#    'product',
#    'dissappoint',
#    'important',
#    'pesticide',
#    'chemical',
#    'free',
#    'would',
#    'recommend',
#    'product',
#    'great',
#    'value',
#    'great',
#    'product',
#    'pleasant',
#    'taste'],
#   'pos'),
#  (['need'], 'pos'),
#  (['gr8', 'product', 'mixed', 'worth', 'tea', 'made', 'even', 'better', 'tea'],
#   'pos'),
#  (['great'], 'pos'),
#  (['mild', 'pleasing', 'instant', 'coffee'], 'pos'),
#  (['tea',
#    'taste',
#    'like',
#    'fruity',
#    'pebble',
#    'fruit',
#    'loop',
#    'lemon',
#    'citrus',
#    'guessing',
#    'bergamot'],
#   'neg'),
#  (['worst',
#    'item',
#    'ever',
#    'received',
#    'put',
#    'right',
#    'garbage',
#    'disappointed'],
#   'neg'),
#  (['buy', 'fresher', 'supermarket', 'half', 'cost', 'waste', 'money'], 'neg'),
#  (['made',
#    'many',
#    'rye',
#    'loaf',
#    'meal',
#    'convenient',
#    'packaging',
#    'finished',
#    'order',
#    'meal',
#    'coarse',
#    'flour',
#    'make',
#    'hearty',
#    'bread'],
#   'pos'),
#  (['regular',
#    'pasta',
#    'sold',
#    '12oz',
#    'box',
#    '8oz',
#    'regular',
#    'pasta',
#    'expands',
#    'cooked',
#    'half',
#    'box',
#    'barely',
#    'made',
#    'half',
#    'serving',
#    'recommended',
#    'cook',
#    'time',
#    'minute',
#    'feel',
#    'undercooked',
#    'minute',
#    'break',
#    'piece',
#    'still',
#    'feel',
#    'undercooked',
#    'taste',
#    'would',
#    'probably',
#    'taste',
#    'better',
#    'boil',
#    'box',
#    'came'],
#   'neg'),
#  (['ingredient',
#    'brominated',
#    'vegetable',
#    'oil',
#    'target',
#    'petition',
#    'mississippi',
#    'teenager',
#    'sarah',
#    'kavanagh',
#    'questioned',
#    'used',
#    'drink',
#    'marketed',
#    'toward',
#    'health',
#    'conscious',
#    'athlete',
#    'petition',
#    'change',
#    'org',
#    'noted',
#    'ingredient',
#    'linked',
#    'flame',
#    'retardant',
#    'approved',
#    'use',
#    'japan',
#    'european',
#    'union'],
#   'neg'),
#  (['livid',
#    'received',
#    'palm',
#    'oil',
#    'excited',
#    'quickly',
#    'arrived',
#    'bought',
#    'plan',
#    'make',
#    'soap',
#    'getting',
#    'busy',
#    'put',
#    'soap',
#    'making',
#    'today',
#    'month',
#    'later',
#    'opened',
#    'jar',
#    'large',
#    'amount',
#    'missing',
#    'full',
#    'jar',
#    'weighed',
#    'bottle',
#    'unable',
#    'remove',
#    'content',
#    'subtract',
#    'weight',
#    'plastic',
#    'jar',
#    'weighted',
#    'used',
#    'needle',
#    'say',
#    'disappointed',
#    'opening',
#    'jar',
#    'came',
#    'never',
#    'buy'],
#   'neg'),
#  (['flavor', 'like'], 'neg'),
#  (['better', 'way', 'fine', 'assortment', 'best', 'jelly'], 'pos'),
#  (['buy',
#    'seller',
#    'tea',
#    'taste',
#    'return',
#    'purchased',
#    'tea',
#    'different',
#    'seller',
#    'good',
#    'taste',
#    'like',
#    'old',
#    'much',
#    'flavor'],
#   'neg'),
#  (['love',
#    'almost',
#    'bean',
#    'almost',
#    'inedible',
#    'sludgily',
#    'overcooked',
#    'obnoxious',
#    'tasting',
#    'sauce',
#    'validating',
#    'existing',
#    'review',
#    'could',
#    'finish',
#    'small',
#    'bowl',
#    'bad',
#    'van',
#    'camp',
#    'bean',
#    'par',
#    'bush',
#    'name',
#    'brand'],
#   'neg'),
#  (['drinking',
#    'yogi',
#    'tea',
#    'licorice',
#    'flavor',
#    'two',
#    'year',
#    'thought',
#    'time',
#    'try',
#    'something',
#    'new',
#    'cocoa',
#    'spice',
#    'without',
#    'sweetener',
#    'creamer',
#    'immediate',
#    'taste',
#    'upon',
#    'entering',
#    'mouth',
#    'sweet',
#    'soothing',
#    'taste',
#    'followed',
#    'strong',
#    'spicy',
#    'zest',
#    'tingle',
#    'throat',
#    'swallowed',
#    'almost',
#    'like',
#    'hot',
#    'cinnamon',
#    'disc',
#    'hard',
#    'candy',
#    'one',
#    'tea',
#    'drink',
#    'without',
#    'sweetener',
#    'tea',
#    'minute',
#    'add',
#    'sugar',
#    'taste',
#    'intensified',
#    'extremely',
#    'delightful',
#    'tea',
#    'favorite',
#    'way',
#    'drink',
#    'cocoa',
#    'spice',
#    'teabag',
#    '12oz',
#    'hot',
#    'water',
#    'packet',
#    'splenda',
#    'teaspoon',
#    'sugar',
#    'bad',
#    'day',
#    'tablespoon',
#    'half',
#    'half',
#    'amazing',
#    'try',
#    'sometime'],
#   'pos'),
#  (['taste', 'awful'], 'neg'),
#  (['big', 'bag', 'delicious'], 'pos'),
#  (['waited',
#    'year',
#    'product',
#    'emerge',
#    'amazon',
#    'made',
#    'sure',
#    'notified',
#    'yum',
#    'shipped',
#    'way',
#    'kauai',
#    'used',
#    'find',
#    'store',
#    'hot',
#    'light',
#    'fluffy',
#    'hawaiian',
#    'sweet',
#    'bread',
#    'splashed',
#    'soft',
#    'sweet',
#    'butter',
#    'smart',
#    'balance',
#    'wonderfully',
#    'delicious',
#    'way',
#    'wake',
#    'morning',
#    'set',
#    'timer',
#    'bread',
#    'maker',
#    'finish',
#    'get',
#    'oooh',
#    'breakfast',
#    'bed',
#    'know',
#    'mean'],
#   'pos'),
#  (['absolutely',
#    'great',
#    'product',
#    'miss',
#    'salt',
#    'seasoning',
#    'great',
#    'food'],
#   'pos'),
#  (['great', 'healthy', 'oil', 'cooking'], 'pos'),
#  (['tasted', 'like', 'wax'], 'neg'),
#  (['best', 'walden', 'farm', 'dressing'], 'pos'),
#  (['great', 'manhattan'], 'pos'),
#  (['really',
#    'enjoy',
#    'tasty',
#    'always',
#    'sound',
#    'good',
#    'really',
#    'taste',
#    'much',
#    'different',
#    'typical',
#    'dutch',
#    'stroopwafel',
#    'thank',
#    'goodness',
#    'individually',
#    'packaged',
#    'eat',
#    'ton',
#    'light',
#    'enough',
#    'eat',
#    'right',
#    'exercise',
#    'give',
#    'little',
#    'sugar',
#    'boost',
#    'great',
#    'complaint',
#    'wish',
#    'came',
#    'smaller',
#    'size',
#    'maybe',
#    'three',
#    'pack',
#    'could',
#    'fit',
#    'little',
#    'running',
#    'pouch'],
#   'pos'),
#  (['xylitol',
#    'gum',
#    'may',
#    'prevent',
#    'cavity',
#    'flavor',
#    'last',
#    'second',
#    'choose',
#    'aspertame',
#    'flavored',
#    'gum',
#    'thank'],
#   'neg'),
#  (['product',
#    'stale',
#    'inedible',
#    'quite',
#    'awful',
#    'asked',
#    'refund',
#    'twice',
#    'recieved',
#    'response',
#    'waste',
#    'time'],
#   'neg'),
#  (['favorite',
#    'tuna',
#    'started',
#    'purchasing',
#    'albacore',
#    'tuna',
#    'ingredient',
#    'albacore',
#    'tuna',
#    'spring',
#    'water',
#    'sea',
#    'salt',
#    'contain',
#    'vegetable',
#    'soybean',
#    'broth',
#    'pyrophosphate',
#    'ingredient',
#    'highly',
#    'recommend',
#    'tuna',
#    'receiving',
#    'tuna',
#    'subscribe',
#    'save',
#    'long',
#    'time',
#    'always',
#    'perfect',
#    'highly',
#    'consistent',
#    'product'],
#   'pos'),
#  (['powerful',
#    'herb',
#    'absolute',
#    'loving',
#    'highly',
#    'recommend',
#    'everyone',
#    'real',
#    'nutrition'],
#   'pos'),
#  (['happy',
#    'purchase',
#    'expiration',
#    'date',
#    'package',
#    'date',
#    'oct',
#    '2017',
#    'month',
#    'time',
#    'purchase',
#    'price',
#    'good',
#    'however',
#    'problem',
#    'product',
#    'listing',
#    'time',
#    'purchase',
#    'product',
#    'listing',
#    'photo',
#    'show',
#    '1lb',
#    'bag',
#    'case',
#    'purchasing',
#    'combined',
#    'order',
#    'friend',
#    'note',
#    'might',
#    'receive',
#    'single',
#    'larger',
#    'bag',
#    'may',
#    'three',
#    'separate',
#    '1lb',
#    'bag',
#    'like',
#    'photo',
#    'implies',
#    'purchasing',
#    'probably',
#    'issue',
#    'splitting',
#    'order',
#    'friend',
#    'using',
#    '3lb',
#    'one',
#    'time',
#    'might',
#    'pour',
#    'package',
#    'content',
#    'container',
#    'capable',
#    'holding',
#    'would',
#    'left',
#    '3lb',
#    'bag',
#    'almond',
#    'flour',
#    'said',
#    'bob',
#    'red',
#    'mill',
#    'amond',
#    'flour',
#    'good',
#    'quality',
#    'stuff'],
#   'pos'),
#  (['gross'], 'neg'),
#  (['box',
#    'lot',
#    'chocolate',
#    'flavored',
#    'coffee',
#    'like',
#    'chocolate',
#    'much'],
#   'neg'),
#  (['item',
#    'true',
#    'description',
#    'item',
#    'came',
#    'trashy',
#    'pink',
#    'bag',
#    'certainly',
#    'cannot',
#    'give',
#    'gift',
#    'disappointing'],
#   'neg'),
#  (['tea', 'bag', 'hole'], 'neg'),
#  (['although',
#    'ordered',
#    'dan',
#    'pak',
#    'jumbo',
#    'premium',
#    'cashew',
#    'salted',
#    'sent',
#    'regular',
#    'cashew',
#    'cashew',
#    'size',
#    'delicious',
#    'ended',
#    'eating'],
#   'neg'),
#  (['ordered',
#    'product',
#    'several',
#    'time',
#    'still',
#    'keep',
#    'coming',
#    'bursted',
#    'open',
#    'sure',
#    'keep',
#    'happening'],
#   'neg'),
#  (['bag', 'smashed'], 'neg'),
#  (['came', 'wrong', 'color', 'broken'], 'neg'),
#  (['taste',
#    'first',
#    'try',
#    'kind',
#    'product',
#    'may',
#    'like',
#    'use',
#    'similar',
#    'staff'],
#   'neg'),
#  (['save',
#    'money',
#    'husband',
#    'took',
#    'one',
#    'spoon',
#    'full',
#    'got',
#    'kitchen',
#    'table',
#    'bowl',
#    'spoon',
#    'cereal',
#    'milk',
#    'went',
#    'closet',
#    'box',
#    'bought',
#    'amazon'],
#   'neg'),
#  (['smell', 'like', 'fresh', 'cut', 'grass'], 'neg'),
#  (['favorite', 'rice', 'always', 'come', 'great'], 'pos'),
#  (['coffee',
#    'old',
#    'cup',
#    'sounded',
#    'like',
#    'hard',
#    'clump',
#    'coffee',
#    'shaken',
#    'flavor',
#    'fresh',
#    'order',
#    'expensive',
#    'good'],
#   'neg'),
#  (['tasty',
#    'wonderful',
#    'combination',
#    'spice',
#    'sweetness',
#    'require',
#    'added',
#    'sugar',
#    'sweetener',
#    'milk',
#    'great',
#    'looking',
#    'chai',
#    'style',
#    'tea'],
#   'pos'),
#  (['although',
#    'like',
#    'several',
#    'walden',
#    'product',
#    'chocolate',
#    'syrup',
#    'caramel',
#    'syrup',
#    'excellent',
#    'peanut',
#    'spread',
#    'dreadful',
#    'first',
#    'taste',
#    'anything',
#    'like',
#    'peanut',
#    'butter',
#    'food',
#    'could',
#    'recognize',
#    'second',
#    'texture',
#    'deeply',
#    'disgusting',
#    'like',
#    'mixed',
#    'sour',
#    'cream',
#    'jello',
#    'dog',
#    'would',
#    'rather',
#    'eat',
#    'toe',
#    'cheese',
#    'product',
#    'let',
#    'work',
#    'together',
#    'identify',
#    'whoever',
#    'created',
#    'supremely',
#    'loathsome',
#    'product',
#    'force',
#    'eat',
#    'jar',
#    'make',
#    'mental',
#    'anguish',
#    'product',
#    'caused',
#    'everyone',
#    'tasted',
#    'still',
#    'nightmare',
#    'half',
#    'teaspoon',
#    'tried',
#    'several',
#    'month',
#    'back',
#    'shudder'],
#   'neg'),
#  (['eat', 'cold', 'weather', 'apparently', 'purchase', 'time', 'love', 'easy'],
#   'pos'),
#  (['much', 'money', 'normally', 'cost'], 'neg'),
#  (['excellent'], 'pos'),
#  (['nasty', 'tbh'], 'neg'),
#  (['found',
#    'vanished',
#    'store',
#    'taste',
#    'better',
#    'remember',
#    'easy',
#    'make',
#    'much',
#    'better',
#    'type',
#    'round',
#    'cup',
#    'add',
#    'water',
#    'taste',
#    'plastic'],
#   'pos'),
#  (['coffee',
#    'received',
#    'old',
#    'expiration',
#    'date',
#    'one',
#    'month',
#    'received',
#    'checked',
#    'thing',
#    'starbucks',
#    'costco',
#    'year',
#    'expiration',
#    'time',
#    'look',
#    'like',
#    'dumping',
#    'old',
#    'coffee',
#    'probably',
#    'got',
#    'discount',
#    'house'],
#   'neg'),
#  (['oil', 'produced', 'last', 'year', 'expires', 'month', 'smell', 'old'],
#   'neg'),
#  (['also',
#    'soft',
#    'enjoyable',
#    'kid',
#    'share',
#    'box',
#    'arrives',
#    'fight',
#    'get',
#    'hold'],
#   'pos'),
#  (['good', 'stuff', 'quick', 'easy', 'make'], 'pos'),
#  (['really', 'enjoy'], 'pos'),
#  (['olive',
#    'glass',
#    'bottle',
#    'separated',
#    'anything',
#    'packaged',
#    'item',
#    'luckily',
#    'break',
#    'shipping',
#    'however',
#    'top',
#    'jar',
#    'hit',
#    'something',
#    'point',
#    'either',
#    'shipment',
#    'prior',
#    'denting',
#    'lid',
#    'opening',
#    'slightly',
#    'seal',
#    'broken',
#    'release',
#    'pop',
#    'heard',
#    'opened',
#    'jar',
#    'therefor',
#    'unable',
#    'eaten',
#    'yesterday',
#    'new',
#    'year',
#    'celebration',
#    'additionally',
#    'disappointing'],
#   'neg'),
#  (['cup',
#    'flour',
#    'cup',
#    'water',
#    'got',
#    'yummy',
#    'vegan',
#    'meat',
#    'easy',
#    'make',
#    'love'],
#   'pos'),
#  (['wow',
#    'love',
#    'chia',
#    'seed',
#    'oatmeal',
#    'every',
#    'morning',
#    'swell',
#    'make',
#    'feel',
#    'full',
#    'hour',
#    'force',
#    'remember',
#    'eat',
#    'lunch',
#    'satisfied'],
#   'pos'),
#  (['place',
#    'buy',
#    'per',
#    'bottle',
#    'totally',
#    'save',
#    'money',
#    'month',
#    'irish',
#    'cream',
#    'one',
#    'still',
#    'delicious',
#    'coffee',
#    'soda',
#    'mix',
#    'drink',
#    'even',
#    'made',
#    'raspberry',
#    'cake'],
#   'pos'),
#  (['hard',
#    'dried',
#    'taste',
#    'like',
#    'sat',
#    'warehouse',
#    'year',
#    'would',
#    'recommend',
#    'buy',
#    'gas',
#    'station',
#    'snack',
#    'never',
#    'one',
#    'taste',
#    'bad',
#    'came',
#    'box'],
#   'neg'),
#  (['taking', 'week', 'palpitation'], 'neg'),
#  (['tried',
#    'lot',
#    'tonic',
#    'mostly',
#    'vodka',
#    'tonic',
#    'one',
#    'drink',
#    'tonic',
#    'made',
#    'syrup',
#    'slightly',
#    'superior',
#    'one',
#    'get',
#    'grocery',
#    'liquor',
#    'store',
#    'consider',
#    'much',
#    'store',
#    'bought',
#    'stuff',
#    'go',
#    'flat',
#    'get',
#    'thrown',
#    'great',
#    'option',
#    'use',
#    'mine',
#    'one',
#    '500',
#    'bottle',
#    'another',
#    'good',
#    'investment',
#    'use',
#    'soda',
#    'stream',
#    'adult',
#    'beverage',
#    'also',
#    'keep',
#    'red',
#    'cola',
#    'around',
#    'reason',
#    'big',
#    'coke',
#    'mixed',
#    'drink',
#    'must'],
#   'pos'),
#  (['work', 'great', 'bought', 'twice', 'never', 'problem', 'yeast', 'rising'],
#   'pos'),
#  (['seven',
#    'twelve',
#    'can',
#    'dented',
#    'five',
#    'can',
#    'badly',
#    'dented',
#    'throw',
#    'away'],
#   'neg'),
#  (['sweet', 'quite', 'gummy'], 'neg'),
#  (['came', 'spoiled'], 'neg'),
#  (['piece',
#    'hard',
#    'chewable',
#    'hardly',
#    'disappointed',
#    'wild',
#    'bill',
#    'way',
#    'better',
#    'buy',
#    'known',
#    'someone',
#    'buy',
#    'great',
#    'company',
#    'great',
#    'reputation',
#    'cheapens',
#    'quality',
#    'cut',
#    'corner',
#    'charge',
#    'crap'],
#   'neg'),
#  (['candy',
#    'wonderful',
#    'really',
#    'enjoyed',
#    'thinking',
#    'getting',
#    'second',
#    'box',
#    'use',
#    'stocking',
#    'stuffer'],
#   'pos'),
#  (['disappointing',
#    'prune',
#    'slimy',
#    'gooey',
#    'smashed',
#    'together',
#    'big',
#    'mess',
#    'purchase',
#    'would',
#    'recommend'],
#   'neg'),
#  (['buying',
#    'year',
#    'always',
#    'two',
#    'box',
#    'pod',
#    'recently',
#    'price',
#    'doubled',
#    'one',
#    'box',
#    'pod',
#    'greed',
#    'forced',
#    'shop',
#    'brand',
#    'surprising',
#    'like',
#    'brand'],
#   'neg'),
#  (['stuff',
#    'bear',
#    'minimal',
#    'resemblance',
#    'real',
#    'macaroni',
#    'cheese',
#    'pasta',
#    'turn',
#    'mushy',
#    'goop',
#    'powdered',
#    'cheese',
#    'taste',
#    'like',
#    'cheese',
#    'odd',
#    'flavor',
#    'really',
#    'beyond',
#    'describing',
#    'convenience',
#    'pretty',
#    'much',
#    'thing',
#    'stuff',
#    'going',
#    'add',
#    'hot',
#    'water',
#    'convenient',
#    'gross',
#    'still',
#    'gross',
#    'want',
#    'something',
#    'hot',
#    'instant',
#    'much',
#    'better',
#    'choice'],
#   'neg'),
#  (['great',
#    'fan',
#    'ginger',
#    'love',
#    'everything',
#    'tea',
#    'stir',
#    'fry',
#    'wonderful',
#    'altoid',
#    'mint',
#    'combine',
#    'best',
#    'world',
#    'mint',
#    'concentrated',
#    'ginger',
#    'flavoring',
#    'soothe',
#    'stomach',
#    'freshen',
#    'breath',
#    'make',
#    'feel',
#    'happy',
#    'love'],
#   'pos'),
#  (['package',
#    'arrived',
#    'scheduled',
#    'date',
#    'box',
#    'inside',
#    'amazon',
#    'box',
#    'appeared',
#    'previously',
#    'used',
#    'item',
#    'tarnished',
#    'frustrating',
#    'order',
#    'amazon',
#    'take',
#    'return',
#    'although',
#    'next',
#    'day',
#    'going',
#    'return',
#    'process',
#    'state',
#    'contact',
#    'customer',
#    'service',
#    'yet',
#    'give',
#    'method',
#    'disappointed',
#    'amazon',
#    'definitely',
#    'consider',
#    'canceling',
#    'prime'],
#   'neg'),
#  (['bought',
#    'coffee',
#    'like',
#    'strong',
#    'bold',
#    'coffee',
#    'product',
#    'perfect',
#    'coffee',
#    'arrived',
#    'quickly'],
#   'pos'),
#  (['stale'], 'neg'),
#  (['love', 'milk'], 'pos'),
#  (['going',
#    'brutally',
#    'honest',
#    'one',
#    'worst',
#    'thing',
#    'ever',
#    'tasted',
#    'simply',
#    'drink',
#    'star',
#    'rating',
#    'required',
#    'think',
#    'deserves',
#    'one',
#    'waste',
#    'money'],
#   'neg'),
#  (['worst',
#    'eucalyptus',
#    'tea',
#    'ever',
#    'absolutely',
#    'eucalyptus',
#    'smell',
#    'taste',
#    'bought',
#    'cause',
#    'eucalyptus',
#    'open',
#    'congested',
#    'chest',
#    'weak',
#    'crap',
#    'nothing',
#    'would',
#    'never',
#    'order'],
#   'neg'),
#  (['brown',
#    'look',
#    'like',
#    'coffee',
#    'like',
#    'taste',
#    'chemical',
#    'aftertaste',
#    'threw',
#    'would',
#    'rather',
#    'drink',
#    'sanka',
#    'recommend',
#    'product'],
#   'neg'),
#  (['popcorn',
#    'flavoring',
#    'friend',
#    'house',
#    'good',
#    'experience',
#    'excited',
#    'pick',
#    'seasoning',
#    'along',
#    'new',
#    'air',
#    'popper',
#    'new',
#    'air',
#    'popper',
#    'great',
#    'throw',
#    'away',
#    'first',
#    'batch',
#    'popcorn',
#    'made',
#    'mistake',
#    'shaking',
#    'bit',
#    'weapon',
#    'grade',
#    'evil',
#    'fairy',
#    'dust',
#    'review',
#    'stated',
#    'remarkably',
#    'fine',
#    'powder',
#    'top',
#    'spicy',
#    'burn',
#    'breathe',
#    'could',
#    'eat',
#    'underwater',
#    'somehow',
#    'consume',
#    'without',
#    'breathing',
#    'would',
#    'maybe',
#    'enjoyable',
#    'summary',
#    'like',
#    'product',
#    'sting',
#    'face',
#    'orifice'],
#   'neg'),
#  (['grade',
#    'maple',
#    'syrup',
#    'delicious',
#    'also',
#    'nutritious',
#    'value',
#    'well',
#    'definitely',
#    'purchase',
#    'thanks',
#    'amazon',
#    'great',
#    'product',
#    'exceptional',
#    'price'],
#   'pos'),
#  (['stale'], 'neg'),
#  (['stirred',
#    'shook',
#    'jar',
#    'yes',
#    'get',
#    'flavor',
#    'described',
#    'taste',
#    'cardboard',
#    'overtakes',
#    'anything',
#    'else',
#    'might',
#    'deter',
#    'maybe',
#    'like',
#    'flavor',
#    'much'],
#   'neg'),
#  (['syrup', 'really', 'bad', 'taste'], 'neg'),
#  (['delicious',
#    'ordered',
#    'second',
#    'pack',
#    'month',
#    'yet',
#    'try',
#    'teriyaki',
#    'smoked',
#    'flavor'],
#   'pos'),
#  (['good',
#    'value',
#    'delivered',
#    'promised',
#    'well',
#    'protected',
#    'arrived',
#    'intact',
#    'exploded',
#    'torn',
#    'bag'],
#   'pos'),
#  (['oatmeal',
#    'salty',
#    'husband',
#    'cannot',
#    'eat',
#    'even',
#    'tried',
#    'mix',
#    'oatmeal',
#    'still',
#    'cannot',
#    'eat',
#    'disappointed',
#    'product',
#    'since',
#    'ordered',
#    'numerous',
#    'time',
#    'last',
#    'two',
#    'time',
#    'ordered',
#    'salty',
#    'husband',
#    'used',
#    'enjoy',
#    'oatmeal',
#    'oatmeal',
#    'every',
#    'day',
#    'brand',
#    'choice'],
#   'neg'),
#  (['nice',
#    'mix',
#    'easy',
#    'grab',
#    'snack',
#    'little',
#    'salty',
#    'little',
#    'sweet',
#    'protein',
#    'boot'],
#   'pos'),
#  (['package', 'defected', 'came'], 'neg'),
#  (['everything',
#    'expecting',
#    'except',
#    'unboxed',
#    'box',
#    'filled',
#    'cocoa',
#    'powder',
#    'container',
#    'opened',
#    'shipped'],
#   'neg'),
#  (['love',
#    'tea',
#    'need',
#    'decaf',
#    'great',
#    'flavor',
#    'buying',
#    'many',
#    'many',
#    'year'],
#   'pos'),
#  (['purchased',
#    'gummy',
#    'bear',
#    'candy',
#    'buffet',
#    'wedding',
#    'big',
#    'hit',
#    'taste',
#    'amazing',
#    'combined',
#    'pineapple',
#    'gummy',
#    'bear',
#    'highly',
#    'recommend',
#    'next',
#    'event'],
#   'pos'),
#  (['yummy', 'perfect', 'flavor', 'need', 'something', 'caffeine'], 'pos'),
#  (['first',
#    'love',
#    'amazon',
#    'shopping',
#    'never',
#    'disappointed',
#    'product',
#    'service',
#    'however',
#    'first',
#    'picture',
#    'box',
#    'actual',
#    'train',
#    'mold',
#    'received',
#    'marshmallow',
#    'hard',
#    'even',
#    'melt',
#    'rice',
#    'krispies',
#    'stale',
#    'box',
#    'still',
#    'valid',
#    'date',
#    'know',
#    'one',
#    'purchase',
#    'never',
#    'make'],
#   'neg'),
#  (['plan', 'try', 'use', 'make', 'white', 'chocolate', 'bake', 'cooky'],
#   'pos'),
#  (['used',
#    'mix',
#    'today',
#    'make',
#    'whoopie',
#    'pie',
#    'cream',
#    'cheese',
#    'frosting',
#    'two',
#    'cooky',
#    'best',
#    'pumpkin',
#    'mix',
#    'ever',
#    'used',
#    'family',
#    'loved',
#    'wait',
#    'make',
#    'denser',
#    'bread',
#    'bread',
#    'maker',
#    'excellent',
#    'quality',
#    'product'],
#   'pos'),
#  (['gave',
#    'food',
#    'poisoning',
#    'going',
#    'trash',
#    'belongs',
#    'homework',
#    'sesame',
#    'seed',
#    'fit',
#    'human',
#    'consumption'],
#   'neg'),
#  (['tried',
#    'pickel',
#    'mix',
#    'bread',
#    'butter',
#    'outsurpasses',
#    'adding',
#    'garlic',
#    'onion',
#    'ingredient',
#    'best'],
#   'pos'),
#  (['time', 'advertised'], 'pos'),
#  (['gave',
#    'box',
#    'woman',
#    'life',
#    'wife',
#    'daughter',
#    'valentine',
#    'day',
#    'always',
#    'love',
#    'chocolate',
#    'offer'],
#   'pos'),
#  (['literally',
#    'fowl',
#    'tasting',
#    'potato',
#    'chip',
#    'ever',
#    'smell',
#    'taste',
#    'horrible',
#    'flavor',
#    'like',
#    'undiscernable',
#    'chemical',
#    'cheddar',
#    'buffalo',
#    'flavor'],
#   'neg'),
#  (['half', 'box', 'broken', 'returning'], 'neg'),
#  (['delivered', 'moldy'], 'neg'),
#  (['love',
#    'van',
#    'holten',
#    'dill',
#    'pickle',
#    'get',
#    'locally',
#    'working',
#    'variety',
#    'ordering',
#    'box',
#    'dozen',
#    'time',
#    'really',
#    'enjoying',
#    'got',
#    'around',
#    'variety',
#    'big',
#    'papa',
#    'ordered',
#    'paying',
#    'expecting',
#    'usual',
#    'dozen',
#    'arrive',
#    'salt',
#    'dill',
#    'indulgence',
#    'extraordinaire',
#    'follow',
#    'happened',
#    'got',
#    'package',
#    'seemed',
#    'light',
#    'opened',
#    'inside',
#    'one',
#    'big',
#    'papa',
#    'dill',
#    'pickle',
#    'also',
#    'gross',
#    'guitar',
#    'pick',
#    'ordered',
#    'time',
#    'slightly',
#    'weirded',
#    'called',
#    'amazon',
#    'customer',
#    'service',
#    'explained',
#    'expected',
#    'received',
#    'credited',
#    'order',
#    'told',
#    'dispose',
#    'pickle',
#    'chose',
#    'delicious',
#    'ordered',
#    'figuring',
#    'confusion',
#    'stock',
#    'room',
#    'practical',
#    'joke',
#    'order',
#    'arrives',
#    'yep',
#    'one',
#    'pickle',
#    'time',
#    'wrong',
#    'pickle',
#    'van',
#    'holten',
#    'chipotle',
#    'pickle',
#    'speak',
#    'anyone',
#    'else',
#    'value',
#    'southern',
#    'bit',
#    'bit',
#    'much',
#    'eat',
#    'anything',
#    'contains',
#    'serious',
#    'spice',
#    'understanding',
#    'chipotle',
#    'one',
#    'substance',
#    'cowardice',
#    'well',
#    'hand',
#    'pickle',
#    'remains',
#    'bag',
#    'radiating',
#    'danger',
#    'called',
#    'amazon',
#    'good',
#    'time',
#    'explaining',
#    'series',
#    'unfortunate',
#    'event',
#    'customer',
#    'service',
#    'fellow',
#    'amused',
#    'kind',
#    'whole',
#    'thing',
#    'refunded',
#    'money',
#    'resolved',
#    'order',
#    'seller',
#    'sold',
#    'nilmee',
#    'either',
#    'know',
#    'selling',
#    'pickle',
#    'either',
#    'way',
#    'thank',
#    'check',
#    'review',
#    'van',
#    'holten',
#    'purchase',
#    'price',
#    'le',
#    'get',
#    'dozen',
#    'pickle',
#    'thing',
#    'around',
#    'much',
#    'reasonable',
#    'happy',
#    'transaction',
#    'anyway',
#    'thought',
#    'others',
#    'know',
#    'ordering',
#    'folk',
#    'might',
#    'worth',
#    'confirming',
#    'going',
#    'get',
#    'call',
#    'nilmee',
#    'order',
#    'pickle',
#    'come',
#    'van',
#    'holten',
#    'understanding',
#    'pickle',
#    'government',
#    'pickle',
#    'military',
#    'grade',
#    'foreign',
#    'distribution',
#    'without',
#    'extensive',
#    'export',
#    'paperwork',
#    'chemical',
#    'weapon',
#    'license',
#    'believe',
#    'also',
#    'come',
#    'custom',
#    'holster',
#    'self',
#    'destruct',
#    'device',
#    'case',
#    'fall',
#    'enemy',
#    'hand'],
#   'neg'),
#  (['cup',
#    'manufacturer',
#    'box',
#    'simply',
#    'packaged',
#    'loose',
#    'plain',
#    'box',
#    'upon',
#    'closer',
#    'inspection',
#    'cup',
#    'expired',
#    'may',
#    '2016'],
#   'neg'),
#  (['lot',
#    'bone',
#    'got',
#    'bone',
#    'stuck',
#    'tongue',
#    'really',
#    'hard',
#    'get',
#    'broke',
#    'tiny',
#    'piece',
#    'bone',
#    'stuck',
#    'tongue',
#    'day',
#    'could',
#    'get',
#    'home',
#    'use',
#    'tweezer',
#    'high',
#    'pain',
#    'tolerance',
#    'getting',
#    'last',
#    'piece',
#    'bone',
#    'come',
#    'tongue',
#    'made',
#    'eye',
#    'water',
#    'really',
#    'fishy',
#    'smell',
#    'taste'],
#   'neg'),
#  (['bought', 'box', 'expire', 'day', 'hard', 'eat', 'box', 'day'], 'neg'),
#  (['splurged',
#    'trying',
#    'starting',
#    'keto',
#    'diet',
#    'going',
#    'waste',
#    'fridge',
#    'unfortunately',
#    'find',
#    'thr',
#    'flavor',
#    'similar',
#    'ketchup',
#    'unsweet',
#    'ive',
#    'since',
#    'made',
#    'homemade',
#    'version',
#    'swerve',
#    'thats',
#    'much',
#    'like',
#    'real',
#    'thing'],
#   'neg'),
#  (['caution',
#    'product',
#    'jacked',
#    'longer',
#    'offered',
#    'amazon',
#    'good',
#    'product',
#    'bad',
#    'product',
#    'buy',
#    'come',
#    'back',
#    'amazon',
#    'control',
#    'bob'],
#   'neg'),
# ...
#    'patch',
#    'kid',
#    'one',
#    'greatest',
#    'invention',
#    'sour',
#    'exterior',
#    'sweet',
#    'interior',
#    'soft',
#    'chewy',
#    'delight',
#    'soon',
#    'enter',
#    'mouth',
#    'disappointed',
#    'biggest',
#    'bag',
#    'ever',
#    'seen',
#    'would',
#    'definitely',
#    'recommend',
#    'product'],
#   'pos'),
#  (['bought',
#    'small',
#    'bag',
#    'jelly',
#    'belly',
#    'sugar',
#    'free',
#    'candy',
#    'hour',
#    'eating',
#    'maybe',
#    'jelly',
#    'bean',
#    'stomach',
#    'began',
#    'rumble',
#    'became',
#    'uncomfortable',
#    'called',
#    'jelly',
#    'belly',
#    'offered',
#    'scan',
#    'email',
#    'receipt',
#    'refund',
#    'told',
#    'could',
#    'help',
#    'receipt',
#    'enough',
#    'refund',
#    'bag',
#    'disappointed',
#    'company',
#    'make',
#    'additional',
#    'purchase',
#    'jelly',
#    'belly',
#    'product'],
#   'neg'),
#  (['waste', 'good', 'drink'], 'neg'),
#  (['standard', 'good', 'value', 'use', 'frequently'], 'pos'),
#  (['really', 'care', 'taste'], 'neg'),
#  (['bad',
#    'stomach',
#    'finish',
#    'put',
#    'work',
#    'office',
#    'thing',
#    'get',
#    'used',
#    'really',
#    'quick',
#    'even',
#    'stopped',
#    'week',
#    'bad'],
#   'neg'),
#  (['yummy'], 'pos'),
#  (['regularly',
#    'use',
#    'french',
#    'vanilla',
#    'folgers',
#    'thought',
#    'would',
#    'give',
#    'cinnamon',
#    'try',
#    'love',
#    'cinnamon',
#    'strong',
#    'enough',
#    'taste',
#    'overpowering',
#    'coffee',
#    'smell',
#    'strong',
#    'french',
#    'vanilla',
#    'brewing',
#    'though',
#    'love',
#    'smell',
#    'permeating',
#    'house',
#    'morning',
#    'almost',
#    'taste',
#    'coffee'],
#   'pos'),
#  (['goji',
#    'berry',
#    'add',
#    'really',
#    'nice',
#    'flavor',
#    'morning',
#    'smoothy',
#    'flavor',
#    'lot',
#    'mineral',
#    'protein',
#    'etc'],
#   'pos'),
#  (['bought', 'tea', 'wife', 'absolutely', 'love', 'thank'], 'pos'),
#  (['total',
#    'joke',
#    'upset',
#    'took',
#    'chance',
#    'vingar',
#    'taste',
#    'taste',
#    'fake',
#    'shocked',
#    'poorly',
#    'taste',
#    'taste',
#    'artichoke',
#    'really',
#    'taste',
#    'vingar',
#    'really',
#    'shame',
#    'waste',
#    'money',
#    'tried',
#    'can',
#    'let',
#    'mom',
#    'finish',
#    'well',
#    'actually',
#    'made',
#    'take',
#    'home',
#    'tossed',
#    'even',
#    'buy',
#    'even',
#    'can',
#    'get',
#    'free',
#    'well',
#    'help',
#    'live',
#    'enjoy',
#    'taste'],
#   'neg'),
#  (['product',
#    'worth',
#    'various',
#    'step',
#    'prepare',
#    'compared',
#    'end',
#    'result',
#    'would',
#    'much',
#    'rather',
#    'use',
#    'mandolin',
#    'prepare',
#    'zucchini',
#    'noodle',
#    'much',
#    'tastier',
#    'low',
#    'calorie',
#    'high',
#    'nutrition',
#    'fewer',
#    'step',
#    'spaghetti',
#    'squash',
#    'also',
#    'good'],
#   'neg'),
#  (['wow',
#    'changed',
#    'recipe',
#    'original',
#    'one',
#    'grew',
#    'eating',
#    'create',
#    'new',
#    'flavor',
#    'call',
#    'zesty',
#    'onion',
#    'instead',
#    'ruining',
#    'everyone'],
#   'neg'),
#  (['product',
#    'match',
#    'ingredient',
#    'description',
#    'carrageenan',
#    'gum',
#    'please',
#    'advice'],
#   'neg'),
#  (['quality',
#    'cocoa',
#    'butter',
#    'excellent',
#    'using',
#    'soap',
#    'lotion',
#    'lip',
#    'balm',
#    'item',
#    'shipped',
#    'quickly'],
#   'pos'),
#  (['little', 'dry', 'taste', 'great'], 'pos'),
#  (['item',
#    'arrived',
#    'time',
#    'packaged',
#    'well',
#    'would',
#    'recommend',
#    'company',
#    'friend',
#    'use',
#    'product',
#    'time',
#    'continue',
#    'purchase',
#    'company'],
#   'pos'),
#  (['like',
#    'drinking',
#    'tea',
#    'filled',
#    'clump',
#    'random',
#    'thing',
#    'huge',
#    'tea',
#    'drinker',
#    'drink',
#    'kind',
#    'tea',
#    'get',
#    'gross',
#    'thing',
#    'mouth',
#    'even',
#    'say',
#    'tea',
#    'good',
#    'even',
#    'try',
#    'people',
#    'buy',
#    'tea',
#    'rip',
#    'open',
#    'package',
#    'dump',
#    'everything',
#    'drink',
#    'get',
#    'stuck',
#    'teeth',
#    'want',
#    'drink',
#    'tea',
#    'eat',
#    'tea'],
#   'neg'),
#  (['son',
#    'sick',
#    'even',
#    'though',
#    'sent',
#    'jellybeans',
#    'love',
#    'much',
#    'practical',
#    'fruit',
#    'say',
#    'usual',
#    'came',
#    'quickly',
#    'well',
#    'packaged'],
#   'pos'),
#  (['tried',
#    'coffe',
#    'safari',
#    'tanzania',
#    'one',
#    'best',
#    'coffee',
#    'ordered',
#    'using',
#    'since',
#    'convienent',
#    'mildness',
#    'organic',
#    'quality',
#    'make',
#    'day',
#    'drinker',
#    'like'],
#   'pos'),
#  (['ice',
#    'cream',
#    'good',
#    'sandwich',
#    'lot',
#    'emulsifier',
#    'egg',
#    'pretty',
#    'nasty',
#    'taste',
#    'like',
#    'chemical',
#    'buy'],
#   'neg'),
#  (['item',
#    'stored',
#    'wrong',
#    'came',
#    'white',
#    'chalky',
#    'kind',
#    'like',
#    'old',
#    'chocolate',
#    'happy',
#    'would',
#    'never',
#    'buy'],
#   'neg'),
#  (['everything', 'expected'], 'pos'),
#  (['love',
#    'price',
#    'great',
#    'get',
#    'big',
#    'bag',
#    'divide',
#    'among',
#    'grown',
#    'grandchild',
#    'learned',
#    'love'],
#   'pos'),
#  (['review',
#    'metallic',
#    'taste',
#    'true',
#    'yet',
#    'liked',
#    'anyways',
#    'long',
#    'cold',
#    'enough',
#    'problem',
#    'opening',
#    'cap',
#    'comprised',
#    'bottle',
#    'inside',
#    'box',
#    'likely',
#    'stacking',
#    'pallet',
#    'upon',
#    'pallet',
#    'weight',
#    'much',
#    'every',
#    'container',
#    'inside',
#    '12pk',
#    'box',
#    'ordered',
#    '12pk',
#    'box',
#    'amazon',
#    'unfortunately',
#    'notice',
#    'problem',
#    'figured',
#    'late',
#    'complain',
#    'month',
#    'later',
#    'complaint',
#    'product'],
#   'neg'),
#  (['something',
#    'wrong',
#    'oil',
#    'even',
#    'refrigerator',
#    'never',
#    'got',
#    'solid'],
#   'neg'),
#  (['fraud',
#    'received',
#    'one',
#    'ounce',
#    'bag',
#    'ounce',
#    'bag',
#    'advertised',
#    'calculates',
#    'per',
#    'lifesaver',
#    'since',
#    'amazon',
#    'usually',
#    'reliable',
#    'must',
#    'screw'],
#   'neg'),
#  (['always',
#    'amazed',
#    'much',
#    'bag',
#    'little',
#    'left',
#    'making',
#    'dashi',
#    'clean',
#    'non',
#    'chemical',
#    'smell',
#    'right',
#    'bag',
#    'plus',
#    'delicious',
#    'soup',
#    'base',
#    'complaint'],
#   'pos'),
#  (['perhaps',
#    'due',
#    'belgian',
#    'background',
#    'raised',
#    'neuhaus',
#    'quite',
#    'obvious',
#    'company',
#    'formed',
#    '2009',
#    'impressed',
#    'product',
#    'much',
#    'learn',
#    'artisan',
#    'chocolate',
#    'creation',
#    'color',
#    'chocolate',
#    'chalky',
#    'much',
#    'like',
#    'refrigerated',
#    'silky',
#    'smooth',
#    'appreciate',
#    'commitment',
#    'environment',
#    'chalky',
#    'crumbly',
#    'bar',
#    'total',
#    'letdown'],
#   'neg'),
#  (['think', 'sat', 'freezer', 'rock', 'hard', 'nasty'], 'neg'),
#  (['awful',
#    'last',
#    'time',
#    'order',
#    'place',
#    'muffin',
#    'turned',
#    'stale',
#    'hard',
#    'ordering',
#    'many',
#    'time'],
#   'neg'),
#  (['best',
#    'honey',
#    'ever',
#    'use',
#    'place',
#    'sugar',
#    'bought',
#    'used',
#    'sugar',
#    'household',
#    'least',
#    'year'],
#   'pos'),
#  (['taste', 'like', 'vinegar', 'threw', 'possible', 'refund', 'replacement'],
#   'neg'),
#  (['best',
#    'hot',
#    'chocolate',
#    'drink',
#    'love',
#    'white',
#    'chocolate',
#    'friend',
#    'gave',
#    'chocolate',
#    'white',
#    'chocolate',
#    'sample',
#    'omg',
#    'loved',
#    'white',
#    'chocolate',
#    'one',
#    'good',
#    'ordered',
#    'full',
#    'container',
#    'last',
#    'long',
#    'time',
#    'saw',
#    'someone',
#    'say',
#    'last',
#    'cup',
#    'something',
#    'last',
#    'much',
#    'even',
#    'using',
#    'generously',
#    'bought',
#    'people',
#    'love'],
#   'pos'),
#  (['mom', 'loved', 'selection', 'snack'], 'pos'),
#  (['never', 'ordered'], 'neg'),
#  (['excellent', 'product', 'excellent', 'order', 'shortly'], 'pos'),
#  (['salmon', 'smelled', 'tasted', 'bad', 'thrown', 'away'], 'neg'),
#  (['disappointed',
#    'always',
#    'gotten',
#    'mccafe',
#    'pod',
#    'reason',
#    'work',
#    'went',
#    'bought',
#    'new',
#    'keurig',
#    'thinking',
#    'pot',
#    'still',
#    'thing',
#    'cup',
#    'get',
#    'filled',
#    'coffee',
#    'ground',
#    'know',
#    'changed',
#    'pod',
#    'get',
#    'credit',
#    'last',
#    'case',
#    'bought',
#    'use',
#    'bought',
#    'another',
#    'work',
#    'either'],
#   'neg'),
#  (['like',
#    'regular',
#    'special',
#    'cereal',
#    'disappointed',
#    'find',
#    'taste',
#    'like',
#    'taste',
#    'like',
#    'cardboard',
#    'eat'],
#   'neg'),
#  (['mango',
#    'leaf',
#    'aah',
#    'omg',
#    'selling',
#    'leaf',
#    'money',
#    'also',
#    'happening'],
#   'neg'),
#  (['like',
#    'sharpness',
#    'expected',
#    'actually',
#    'threw',
#    'whole',
#    'bottle',
#    'tasting',
#    'sorry'],
#   'neg'),
#  (['came',
#    'piece',
#    'two',
#    'package',
#    'already',
#    'opened',
#    'thanks',
#    'crappy',
#    'way',
#    'treated',
#    'item',
#    'payed'],
#   'neg'),
#  (['cold',
#    'pack',
#    'stay',
#    'cold',
#    'candy',
#    'melted',
#    'many',
#    'others',
#    'broken'],
#   'neg'),
#  (['tea', 'delicious', 'give', 'right', 'kick', 'caffeine', 'get', 'day'],
#   'pos'),
#  (['order',
#    'product',
#    'sent',
#    'wrong',
#    'one',
#    'stopped',
#    'ordering',
#    'coffee',
#    'sight',
#    'ordered',
#    'tully',
#    'house',
#    'blend',
#    'extra',
#    'bold'],
#   'neg'),
#  (['little',
#    'disappointed',
#    'use',
#    'anything',
#    '4oz',
#    'water',
#    'taste',
#    'bit',
#    'watery',
#    'get',
#    'full',
#    'cup',
#    'cappuccino',
#    'use',
#    'cup',
#    'make',
#    'cost',
#    'buying',
#    'cup',
#    'convenience',
#    'store'],
#   'neg'),
#  (['delicious', 'product', 'reasonable', 'price'], 'pos'),
#  (['yes', 'hot', 'nice', 'flavor', 'smokey', 'aftertaste', 'taste', 'bud'],
#   'pos'),
#  (['love',
#    'bake',
#    'use',
#    'best',
#    'ingredient',
#    'find',
#    'fit',
#    'bill',
#    'perfect',
#    'size',
#    'bake',
#    'frequently',
#    'reasonable',
#    'price',
#    'almost',
#    'ready',
#    'new',
#    'bottle'],
#   'pos'),
#  (['great', 'product'], 'pos'),
#  (['use',
#    'everything',
#    'clean',
#    'around',
#    'house',
#    'wipe',
#    'traditional',
#    'use',
#    'handy',
#    'get',
#    'subscribe',
#    'save',
#    'every',
#    'month',
#    'necessary',
#    'save',
#    'price'],
#   'pos'),
#  (['quality', 'bialy'], 'neg'),
#  (['great', 'popcorn', 'tender', 'light', 'heavy', 'hull'], 'pos'),
#  (['second',
#    'year',
#    'ordering',
#    'fruitcake',
#    'wonderful',
#    'worth',
#    'every',
#    'penny',
#    'love',
#    'good',
#    'fruitcake',
#    'one',
#    'order'],
#   'pos'),
#  (['bought',
#    'super',
#    'grainy',
#    'matter',
#    'good',
#    'mixed',
#    'aftertaste',
#    'soap',
#    'nasty',
#    'company',
#    'product',
#    'worst',
#    'found',
#    'everything',
#    'tried',
#    'bad'],
#   'neg'),
#  (['plum',
#    'small',
#    'peal',
#    'hardly',
#    'anything',
#    'left',
#    'eat',
#    'disappointed',
#    'worth',
#    'price',
#    'sold',
#    'never',
#    'order'],
#   'neg'),
#  (['diabetes',
#    'childhood',
#    'dream',
#    'never',
#    'tasted',
#    'good',
#    'pot',
#    'gold',
#    'leprechaun',
#    'included'],
#   'pos'),
#  (['really',
#    'excited',
#    'flavor',
#    'unfortunately',
#    'quite',
#    'disappointing',
#    'pretty',
#    'much',
#    'taste',
#    'like',
#    'straight',
#    'water',
#    'light',
#    'coffee',
#    'coloring'],
#   'neg'),
#  (['bought',
#    'lighting',
#    'deal',
#    'hoping',
#    'get',
#    'jolt',
#    'energy',
#    'start',
#    'long',
#    'day',
#    'energy',
#    'wise',
#    'seem',
#    'moderate',
#    'effect',
#    'taste',
#    'horrific',
#    'wife',
#    'tried',
#    'mocha',
#    'caramel',
#    'far',
#    'reaction',
#    'yuk',
#    'harsh',
#    'chemical',
#    'taste',
#    'similar',
#    'bad',
#    'cough',
#    'syrup',
#    'love',
#    'coffee',
#    'espresso',
#    'etc',
#    'hard',
#    'time',
#    'finishing',
#    'box'],
#   'neg'),
#  (['want',
#    'great',
#    'tasting',
#    'hot',
#    'sauce',
#    'set',
#    'fire',
#    'need',
#    'try',
#    'one',
#    'quick',
#    'turn',
#    'around',
#    'bonus',
#    'coupon'],
#   'pos'),
#  (['box',
#    'piece',
#    'cracked',
#    'open',
#    'black',
#    'sootie',
#    'box',
#    'like',
#    'nancy'],
#   'neg'),
#  (['awful'], 'neg'),
#  (['bottle',
#    'arrived',
#    'leaking',
#    'molasses',
#    'inner',
#    'protective',
#    'seal',
#    'open',
#    'know',
#    'due',
#    'shipment',
#    'dissatisfied',
#    'hoping',
#    'get',
#    'refund',
#    'replacement'],
#   'neg'),
#  (['bought',
#    'vanilla',
#    'bean',
#    'first',
#    'time',
#    'delivered',
#    'son',
#    'brought',
#    'back',
#    'opened',
#    'expected',
#    'vanilla',
#    'fragrance',
#    'fill',
#    'room',
#    'read',
#    'review',
#    'bought',
#    'vanilla',
#    'extract',
#    'expected',
#    'least',
#    'familiar',
#    'fragrance',
#    'cut',
#    'open',
#    'shrink',
#    'wrap',
#    'still',
#    'single',
#    'fragrance',
#    'split',
#    'bean',
#    'still',
#    'smell',
#    'yes',
#    'even',
#    'smell',
#    'tasted',
#    'plastic',
#    'taste',
#    'smell',
#    'believe',
#    'must',
#    'shrink',
#    'wrap',
#    'singapore',
#    'packet',
#    'vanilla',
#    'bean',
#    'pod',
#    'vanilla',
#    'fragrance',
#    'discard',
#    'return',
#    'use',
#    'making',
#    'vanilla',
#    'extract',
#    'still',
#    'give',
#    'fragrance',
#    'still',
#    'give',
#    'robust',
#    'extract',
#    'know',
#    'waste',
#    'money',
#    'steep',
#    'vodka',
#    'even',
#    'fragrance',
#    'unlikely',
#    'get',
#    'vanilla',
#    'extra',
#    'please',
#    'let',
#    'know',
#    'packet',
#    'josephine'],
#   'neg'),
#  (['vivido', 'best', 'zatar', 'able', 'find', 'internet', 'taste', 'authenic'],
#   'pos'),
#  (['shipped', 'quickly', 'taste', 'amazing', 'loved'], 'pos'),
#  (['ingredient',
#    'per',
#    'container',
#    'organic',
#    'low',
#    'fat',
#    'milk',
#    'organic',
#    'cane',
#    'sugar',
#    'natural',
#    'strawberry',
#    'flavor',
#    'carrageenan',
#    'vitamin',
#    'palmitate',
#    'vitamin',
#    'comment',
#    'gram',
#    'sugar',
#    'tsp',
#    'sugar',
#    'sugar',
#    'tsp',
#    'sugar',
#    'milk',
#    'taste',
#    'would',
#    'call',
#    'healthy',
#    'mainly',
#    'due',
#    'carrageenan',
#    'abundance',
#    'sugar',
#    'absence',
#    'strawberry',
#    'carton',
#    'stuff',
#    'worth',
#    'buy'],
#   'neg'),
#  (['wilted', 'within', 'day'], 'neg'),
#  (['got',
#    'still',
#    'sealed',
#    'plastic',
#    'wrap',
#    'get',
#    'feedback',
#    'seems',
#    'worth',
#    'get',
#    'paid'],
#   'neg'),
#  (['sweet', 'seedless', 'hing', 'mui', 'good', 'bad', 'taste', 'remember'],
#   'neg'),
#  (['extremely',
#    'terrible',
#    'assume',
#    'people',
#    'water',
#    'put',
#    '8oz',
#    'water',
#    'per',
#    'packet',
#    'need',
#    'use',
#    'packet',
#    '16oz',
#    'cup',
#    'even',
#    'nail',
#    'ratio',
#    'taste',
#    'terrible',
#    'avoid'],
#   'neg'),
#  (['say',
#    'love',
#    'candy',
#    'came',
#    'melted',
#    'sticky',
#    'gross',
#    'intelligent',
#    'specific',
#    'review',
#    'rejected',
#    'dumbed',
#    'way',
#    'discourage',
#    'dear',
#    'reader',
#    'ordering',
#    'mess',
#    'great',
#    'candy',
#    'good'],
#   'neg'),
#  (['love'], 'pos'),
#  (['mine',
#    'came',
#    'damaged',
#    'sticky',
#    'outside',
#    'sure',
#    'dare',
#    'consume',
#    'individual',
#    'packet',
#    'intact',
#    'still',
#    'nervous'],
#   'neg'),
#  (['needed', 'stock', 'motorhome', 'perfect', 'size'], 'pos'),
#  (['emily',
#    'chocolate',
#    'item',
#    'wonderful',
#    'purchased',
#    'box',
#    'gift',
#    'separate',
#    'people',
#    'husband',
#    'buy',
#    'everyone',
#    'loved',
#    'fresh',
#    'dark',
#    'chocolate',
#    'wonderful'],
#   'pos'),
#  (['right', 'button', 'work'], 'neg'),
#  (['almond',
#    'pretty',
#    'gross',
#    'never',
#    'almond',
#    'dislike',
#    'think',
#    'twice',
#    'ordering',
#    'large',
#    'package',
#    'guess',
#    'supposed',
#    'raw',
#    'chewy',
#    'nut',
#    'supposed',
#    'crunch',
#    'even',
#    'raw',
#    'one'],
#   'neg'),
#  (['everyone',
#    'taste',
#    'indifferent',
#    'taste',
#    'good',
#    'cranked',
#    'water',
#    'heater',
#    'drew',
#    'water',
#    'tested',
#    'temp',
#    'followed',
#    'instruction',
#    'like',
#    'taste',
#    'got',
#    'right',
#    'texture',
#    'pan',
#    'frying',
#    'taste',
#    'awfully',
#    'bad',
#    'simply',
#    'potato',
#    'better'],
#   'neg'),
#  (['funny',
#    'flavor',
#    'vinegar',
#    'flavor',
#    'hoped',
#    'create',
#    'low',
#    'fat',
#    'alternative',
#    'salt',
#    'vinegar',
#    'chip'],
#   'neg'),
#  ...]

# %%
# Our list contains over 800,000 reviews
len(labeled_reviews)
# Out:
# 809226

# %%
labeled_reviews = positive[:1000] + negative[:1000]
random.shuffle(labeled_reviews)

# %%
labeled_reviews_joined = []
for i in labeled_reviews:
    labeled_reviews_joined.append((" ".join(i[0]), i[1]))

# %%
with open("2000Reviews.csv", 'w', newline='') as f:
    writer = csv.writer(f)

    for review in labeled_reviews_joined:
        writer.writerow(review)
