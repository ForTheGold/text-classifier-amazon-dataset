# %%
import pandas as pd

# %%
Grocery_json = pd.read_json('Resources/Grocery_and_Gourmet_Food.json',lines=True)

# %%
Grocery_json
# Out:
#          overall  verified   reviewTime      reviewerID        asin  \
# 0              5      True   06 4, 2013   ALP49FBWT4I7V  1888861614
# 1              4      True  05 23, 2014  A1KPIZOCLB9FZ8  1888861614
# 2              4      True   05 9, 2014  A2W0FA06IYAYQE  1888861614
# 3              5      True  04 20, 2014  A2PTZTCH2QUYBC  1888861614
# 4              4      True  04 16, 2014  A2VNHGJ59N4Z90  1888861614
# ...          ...       ...          ...             ...         ...
# 5074155        5      True   10 4, 2018   AGOPF2VTEOP57  B01HJHSVG6
# 5074156        3      True   10 3, 2018   A5X5TI4JCH9CN  B01HJHSVG6
# 5074157        4      True   10 2, 2018  A1WMQQLC3TVAFI  B01HJHSVG6
# 5074158        5      True  09 30, 2018   ALVP6JZRTEDY6  B01HJHSVG6
# 5074159        5      True  09 29, 2018   AZFPVUZOVGBYR  B01HJHSVG6
#
#                reviewerName  \
# 0                      Lori
# 1                BK Shopper
# 2            daninethequeen
# 3                   Tammara
# 4        LaQuinta Alexander
# ...                     ...
# 5074155                 Bob
# 5074156  Jacqueline Schafer
# 5074157        Motionjunkie
# 5074158             Marissa
# 5074159     Amazon Customer
#
#                                                 reviewText  \
# 0        Very pleased with my purchase. Looks exactly l...
# 1        Very nicely crafted but too small. Am going to...
# 2        still very pretty and well made...i am super p...
# 3        I got this for our wedding cake, and it was ev...
# 4        It was just what I want to put at the top of m...
# ...                                                    ...
# 5074155  Love this product, very fresh, complete full f...
# 5074156  Good taste but small quantity for the expensiv...
# 5074157  Unlike some of the bad reviews regarding aroma...
# 5074158  I absolutely love this vanilla bean paste. I h...
# 5074159                                      So delicious!
#
#                                                    summary  unixReviewTime  \
# 0                                                  Love it      1370304000
# 1                                           Nice but small      1400803200
# 2                             the "s" looks like a 5, kina      1399593600
# 3                        Would recommend this to a friend!      1397952000
# 4                                                   Topper      1397606400
# ...                                                    ...             ...
# 5074155                                  Exceclent product      1538611200
# 5074156  Good taste but small quantity for the price us...      1538524800
# 5074157                                 See Comments below      1538438400
# 5074158                                             Love!!      1538265600
# 5074159                                           Worth it      1538179200
#
#         vote image                  style
# 0        NaN   NaN                    NaN
# 1        NaN   NaN                    NaN
# 2        NaN   NaN                    NaN
# 3        NaN   NaN                    NaN
# 4        NaN   NaN                    NaN
# ...      ...   ...                    ...
# 5074155  NaN   NaN  {'Size:': ' 2.29 oz'}
# 5074156  NaN   NaN  {'Size:': ' 2.29 oz'}
# 5074157  NaN   NaN  {'Size:': ' 2.29 oz'}
# 5074158  NaN   NaN  {'Size:': ' 2.29 oz'}
# 5074159  NaN   NaN  {'Size:': ' 2.29 oz'}
#
# [5074160 rows x 12 columns]

# %%
Grocery_json.columns
# Out:
# Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'image', 'style'],
#       dtype='object')

# %%
#count the number of words in a review
#review_length = len()
#review_length

# %%
groceries_df = Grocery_json[['overall','reviewerID', 'reviewTime','unixReviewTime', 'reviewText']]
groceries_df
# Out:
#          overall      reviewerID   reviewTime  unixReviewTime  \
# 0              5   ALP49FBWT4I7V   06 4, 2013      1370304000
# 1              4  A1KPIZOCLB9FZ8  05 23, 2014      1400803200
# 2              4  A2W0FA06IYAYQE   05 9, 2014      1399593600
# 3              5  A2PTZTCH2QUYBC  04 20, 2014      1397952000
# 4              4  A2VNHGJ59N4Z90  04 16, 2014      1397606400
# ...          ...             ...          ...             ...
# 5074155        5   AGOPF2VTEOP57   10 4, 2018      1538611200
# 5074156        3   A5X5TI4JCH9CN   10 3, 2018      1538524800
# 5074157        4  A1WMQQLC3TVAFI   10 2, 2018      1538438400
# 5074158        5   ALVP6JZRTEDY6  09 30, 2018      1538265600
# 5074159        5   AZFPVUZOVGBYR  09 29, 2018      1538179200
#
#                                                 reviewText
# 0        Very pleased with my purchase. Looks exactly l...
# 1        Very nicely crafted but too small. Am going to...
# 2        still very pretty and well made...i am super p...
# 3        I got this for our wedding cake, and it was ev...
# 4        It was just what I want to put at the top of m...
# ...                                                    ...
# 5074155  Love this product, very fresh, complete full f...
# 5074156  Good taste but small quantity for the expensiv...
# 5074157  Unlike some of the bad reviews regarding aroma...
# 5074158  I absolutely love this vanilla bean paste. I h...
# 5074159                                      So delicious!
#
# [5074160 rows x 5 columns]

# %%
# add review_length to the df
#groceries_df = groceries_df

# %%
#drop dupicates
groceries_df = groceries_df.drop_duplicates()
groceries_df
# Out:
#          overall      reviewerID   reviewTime  unixReviewTime  \
# 0              5   ALP49FBWT4I7V   06 4, 2013      1370304000
# 1              4  A1KPIZOCLB9FZ8  05 23, 2014      1400803200
# 2              4  A2W0FA06IYAYQE   05 9, 2014      1399593600
# 3              5  A2PTZTCH2QUYBC  04 20, 2014      1397952000
# 4              4  A2VNHGJ59N4Z90  04 16, 2014      1397606400
# ...          ...             ...          ...             ...
# 5074155        5   AGOPF2VTEOP57   10 4, 2018      1538611200
# 5074156        3   A5X5TI4JCH9CN   10 3, 2018      1538524800
# 5074157        4  A1WMQQLC3TVAFI   10 2, 2018      1538438400
# 5074158        5   ALVP6JZRTEDY6  09 30, 2018      1538265600
# 5074159        5   AZFPVUZOVGBYR  09 29, 2018      1538179200
#
#                                                 reviewText
# 0        Very pleased with my purchase. Looks exactly l...
# 1        Very nicely crafted but too small. Am going to...
# 2        still very pretty and well made...i am super p...
# 3        I got this for our wedding cake, and it was ev...
# 4        It was just what I want to put at the top of m...
# ...                                                    ...
# 5074155  Love this product, very fresh, complete full f...
# 5074156  Good taste but small quantity for the expensiv...
# 5074157  Unlike some of the bad reviews regarding aroma...
# 5074158  I absolutely love this vanilla bean paste. I h...
# 5074159                                      So delicious!
#
# [4679033 rows x 5 columns]

# %%
rating_5 = groceries_df.loc[groceries_df['overall'] == 5]
rating_5
# Out:
#          overall      reviewerID   reviewTime  unixReviewTime  \
# 0              5   ALP49FBWT4I7V   06 4, 2013      1370304000
# 3              5  A2PTZTCH2QUYBC  04 20, 2014      1397952000
# 6              5   A94ZG5CWN70E7   12 1, 2013      1385856000
# 8              5   AGKW3A1RB1YGO   10 2, 2013      1380672000
# 9              5  A1B65IWLUVOUQB   09 6, 2013      1378425600
# ...          ...             ...          ...             ...
# 5074153        5  A1VL40O7D88AY0   10 4, 2018      1538611200
# 5074154        5  A1LBAF0CNISB04   10 4, 2018      1538611200
# 5074155        5   AGOPF2VTEOP57   10 4, 2018      1538611200
# 5074158        5   ALVP6JZRTEDY6  09 30, 2018      1538265600
# 5074159        5   AZFPVUZOVGBYR  09 29, 2018      1538179200
#
#                                                 reviewText
# 0        Very pleased with my purchase. Looks exactly l...
# 3        I got this for our wedding cake, and it was ev...
# 6        Omg.. The S was inexpensive and EXACTLY what w...
# 8        Perfect!!! Can not wait to use on my Wedding c...
# 9        This was exactly what we were looking for to m...
# ...                                                    ...
# 5074153  Love this Vanilla.  Blends and bakes beautifully.
# 5074154  You'll never go back to plain ol' Vanilla Extr...
# 5074155  Love this product, very fresh, complete full f...
# 5074158  I absolutely love this vanilla bean paste. I h...
# 5074159                                      So delicious!
#
# [3275366 rows x 5 columns]

# %%
rating_1 = groceries_df.loc[groceries_df['overall'] == 1]
rating_1
# Out:
#          overall      reviewerID   reviewTime  unixReviewTime  \
# 5              1   ATQL0XOLZNHZ4  02 21, 2014      1392940800
# 22             1   AE937MVR5J8OL  12 10, 2016      1481328000
# 27             1  A27LF8222OIRRN  09 10, 2016      1473465600
# 37             1  A34RH95REHOQFO  09 25, 2015      1443139200
# 69             1  A3ELDSSPP9RZPG  03 31, 2017      1490918400
# ...          ...             ...          ...             ...
# 5074102        1  A2CSMC3CQE2SPP  07 28, 2018      1532736000
# 5074110        1  A1ZO0PE7RT0IKK  05 19, 2017      1495152000
# 5074111        1  A1T8D0SC1P04CZ   09 8, 2018      1536364800
# 5074112        1  A3TG44X2A5WTP5  08 27, 2018      1535328000
# 5074120        1  A33SA5P6IOEATJ  10 10, 2016      1476057600
#
#                                                 reviewText
# 5        The S is beautiful, however upon checkout it i...
# 22                     Tasted old and not individually bag
# 27       Not the great taste everyone was talking about :(
# 37       Terrible. What a waste of money. This is not t...
# 69       The tea is so fine it leaves tea particles flo...
# ...                                                    ...
# 5074102  I wish I loved this, but the truth is, it tast...
# 5074110  Followed instructions on the package to prepar...
# 5074111       For my grandson. Arrived broken into crumbs.
# 5074112  These are delicious cookies - just don't order...
# 5074120  Can't say he product is good as is practically...
#
# [382925 rows x 5 columns]

# %%
rating_2 = groceries_df.loc[groceries_df['overall'] == 2]
rating_2
# Out:
#          overall      reviewerID   reviewTime  unixReviewTime  \
# 46             2  A1EDAUU1B7YGTD   05 7, 2015      1430956800
# 55             2  A36N7FI7QREIH7  01 10, 2015      1420848000
# 77             2    AA3RFH4XSLRF  01 28, 2017      1485561600
# 100            2   A3T7ACW6DIECL   09 8, 2015      1441670400
# 166            2  A38YPICAU2VDU8  09 10, 2016      1473465600
# ...          ...             ...          ...             ...
# 5074029        2  A38ME72ZVZ3UQD  09 15, 2016      1473897600
# 5074084        2  A1CHF9VHRDTTO5  09 10, 2018      1536537600
# 5074115        2   AHDO6UIU1Y68O  10 12, 2017      1507766400
# 5074116        2  A2RZH38UWWX059  09 25, 2017      1506297600
# 5074142        2   AWG7PU0OYQTHE  06 21, 2017      1498003200
#
#                                                 reviewText
# 46       Mediocre taste and not like the yellow label f...
# 55       Lipton Yellow is normally great premium tea, b...
# 77       Good for Lipton fans maybe, but not so good fo...
# 100                                    Just not that good.
# 166      i love reishi coffee...but I prefer no sugar. ...
# ...                                                    ...
# 5074029   Didn't care for the pork, the rest were just OK.
# 5074084  I received this candy today,  it arrived in pr...
# 5074115                     Cookies came broken in pieces.
# 5074116  These were smashed to bits upon delivery. For ...
# 5074142  Honestly not my favorite product from this com...
#
# [207046 rows x 5 columns]

# %%
rating_3 = groceries_df.loc[groceries_df['overall'] == 3]
rating_3
# Out:
#          overall      reviewerID   reviewTime  unixReviewTime  \
# 7              3  A3QBT8YC3CZ7C9   11 6, 2013      1383696000
# 40             3  A165AME4SLYDWD  08 23, 2015      1440288000
# 60             3  A29LPNLNZ7E2XI  11 23, 2014      1416700800
# 67             3  A1YA5QHMETOVC8  05 21, 2009      1242864000
# 68             3   ACOICLIJQYECU  04 11, 2008      1207872000
# ...          ...             ...          ...             ...
# 5074089        3  A2OWJLIXWRH7SI   02 1, 2018      1517443200
# 5074134        3  A143ZDYT3UZSJR   08 1, 2018      1533081600
# 5074144        3  A1P0X9E6F99J4T  05 20, 2017      1495238400
# 5074149        3  A3NY9RMNIODSDW  09 12, 2016      1473638400
# 5074156        3   A5X5TI4JCH9CN   10 3, 2018      1538524800
#
#                                                 reviewText
# 7        It was a nice size for a cake topper and it wa...
# 40       Same product and name as the tea I've bought a...
# 60       Normally this tea rates 5 stars, it has a wond...
# 67       I have been a Lipton loose tea junkie for 50 y...
# 68       I have recently started drinking hot tea again...
# ...                                                    ...
# 5074089  I'm a spice fiend, but I can't say this add al...
# 5074134  I expected more truffle flavor, especially for...
# 5074144  Needs improvement to make it taste like real r...
# 5074149  Expensive and could have bought at local store...
# 5074156  Good taste but small quantity for the expensiv...
#
# [302012 rows x 5 columns]

# %%
rating_4 = groceries_df.loc[groceries_df['overall'] == 4]
rating_4
# Out:
#          overall      reviewerID   reviewTime  unixReviewTime  \
# 1              4  A1KPIZOCLB9FZ8  05 23, 2014      1400803200
# 2              4  A2W0FA06IYAYQE   05 9, 2014      1399593600
# 4              4  A2VNHGJ59N4Z90  04 16, 2014      1397606400
# 17             4  A21ZU2TINEQE0H   02 8, 2014      1391817600
# 38             4  A19TFNGQV7GPSX  09 21, 2015      1442793600
# ...          ...             ...          ...             ...
# 5074133        4  A2CC652MJ0FX7E  07 27, 2016      1469577600
# 5074135        4   AO0QVVFS0P2GU  08 15, 2017      1502755200
# 5074146        4  A1AZD3IIOFDLPC  03 12, 2018      1520812800
# 5074151        4  A1EET7MJO4KKX2   10 7, 2018      1538870400
# 5074157        4  A1WMQQLC3TVAFI   10 2, 2018      1538438400
#
#                                                 reviewText
# 1        Very nicely crafted but too small. Am going to...
# 2        still very pretty and well made...i am super p...
# 4        It was just what I want to put at the top of m...
# 17       Tried this while overseas last year; don't rem...
# 38       Just so everyone knows, this IS the orange pek...
# ...                                                    ...
# 5074133  This item arrived a little faster than the ori...
# 5074135                               OK and without eggs.
# 5074146  Very tasty. The individual packaging creates a...
# 5074151  This is only the 2nd kind of vanilla paste I h...
# 5074157  Unlike some of the bad reviews regarding aroma...
#
# [511684 rows x 5 columns]

# %%
groceries_df_12_45 = groceries_df[groceries_df.overall != 3]
groceries_df_12_45
# Out:
#          overall      reviewerID   reviewTime  unixReviewTime  \
# 0              5   ALP49FBWT4I7V   06 4, 2013      1370304000
# 1              4  A1KPIZOCLB9FZ8  05 23, 2014      1400803200
# 2              4  A2W0FA06IYAYQE   05 9, 2014      1399593600
# 3              5  A2PTZTCH2QUYBC  04 20, 2014      1397952000
# 4              4  A2VNHGJ59N4Z90  04 16, 2014      1397606400
# ...          ...             ...          ...             ...
# 5074154        5  A1LBAF0CNISB04   10 4, 2018      1538611200
# 5074155        5   AGOPF2VTEOP57   10 4, 2018      1538611200
# 5074157        4  A1WMQQLC3TVAFI   10 2, 2018      1538438400
# 5074158        5   ALVP6JZRTEDY6  09 30, 2018      1538265600
# 5074159        5   AZFPVUZOVGBYR  09 29, 2018      1538179200
#
#                                                 reviewText
# 0        Very pleased with my purchase. Looks exactly l...
# 1        Very nicely crafted but too small. Am going to...
# 2        still very pretty and well made...i am super p...
# 3        I got this for our wedding cake, and it was ev...
# 4        It was just what I want to put at the top of m...
# ...                                                    ...
# 5074154  You'll never go back to plain ol' Vanilla Extr...
# 5074155  Love this product, very fresh, complete full f...
# 5074157  Unlike some of the bad reviews regarding aroma...
# 5074158  I absolutely love this vanilla bean paste. I h...
# 5074159                                      So delicious!
#
# [4377021 rows x 5 columns]

# %%
#choosing every second row of the five star rating for a total of 600,000 to reduce its size from around 3.5 million ratings to a number closer to the 1 star ratings. 
rating_5_trimmed = rating_5[:1200000:2]
rating_5_trimmed
# Out:
#          overall      reviewerID   reviewTime  unixReviewTime  \
# 0              5   ALP49FBWT4I7V   06 4, 2013      1370304000
# 6              5   A94ZG5CWN70E7   12 1, 2013      1385856000
# 9              5  A1B65IWLUVOUQB   09 6, 2013      1378425600
# 11             5  A1QVBUH9E1V6I8  11 19, 2014      1416355200
# 13             5  A2CHH5U12THP2D   11 3, 2014      1414972800
# ...          ...             ...          ...             ...
# 1887403        5  A2U6LHY7C8NX2O  10 27, 2014      1414368000
# 1887405        5  A1CY3RZDF9J1QE  10 17, 2014      1413504000
# 1887407        5  A2DUF3NYSYKIZI   10 9, 2014      1412812800
# 1887410        5  A2MPRJJLG5J94L  09 23, 2014      1411430400
# 1887413        5  A3R3T7V9ZU2L7E   09 5, 2014      1409875200
#
#                                                 reviewText
# 0        Very pleased with my purchase. Looks exactly l...
# 6        Omg.. The S was inexpensive and EXACTLY what w...
# 9        This was exactly what we were looking for to m...
# 11                                     No adverse comment.
# 13       Best black tea in US.\n\nHighly recommend.\nI ...
# ...                                                    ...
# 1887403                                              GREAT
# 1887405               They don't taste healthy! Love these
# 1887407       The best on the market and the lowest carbs!
# 1887410  If you are living in the low-carb world you ne...
# 1887413    These things taste identical to real tortillas!
#
# [600000 rows x 5 columns]

# %%
groceries_df_1_5 = [rating_5_trimmed, rating_1]
groceries_df_1_5
groc_1_5 = pd.concat(groceries_df_1_5)
groc_1_5
# Out:
#          overall      reviewerID   reviewTime  unixReviewTime  \
# 0              5   ALP49FBWT4I7V   06 4, 2013      1370304000
# 6              5   A94ZG5CWN70E7   12 1, 2013      1385856000
# 9              5  A1B65IWLUVOUQB   09 6, 2013      1378425600
# 11             5  A1QVBUH9E1V6I8  11 19, 2014      1416355200
# 13             5  A2CHH5U12THP2D   11 3, 2014      1414972800
# ...          ...             ...          ...             ...
# 5074102        1  A2CSMC3CQE2SPP  07 28, 2018      1532736000
# 5074110        1  A1ZO0PE7RT0IKK  05 19, 2017      1495152000
# 5074111        1  A1T8D0SC1P04CZ   09 8, 2018      1536364800
# 5074112        1  A3TG44X2A5WTP5  08 27, 2018      1535328000
# 5074120        1  A33SA5P6IOEATJ  10 10, 2016      1476057600
#
#                                                 reviewText
# 0        Very pleased with my purchase. Looks exactly l...
# 6        Omg.. The S was inexpensive and EXACTLY what w...
# 9        This was exactly what we were looking for to m...
# 11                                     No adverse comment.
# 13       Best black tea in US.\n\nHighly recommend.\nI ...
# ...                                                    ...
# 5074102  I wish I loved this, but the truth is, it tast...
# 5074110  Followed instructions on the package to prepar...
# 5074111       For my grandson. Arrived broken into crumbs.
# 5074112  These are delicious cookies - just don't order...
# 5074120  Can't say he product is good as is practically...
#
# [982925 rows x 5 columns]

# %%
g1_5 = pd.merge(rating_5_trimmed, rating_1, how='outer')
g1_5
# Out:
#         overall      reviewerID   reviewTime  unixReviewTime  \
# 0             5   ALP49FBWT4I7V   06 4, 2013      1370304000
# 1             5   A94ZG5CWN70E7   12 1, 2013      1385856000
# 2             5  A1B65IWLUVOUQB   09 6, 2013      1378425600
# 3             5  A1QVBUH9E1V6I8  11 19, 2014      1416355200
# 4             5  A2CHH5U12THP2D   11 3, 2014      1414972800
# ...         ...             ...          ...             ...
# 982920        1  A2CSMC3CQE2SPP  07 28, 2018      1532736000
# 982921        1  A1ZO0PE7RT0IKK  05 19, 2017      1495152000
# 982922        1  A1T8D0SC1P04CZ   09 8, 2018      1536364800
# 982923        1  A3TG44X2A5WTP5  08 27, 2018      1535328000
# 982924        1  A33SA5P6IOEATJ  10 10, 2016      1476057600
#
#                                                reviewText
# 0       Very pleased with my purchase. Looks exactly l...
# 1       Omg.. The S was inexpensive and EXACTLY what w...
# 2       This was exactly what we were looking for to m...
# 3                                     No adverse comment.
# 4       Best black tea in US.\n\nHighly recommend.\nI ...
# ...                                                   ...
# 982920  I wish I loved this, but the truth is, it tast...
# 982921  Followed instructions on the package to prepar...
# 982922       For my grandson. Arrived broken into crumbs.
# 982923  These are delicious cookies - just don't order...
# 982924  Can't say he product is good as is practically...
#
# [982925 rows x 5 columns]

# %%
groceries_csv = g1_5.to_csv(path_or_buf='groceries_trimmed.csv', index=False)
