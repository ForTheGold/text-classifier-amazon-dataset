# %%
import csv
import random
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

# %%
data = []
with open('groceries_trimmed.csv') as f:
    reader = csv.reader(f, delimiter=',')
    for i in reader:
        data.append(i)

data = data[1:]

# %%
tokenizer = RegexpTokenizer(r'\w+')
stop_words = set(stopwords.words('english'))

# %%
positive = []
negative = []

for i in data:
    if i[0] == '5':
        tokens = tokenizer.tokenize(i[1].lower())
        filtered = [token for token in tokens if token not in stop_words]

        if len(filtered) > 0:
            positive.append((filtered, 'pos'))
    else:
        tokens = tokenizer.tokenize(i[1].lower())
        filtered = [token for token in tokens if token not in stop_words]
        if len(filtered) > 0:
            negative.append((filtered, 'neg'))

# %%
random.shuffle(positive)
labeled_reviews = positive[:len(negative)] + negative
random.shuffle(labeled_reviews)

# %%
labeled_reviews
# Out:
# [(['yes',
#    'ordered',
#    '5',
#    'boxes',
#    '24ct',
#    'pecan',
#    'turtles',
#    'shipped',
#    '10',
#    'boxes',
#    'pecan',
#    'cashew',
#    'turtles',
#    'e',
#    'mailed',
#    'back',
#    'asking',
#    'substituted',
#    'without',
#    'approval',
#    'response',
#    'website',
#    'clearly',
#    'stated',
#    'turtles',
#    'combination',
#    'pecan',
#    'cashew',
#    'turtles',
#    'needless',
#    'say',
#    'happy',
#    'future',
#    'orders',
#    'go',
#    'someone',
#    'else',
#    'john'],
#   'neg'),
#  (['disappointed',
#    'product',
#    'discontinued',
#    'least',
#    'continuous',
#    'delivery',
#    'quantity',
#    'hope',
#    'case',
#    'decaf',
#    'actually',
#    'use'],
#   'pos'),
#  (['texas',
#    'pepper',
#    'works',
#    'queso',
#    'blanco',
#    'white',
#    'cheese',
#    'dip',
#    'waste',
#    'money',
#    'tasted',
#    'like',
#    'jelly',
#    'gel',
#    'water',
#    'nothing',
#    'even',
#    'close',
#    'taste',
#    'cheese',
#    'aweful'],
#   'neg'),
#  (['purchased', 'gift', 'loved'], 'pos'),
#  (['came',
#    'advertised',
#    'always',
#    'enjoyed',
#    'quick',
#    'snack',
#    'road',
#    'recommend',
#    'anyone',
#    'likes',
#    'oatmeal',
#    'products',
#    'quaker'],
#   'pos'),
#  (['delicious',
#    'pull',
#    'peel',
#    'twizzlers',
#    'take',
#    'back',
#    'simpler',
#    'times'],
#   'pos'),
#  (['could',
#    'barely',
#    'taste',
#    'brewed',
#    'different',
#    'ways',
#    'luck',
#    'sticking',
#    'local',
#    'beans',
#    'guess'],
#   'neg'),
#  (['favorite'], 'pos'),
#  (['received', 'totally', 'melted', 'disgusting'], 'neg'),
#  (['best',
#    'gluten',
#    'free',
#    'pasta',
#    'brand',
#    'ever',
#    'tried',
#    'texture',
#    'like',
#    'regular',
#    'pasta',
#    'overcook',
#    'cook',
#    '10',
#    'minutes',
#    'tends',
#    'get',
#    'dry',
#    'texture',
#    'stored',
#    'fridge',
#    'add',
#    'sauce',
#    'microwave',
#    'gets',
#    'nice',
#    'soft',
#    'cold',
#    'salads',
#    'make',
#    'tuna',
#    'pasta',
#    'salad',
#    'try',
#    'make',
#    'enough',
#    'dryness',
#    'factor'],
#   'pos'),
#  (['like', 'taste', 'like', 'rubber'], 'neg'),
#  (['nice', 'dark', 'rich', 'blend', 'coffee'], 'pos'),
#  (['bag',
#    'came',
#    'first',
#    'thing',
#    'noticed',
#    'oils',
#    'every',
#    'bean',
#    'covered',
#    'oil',
#    'oily',
#    'beans',
#    'either',
#    'roasted',
#    'ruins',
#    'flavor',
#    'old',
#    'hell',
#    'either',
#    'way',
#    'put',
#    'machine'],
#   'neg'),
#  (['kind',
#    'expensive',
#    'otherwise',
#    'olive',
#    'oil',
#    'great',
#    'next',
#    'time',
#    'buy',
#    'walmart'],
#   'pos'),
#  (['mccormick', 'best'], 'pos'),
#  (['husband',
#    'loves',
#    'syrup',
#    'uses',
#    'make',
#    'peach',
#    'iced',
#    'tea',
#    'starts',
#    'unsweet',
#    'fresh',
#    'brewed',
#    'tea',
#    'adds',
#    '1',
#    'tablespoon',
#    'per',
#    '16oz',
#    'cup',
#    'still',
#    'sugar',
#    'bought',
#    'type',
#    'soda',
#    'year',
#    'worth',
#    'buy',
#    'syrup',
#    'price',
#    '4',
#    'pack',
#    'wonderful'],
#   'pos'),
#  (['totally', 'recommend'], 'pos'),
#  (['married',
#    'beach',
#    'sandy',
#    'area',
#    'wedding',
#    'topper',
#    'perfect',
#    'item',
#    'cake',
#    'bring',
#    'admiration',
#    'guests',
#    'neat'],
#   'pos'),
#  (['tastes',
#    'like',
#    'poison',
#    'works',
#    'spray',
#    'like',
#    '6',
#    'times',
#    'tongue',
#    'hold',
#    'makes',
#    'grown',
#    'men',
#    'cry',
#    'throw',
#    'worst',
#    'manage',
#    'yes',
#    'make',
#    'hyper',
#    'explode',
#    'heart'],
#   'neg'),
#  (['unfortunately',
#    'probably',
#    'one',
#    'worst',
#    'gf',
#    'bread',
#    'yet',
#    'bought',
#    'frozen',
#    'local',
#    'market',
#    'thawed',
#    'slice',
#    'bread',
#    'fell',
#    'apart',
#    'top',
#    'bread',
#    'crust',
#    'hard',
#    'dry',
#    'taste',
#    'okay',
#    'quality',
#    'slice',
#    'negated',
#    'fact',
#    'never',
#    'brand'],
#   'neg'),
#  (['6', 'crazy'], 'neg'),
#  (['love', 'oatmeal', 'continue', 'buy'], 'pos'),
#  (['makes', 'season', 'fun', 'thank'], 'pos'),
#  (['love',
#    'flavor',
#    'oatmeal',
#    'fairly',
#    'healthy',
#    'filling',
#    'would',
#    'recommend',
#    'great',
#    'flavor',
#    'sweet'],
#   'pos'),
#  (['even',
#    '1',
#    'star',
#    'given',
#    'since',
#    '29',
#    'pretzels',
#    'arrived',
#    'whole',
#    'others',
#    'broken',
#    'degree',
#    'ridiculous',
#    'deserve',
#    'money',
#    'back'],
#   'neg'),
#  (['poor',
#    'quality',
#    'taste',
#    'old',
#    'cannot',
#    'return',
#    'overall',
#    'disappointing'],
#   'neg'),
#  (['ordered',
#    'trying',
#    'different',
#    'brands',
#    'local',
#    'stores',
#    'assumed',
#    'kohinoor',
#    'would',
#    'good',
#    'toor',
#    'daal',
#    'especioaly',
#    'since',
#    'always',
#    'liked',
#    'spices',
#    'basmati',
#    'rice',
#    'past',
#    'disappointed',
#    'though',
#    'quality',
#    'toor',
#    'daal',
#    'first',
#    'little',
#    'expensive',
#    'compared',
#    'toor',
#    'daal',
#    'local',
#    'indian',
#    'stores',
#    'secondly',
#    'daal',
#    'boil',
#    'easily',
#    'mediocre',
#    'taste'],
#   'neg'),
#  (['well',
#    'amazon',
#    'said',
#    'want',
#    'tomorrow',
#    '2',
#    'hrs',
#    'ever',
#    'minutes',
#    'friday',
#    'today',
#    'tuesday',
#    'still',
#    'great',
#    'shipping',
#    'things',
#    'takes',
#    'forever'],
#   'neg'),
#  (['bought',
#    'use',
#    'dutch',
#    'bros',
#    'iced',
#    'white',
#    'annihilator',
#    'plus',
#    'white',
#    'chocolate',
#    'steamed',
#    'half',
#    'half',
#    'good',
#    'sweet',
#    'tasting',
#    'combo'],
#   'pos'),
#  (['tea',
#    'expected',
#    'bitter',
#    'easy',
#    'mix',
#    'taste',
#    'tried',
#    'canned',
#    'matcha',
#    'much',
#    'better'],
#   'neg'),
#  (['cheaply', 'made', 'kcups', 'tops', 'completely', 'sealed'], 'neg'),
#  (['k',
#    'cups',
#    'work',
#    'mr',
#    'coffee',
#    'k',
#    'cup',
#    'brewer',
#    'even',
#    'open',
#    'pods',
#    'pour',
#    'grounds',
#    'eco',
#    'brew',
#    'filter',
#    'grind',
#    'fine',
#    'water',
#    'penetrate',
#    'enough',
#    'brew',
#    '3',
#    '4',
#    'ounces',
#    'making',
#    'run',
#    'brewer',
#    'twice',
#    'get',
#    'decent',
#    'cup',
#    'coffee',
#    'company',
#    'response',
#    'complained',
#    'k',
#    'cups',
#    'email',
#    'apology',
#    'statement',
#    'checking',
#    'problem',
#    'requesting',
#    'info',
#    'batch',
#    'number',
#    'size',
#    'purchased',
#    'name',
#    'address',
#    'etc',
#    'nothing',
#    'two',
#    'weeks',
#    'buying'],
#   'neg'),
#  (['delish'], 'pos'),
#  (['love', 'stuff'], 'pos'),
#  (['beautifully',
#    'packaged',
#    'good',
#    'tasting',
#    'shipping',
#    '5',
#    '00',
#    'per',
#    'cookie',
#    'cookie',
#    'little',
#    'wider',
#    'quarter'],
#   'neg'),
#  (['chocolate', 'bars', 'good', 'wait', 'try', 'different', 'flavors'], 'pos'),
#  (['wonderfully', 'delicious', 'calming', 'warming', 'could', 'go', 'taste'],
#   'pos'),
#  (['grandson', 'gobbles'], 'pos'),
#  (['careful',
#    'ordering',
#    'product',
#    'ordered',
#    'product',
#    'husband',
#    'showed',
#    'red',
#    'bag',
#    'older',
#    'kind',
#    'new',
#    'black',
#    'bag',
#    'current',
#    'kind',
#    'received',
#    'order',
#    'black',
#    'bag',
#    'wil',
#    'order'],
#   'neg'),
#  (['large',
#    'round',
#    'paper',
#    'appently',
#    'edible',
#    'fit',
#    'cupcake',
#    'image',
#    'sharp',
#    'productt',
#    'descrition',
#    'clear',
#    'flat',
#    'thought',
#    'small',
#    'edible',
#    'boston',
#    'terrier',
#    'topping',
#    'cupcake'],
#   'neg'),
#  (['many',
#    'great',
#    'reviews',
#    'salami',
#    'received',
#    'noticed',
#    'couple',
#    'extremely',
#    'dissatisfied',
#    'sample',
#    'received',
#    'guess',
#    'must',
#    'gotten',
#    'batch',
#    'salami',
#    'received',
#    'inedible',
#    'hard',
#    'virtually',
#    'impossible',
#    'cut',
#    'kitchen',
#    'knife',
#    'manage',
#    'hack',
#    'piece',
#    'flavor',
#    'awful'],
#   'neg'),
#  (['arrived',
#    'broken',
#    'cut',
#    'glass',
#    'chards',
#    'wash',
#    'glass',
#    'containers'],
#   'neg'),
#  (['aside',
#    'receiving',
#    'blend',
#    'brew',
#    'instead',
#    '3',
#    '1',
#    'horrible',
#    'tasting',
#    'recommend',
#    'anyone',
#    'awful',
#    'taste',
#    'might',
#    'due',
#    'product',
#    'thailand',
#    'might',
#    'cater',
#    'consumer',
#    'puerto',
#    'rico',
#    'knowing',
#    'bit',
#    'good',
#    'tasting',
#    'coffee',
#    'called',
#    'coffee',
#    'tastes',
#    'like',
#    'pencil',
#    'sharpenings',
#    'soil',
#    'sugarl'],
#   'neg'),
#  (['wanted',
#    'like',
#    'good',
#    'bought',
#    'kiddos',
#    'eat',
#    'either',
#    'disappointed'],
#   'neg'),
#  (['bigelow',
#    'tea',
#    'imports',
#    'tea',
#    'china',
#    'beware',
#    'lies',
#    'lurk',
#    'behind',
#    'certified',
#    'organic',
#    'healthy',
#    'tea',
#    'grown',
#    'polluted',
#    'wasteland'],
#   'neg'),
#  (['love',
#    'aloe',
#    'drinks',
#    'someone',
#    'touchy',
#    'stomach',
#    'history',
#    'ulcers',
#    'happy',
#    'tasty',
#    'beverage',
#    'soothes',
#    'stomach',
#    'every',
#    'time',
#    'sweet',
#    'mean',
#    'taste',
#    'fruity',
#    'slightly',
#    'sweet',
#    'like',
#    'beverage',
#    'hate',
#    'overwhelmingly',
#    'sweet',
#    'drinks',
#    'full',
#    'sugar',
#    'sugar',
#    'substitute',
#    'first',
#    'sips',
#    'little',
#    'startled',
#    'small',
#    'bits',
#    'aloe',
#    'gel',
#    'bottle',
#    'grown',
#    'really',
#    'fond',
#    'aloe',
#    'bits',
#    'adds',
#    'extra',
#    'element',
#    'enjoyment',
#    'become',
#    'go',
#    'drink',
#    'fridge'],
#   'pos'),
#  (['fresh', 'crunchy'], 'pos'),
#  (['expired', 'received'], 'neg'),
#  (['received',
#    'gum',
#    'old',
#    'stale',
#    'even',
#    'chew',
#    'thus',
#    'throw',
#    'away',
#    'disappointed'],
#   'neg'),
#  (['great',
#    'healthy',
#    'snack',
#    'one',
#    'believe',
#    'much',
#    'protein',
#    'contain'],
#   'pos'),
#  (['really',
#    'hoping',
#    'like',
#    'protein',
#    'powder',
#    'low',
#    'calories',
#    'high',
#    'protein',
#    'awful',
#    'nasty',
#    'chalky',
#    'taste',
#    'even',
#    'make',
#    'shake',
#    'use',
#    'protein',
#    'powder',
#    'taste',
#    'disappointing',
#    'looking',
#    'forward',
#    'trying',
#    'eas',
#    'lean',
#    '15',
#    'protein',
#    'powder',
#    'though'],
#   'neg'),
#  (['waited',
#    'long',
#    'ask',
#    'refund',
#    'pot',
#    'sink',
#    'used',
#    'like',
#    'vanilla',
#    'ever',
#    'taste',
#    'really',
#    'bad',
#    'also',
#    'sister',
#    'check',
#    'said',
#    'thing'],
#   'neg'),
#  (['never',
#    'big',
#    'fan',
#    'kind',
#    'cold',
#    'cereal',
#    'bought',
#    'cereal',
#    'need',
#    'quick',
#    'easy',
#    'food',
#    'also',
#    'healthy',
#    'wow',
#    'surprised',
#    'tasty',
#    'cereal',
#    'ever',
#    'definitely',
#    'taste',
#    'boring',
#    'usual',
#    'healthy',
#    'products',
#    'indeed',
#    'healthy',
#    'eating',
#    'cereal',
#    'fun',
#    'glad',
#    'gave',
#    'try',
#    'definitely',
#    'buy'],
#   'pos'),
#  (['love',
#    'tea',
#    'usually',
#    'cup',
#    'every',
#    'morning',
#    'received',
#    'timely',
#    'well'],
#   'pos'),
#  (['grown',
#    'accustomed',
#    'flavor',
#    'real',
#    'organic',
#    'sumatra',
#    'aceh',
#    'coffee',
#    'one',
#    'different',
#    'taste',
#    'perhaps',
#    'fact',
#    '1',
#    'original',
#    'green',
#    'mountain',
#    'packaging',
#    '2',
#    'read',
#    'part',
#    'labeled',
#    'retail',
#    'sale',
#    'shame',
#    'going',
#    'back',
#    'staying',
#    'keurig'],
#   'neg'),
#  (['drinking',
#    'matcha',
#    'bit',
#    'low',
#    'quality',
#    'think',
#    'matcha',
#    'good',
#    'may',
#    'high',
#    'quality',
#    'matcha',
#    'compare',
#    'pure',
#    'matcha',
#    'brand',
#    'powder',
#    'much',
#    'higher',
#    'quality',
#    'tastes',
#    'hundred',
#    'times',
#    'better',
#    'sorry',
#    'wasted',
#    'money',
#    'plus',
#    'chinese',
#    'matcha',
#    'much',
#    'likley',
#    'contain',
#    'lead'],
#   'neg'),
#  (['disappointed',
#    'recieved',
#    'package',
#    'today',
#    'product',
#    'mentioned',
#    'supposed',
#    '2',
#    'pack',
#    'black',
#    'tapioca',
#    'pearl',
#    'reason',
#    'made',
#    'purchase',
#    'instead',
#    'sent',
#    'one',
#    'pack',
#    'black',
#    'tapioca',
#    'pearl',
#    'color',
#    'tapioca',
#    'product',
#    'eligible',
#    'return'],
#   'neg'),
#  (['good',
#    'pistachios',
#    'tasteless',
#    'stale',
#    'salted',
#    'unami',
#    'turkish',
#    'flavor',
#    'real',
#    'turkish',
#    'pistachios',
#    'directly',
#    'turkey',
#    'sorry',
#    'wasted',
#    'money',
#    'taste',
#    'like',
#    'regular',
#    'california',
#    'nuts',
#    'people',
#    'sell',
#    'authentic',
#    'stuff',
#    'nowadays',
#    'trust',
#    'nobody',
#    'almost',
#    '60',
#    'bad',
#    'product',
#    'never',
#    'vendor'],
#   'neg'),
#  (['stoked',
#    'try',
#    'cookies',
#    'mean',
#    'fudge',
#    'shortbread',
#    'together',
#    'heck',
#    'yes',
#    'great',
#    'luck',
#    'back',
#    'nature',
#    'cookies',
#    'tried',
#    'chocolate',
#    'chunk',
#    'triple',
#    'ginger',
#    'lemon',
#    'vanilla',
#    'good',
#    'god',
#    'fudge',
#    'striped',
#    'cookies',
#    'god',
#    'awful',
#    'taste',
#    'crumbly',
#    'boot',
#    'chocolate',
#    'taste',
#    'like',
#    'anything',
#    'could',
#    'taste',
#    'raw',
#    'flour',
#    'something',
#    'nasty',
#    'like',
#    'really',
#    'need',
#    'change',
#    'recipe',
#    'one',
#    'aint',
#    'working',
#    'high',
#    'hopes',
#    'let',
#    'stick',
#    'back',
#    'nature',
#    'cookies',
#    'maybe',
#    'try',
#    'chocolate',
#    'oatmeal',
#    'ones',
#    'next',
#    'staying',
#    'away',
#    'mint',
#    'ones',
#    'hear',
#    'way',
#    'salty',
#    'sensitive',
#    'kind',
#    'thing'],
#   'neg'),
#  (['get',
#    '9',
#    '75',
#    'pounds',
#    '4',
#    '42',
#    'kg',
#    'salt',
#    'total',
#    'six',
#    'pouches',
#    'described',
#    'use',
#    'place',
#    'table',
#    'salt',
#    'buy',
#    'small',
#    'real',
#    'salt',
#    'dispenser',
#    'refill',
#    'people',
#    'always',
#    'read',
#    'labeling',
#    'see',
#    'table'],
#   'pos'),
#  (['great',
#    'value',
#    'get',
#    'exactly',
#    'says',
#    'ade',
#    'red',
#    'velvet',
#    'cupcakes',
#    'turned',
#    'great',
#    'worth',
#    'buy',
#    'large',
#    'bottle',
#    'need',
#    'food',
#    'amount',
#    'small',
#    'ones',
#    'expwnsive',
#    'go',
#    'far',
#    'buy',
#    'run'],
#   'pos'),
#  (['brand',
#    'recommended',
#    'someone',
#    'knew',
#    'know',
#    'stuff',
#    'however',
#    'case',
#    'water',
#    'arrived',
#    'tested',
#    'ph',
#    '6',
#    'ph',
#    'called',
#    'expert',
#    'said',
#    'shake',
#    'bottle',
#    'vigorously',
#    'retest',
#    'showed',
#    '6',
#    'ph',
#    'ordered',
#    'water',
#    'ph',
#    'advertised',
#    'label',
#    'called',
#    'toll',
#    'free',
#    'number',
#    'bottle',
#    'marketing',
#    'gave',
#    'bull',
#    'needing',
#    'special',
#    'instrument',
#    'calibrated',
#    'instrument',
#    'test',
#    'water',
#    'two',
#    'different',
#    'chemist',
#    'hardly',
#    'know',
#    'told',
#    'true',
#    'disappointed',
#    'since',
#    'pricey'],
#   'neg'),
#  (['really',
#    'love',
#    'ginger',
#    'chew',
#    'give',
#    'family',
#    'friends',
#    'little',
#    'snack',
#    'bags',
#    'loved'],
#   'pos'),
#  (['know',
#    'companies',
#    'always',
#    'mess',
#    'good',
#    'thing',
#    'least',
#    'coke',
#    'learned',
#    'lesson',
#    'bought',
#    'last',
#    'year',
#    'thinking',
#    'buying',
#    'always',
#    'bought',
#    'tasted',
#    'thought',
#    'maybe',
#    'new',
#    'extra',
#    'kind',
#    'picked',
#    'wrong',
#    'box',
#    'nope',
#    'changed',
#    'without',
#    'even',
#    'asking',
#    'customers',
#    'flavor',
#    'fruity',
#    'bad',
#    'way',
#    'satisfying',
#    'slighty',
#    'crunchy',
#    'texture',
#    'gone',
#    'see',
#    'stores',
#    'year',
#    'still',
#    'last',
#    'year',
#    'unsuspecting',
#    'people',
#    'pick',
#    'put',
#    'carts',
#    'many',
#    'definitely',
#    'flying',
#    'shelves',
#    'valentine',
#    'day',
#    'tons',
#    'left',
#    'able',
#    'give',
#    'away',
#    'goodbye',
#    'go',
#    'back',
#    'old',
#    'conversation',
#    'hearts'],
#   'neg'),
#  (['kid', 'hates'], 'neg'),
#  (['creamy',
#    'crumbly',
#    'sweet',
#    'sweet',
#    'treats',
#    'unique',
#    'flavor',
#    'perhaps',
#    'use',
#    'little',
#    'sesame',
#    'twelve',
#    'bars',
#    'box',
#    'go',
#    'people',
#    'think',
#    'adventurous',
#    'trying',
#    'really',
#    'everyone',
#    'tried',
#    'really'],
#   'pos'),
#  (['tea',
#    'tastes',
#    'great',
#    'really',
#    'helps',
#    'relax',
#    'recommending',
#    'friends'],
#   'pos'),
#  (['kellogg',
#    'cereals',
#    'contain',
#    'genetically',
#    'modified',
#    'organisms',
#    'crops',
#    'dna',
#    'spliced',
#    'toxins',
#    'bacteria',
#    'kellogg',
#    'paid',
#    '600',
#    '000',
#    'dollars',
#    'fight',
#    'right',
#    'know',
#    'gmo',
#    'food',
#    'would',
#    'buy',
#    'cereal'],
#   'neg'),
#  (['mojita',
#    'mix',
#    'expected',
#    'even',
#    'read',
#    'positive',
#    'reviews',
#    'taste',
#    'good',
#    'matter',
#    'mixed',
#    'tried',
#    'several',
#    'times',
#    'still',
#    'good',
#    'poured',
#    'remainder',
#    'gave',
#    'one',
#    'away',
#    'another',
#    'opened',
#    'time',
#    'soon',
#    'hmmm',
#    'may',
#    'give',
#    'away',
#    'dirty',
#    'santa',
#    'gift',
#    'sounds',
#    'like',
#    'plan'],
#   'neg'),
#  (['love'], 'pos'),
#  (['campbell',
#    'chunky',
#    'clam',
#    'chowder',
#    'used',
#    'one',
#    'favorites',
#    'longer',
#    'current',
#    'offering',
#    'must',
#    'use',
#    'new',
#    'recipe',
#    'former',
#    'sweet',
#    'creamy',
#    'taste',
#    'gone',
#    'runny',
#    'funny',
#    'kind',
#    'peppery',
#    'flavor',
#    'reminds',
#    'bp',
#    'oil',
#    'spill',
#    'includes',
#    'crunchy',
#    'bits',
#    'shell',
#    'sand',
#    'ate',
#    'couple',
#    'spoonfuls',
#    'threw',
#    'rest',
#    'away',
#    'ugh',
#    'never'],
#   'neg'),
#  (['received',
#    'one',
#    'packet',
#    'coffee',
#    'gift',
#    'set',
#    'office',
#    'party',
#    'need',
#    'coffee',
#    'mugs',
#    'sat',
#    'around',
#    'months',
#    'months',
#    'well',
#    'ran',
#    'folgers',
#    'one',
#    'morning',
#    'want',
#    'run',
#    'grocery',
#    'store',
#    'finally',
#    'ripped',
#    'open',
#    'gift',
#    'set',
#    'use',
#    'coffee',
#    'omg',
#    'wait',
#    'long',
#    'smooth',
#    'flavorful',
#    'delicious',
#    'sad',
#    'time',
#    'never',
#    'drank',
#    'needless',
#    'say',
#    'immediately',
#    'ordered',
#    'got',
#    'flavors',
#    'try',
#    'good',
#    'well',
#    'still',
#    'love',
#    'jamaican',
#    'crazy',
#    'best'],
#   'pos'),
#  (['product', 'expiration', 'date', 'july', '2016'], 'neg'),
#  (['dont', 'waste', 'time', 'money', 'product', 'aroma', 'taste'], 'neg'),
#  (['love'], 'pos'),
#  (['love', 'salt', 'salt', 'grinder'], 'pos'),
#  (['grandson',
#    'loves',
#    'buy',
#    'case',
#    'family',
#    'members',
#    'enjoy',
#    'eatings',
#    'annie',
#    'buy',
#    'case'],
#   'pos'),
#  (['totally', 'love', 'thanks'], 'pos'),
#  (['bought',
#    'item',
#    'great',
#    'deal',
#    'expiration',
#    'date',
#    '6',
#    'month',
#    'recieve',
#    'anyone',
#    'curious',
#    'would',
#    'buy',
#    'product'],
#   'pos'),
#  (['nice', 'quick', 'service'], 'pos'),
#  (['perfect'], 'pos'),
#  (['3',
#    '16',
#    'unsealed',
#    'bucket',
#    'oatmeal',
#    'manufactured',
#    'date',
#    '2011',
#    'moldy',
#    'may',
#    'good',
#    'item',
#    'buy',
#    'bulk',
#    'plan',
#    'using',
#    'within',
#    'year',
#    'planning',
#    'item',
#    'usable',
#    'years',
#    'road',
#    'shtf',
#    'even',
#    'near',
#    '30',
#    'year',
#    'shelf',
#    'life',
#    'claimed',
#    'augason',
#    'farms',
#    'may',
#    'find',
#    'mighty',
#    'disappointed',
#    'unless',
#    'way',
#    'hold',
#    'humidity',
#    'level',
#    'stored',
#    'constant',
#    '15'],
#   'neg'),
#  (['rich',
#    'tasting',
#    'great',
#    'selection',
#    'remember',
#    'eat',
#    'many',
#    'due',
#    'malitol',
#    'definitely',
#    'disrupt',
#    'digestive',
#    'system',
#    'eat',
#    'many',
#    'like',
#    'malitol',
#    'reminder',
#    'eat',
#    'two',
#    'one',
#    'time',
#    'make',
#    'perfect',
#    'sweet',
#    'snack',
#    'wish',
#    'expensive',
#    'online',
#    'prices',
#    'much',
#    'better',
#    'grocery',
#    'stores',
#    'believe',
#    'russell',
#    'stover',
#    'one',
#    'best',
#    'sugar',
#    'free',
#    'candies',
#    'market'],
#   'pos'),
#  (['unusual',
#    'sauce',
#    'good',
#    'flavor',
#    'high',
#    'heat',
#    'use',
#    'drops',
#    'cocktail',
#    'sauce',
#    'soups',
#    'etc',
#    'people',
#    'use',
#    'drop',
#    'time',
#    'thing',
#    'must',
#    'use',
#    'sparingly',
#    'hurt',
#    'dilute',
#    'enough',
#    'sauce',
#    'soup',
#    'chili',
#    'whatever',
#    'like',
#    'hot',
#    'sauce',
#    'find',
#    'really',
#    'great',
#    'taste',
#    'blends',
#    'well',
#    'dishes',
#    'hand',
#    'use',
#    'straight',
#    'probably',
#    'sorry',
#    'people',
#    'would',
#    'considered',
#    'extremely',
#    'hot',
#    'sauce',
#    'bottle',
#    'warnings',
#    'people',
#    'heart',
#    'respiratory',
#    'problems'],
#   'pos'),
#  (['good', 'expected', 'looking', 'flavour', 'starbucks', 'different'], 'neg'),
#  (['love',
#    'vanilla',
#    'bars',
#    'way',
#    'losing',
#    '50lbs',
#    'perfect',
#    'need',
#    'sugar',
#    'fix',
#    'ww',
#    '5',
#    'points',
#    'ps',
#    'bother',
#    'weird',
#    'flavors',
#    'bit',
#    'funky'],
#   'pos'),
#  (['two',
#    'bottles',
#    'glass',
#    'shattered',
#    'box',
#    'mess',
#    'took',
#    'video',
#    'pictures',
#    'sent',
#    'amazon',
#    'ups',
#    'mountain',
#    'water',
#    'directly',
#    'told',
#    'hold',
#    'onto',
#    'product',
#    'five',
#    'days',
#    'would',
#    'handled',
#    'day',
#    'stuff',
#    'garage',
#    'one',
#    'ever',
#    'contacted',
#    'since',
#    'feel',
#    'got',
#    'ripped',
#    'passing',
#    'buck',
#    'one',
#    'wanted',
#    'take',
#    'responsibility',
#    'damage',
#    'box',
#    'set',
#    'porch',
#    'upside',
#    'box',
#    'soggy'],
#   'neg'),
#  (['bought',
#    'couple',
#    'whole',
#    'foods',
#    'finish',
#    'first',
#    'one',
#    'threw',
#    'away',
#    'second',
#    'even',
#    'resemble',
#    'food',
#    'ramen',
#    'kicks',
#    'butt',
#    'absolutely',
#    'disgusting',
#    'ew',
#    'gross',
#    'waste',
#    'money',
#    'way'],
#   'neg'),
#  (['thought',
#    'would',
#    'nice',
#    'product',
#    'taste',
#    'bad',
#    'drink',
#    'would',
#    'recommend',
#    'friends',
#    'crystal',
#    'light',
#    'way',
#    'better',
#    'flavors'],
#   'neg'),
#  (['delcious',
#    'even',
#    'gluten',
#    'free',
#    'love',
#    'sesame',
#    'seeds',
#    'great',
#    'substitute',
#    'extra',
#    'salt'],
#   'pos'),
#  (['put',
#    'cinnamon',
#    'coffee',
#    'cook',
#    'mix',
#    'raw',
#    'honey',
#    'health',
#    'purposes',
#    'without',
#    'fear',
#    'liver',
#    'damage',
#    'common',
#    'cinnamon',
#    'thanks',
#    'great',
#    'product'],
#   'pos'),
#  (['good', 'size', 'fresh', 'looking', 'green', 'peppers'], 'pos'),
#  (['fantastic', 'taste', 'like', 'stuff', 'rick', 'bayless'], 'pos'),
#  (['great', 'taste'], 'pos'),
#  (['love', 'red', 'boat', 'bottle', 'bad', 'full', 'chunks'], 'neg'),
#  (['tasted',
#    'like',
#    'plastic',
#    'arrived',
#    'broken',
#    'tiny',
#    'pieces',
#    'love',
#    'healthy',
#    'foods',
#    'hoping',
#    'decent',
#    'tasting',
#    'snack'],
#   'neg'),
#  (['like',
#    'bottle',
#    'much',
#    'much',
#    'much',
#    'better',
#    'happy',
#    'k',
#    'cups',
#    'disappointed'],
#   'neg'),
#  (['love', 'fondant', 'easy', 'work', 'wonderful', 'taste'], 'pos'),
#  (['noodle',
#    'smells',
#    'break',
#    'small',
#    'pieces',
#    'sauce',
#    'semlls',
#    'sour',
#    'nothing',
#    'like',
#    'say',
#    'package',
#    'curry',
#    'kind',
#    'japan',
#    'curry',
#    'india',
#    'curry',
#    'kind',
#    'curry',
#    'ever',
#    'taste',
#    'bad',
#    'bad',
#    'bad',
#    'product',
#    'btw',
#    '3',
#    '6',
#    'bowl',
#    'dent'],
#   'neg'),
#  (['good', 'taffys'], 'pos'),
#  (['definitely', 'seedless'], 'neg'),
#  (['like'], 'neg'),
#  (['expiration', 'date', 'package', 'stale', 'buy'], 'neg'),
#  (['love',
#    'sprinkle',
#    'nbsp',
#    'data',
#    'hook',
#    'product',
#    'link',
#    'linked',
#    'class',
#    'link',
#    'normal',
#    'href',
#    'chia',
#    'seeds',
#    '2',
#    'pounds',
#    'dp',
#    'b009z5y3q8',
#    'ref',
#    'cm_cr_arp_d_rvw_txt',
#    'ie',
#    'utf8',
#    'chia',
#    'seeds',
#    '2',
#    'pounds',
#    'nbsp',
#    'really',
#    'good',
#    'warm',
#    'meal',
#    'morning',
#    'get',
#    'day',
#    'started',
#    'right'],
#   'pos'),
#  (['oat',
#    'groats',
#    'great',
#    'much',
#    'better',
#    '5',
#    'minute',
#    'rolled',
#    'oats',
#    'takes',
#    '50',
#    'minutes',
#    'make',
#    'worth',
#    'opinion',
#    'make',
#    'enough',
#    'week',
#    'seem',
#    'like',
#    'much',
#    'extra',
#    'work'],
#   'pos'),
#  (['pecan', 'pie', 'recipe', 'label'], 'pos'),
#  (['old',
#    'roasted',
#    'coffee',
#    'koffee',
#    'kult',
#    'web',
#    'description',
#    'coffee',
#    'said',
#    'big',
#    'body',
#    'low',
#    'acidity',
#    'crisp',
#    'sweet',
#    'flavor',
#    'however',
#    'strange',
#    'company',
#    'describe',
#    'important',
#    'flavors',
#    'good',
#    'coffee',
#    'must',
#    'caramel',
#    'chocolate',
#    'apple',
#    'peach',
#    'well',
#    'balance',
#    'etc',
#    'anyway',
#    'grinded',
#    '11',
#    'grams',
#    'coffee',
#    'beans',
#    'used',
#    'cup',
#    'hold',
#    '210',
#    'grams',
#    'water',
#    'cupping',
#    'purpose',
#    'measured',
#    'ground',
#    'weights',
#    'exactly',
#    'followed',
#    'scaa',
#    'cupping',
#    'protocols',
#    'immediately',
#    'realized',
#    'absolutely',
#    'aroma',
#    'ground',
#    'coffee',
#    'indicates',
#    'coffee',
#    'roasted',
#    'quite',
#    'ago',
#    'poured',
#    'hot',
#    'water',
#    'waited',
#    'min',
#    'break',
#    'cup',
#    'means',
#    'breaking',
#    'top',
#    'layer',
#    'coffee',
#    'ground',
#    'smell',
#    'aroma',
#    'expected',
#    'aroma',
#    'definitely',
#    'old',
#    'beans',
#    'finally',
#    'cupping',
#    'knew',
#    'already',
#    'useless',
#    'gave',
#    'try',
#    'zero',
#    'flavors',
#    'crisp',
#    'sweet',
#    'flavor',
#    'big',
#    'body',
#    'less',
#    'acidity',
#    'yes',
#    'basically',
#    'coffee',
#    'flat',
#    'complete',
#    'deprived',
#    'good',
#    'flavors',
#    'good',
#    'freshly',
#    'roasted',
#    'coffee',
#    'thing',
#    'glad',
#    'pay',
#    'full',
#    'price',
#    'shipping',
#    'probably',
#    'using',
#    'left',
#    'coffee',
#    'flavored',
#    'cold',
#    'brew',
#    'wonder',
#    'even',
#    'might',
#    'come',
#    'good',
#    'enough',
#    'drink',
#    'also',
#    'website',
#    'coffee',
#    'description',
#    'says',
#    'artisan',
#    'roasted',
#    'fresh',
#    'perfection',
#    'small',
#    'batch',
#    'roasters',
#    'roasted',
#    'immediately',
#    'prior',
#    'packaging',
#    'every',
#    'bag',
#    'consistently',
#    'roasting',
#    'profile',
#    'system',
#    'first',
#    'thought',
#    'roast',
#    'coffee',
#    'ordered',
#    'prior',
#    'shipping',
#    'reading',
#    'description',
#    'carefully',
#    'roasted',
#    'immediately',
#    'prior',
#    'packaging',
#    'say',
#    'prior',
#    'shipping',
#    'via',
#    'amazon',
#    'prime',
#    'guess',
#    'bad',
#    'miss',
#    'understood',
#    'might',
#    'roasted',
#    'beans',
#    'packaged',
#    'bags',
#    'immediately',
#    'one',
#    'knows',
#    'long',
#    'coffees',
#    'sitting',
#    'warehouse',
#    'roast',
#    'date',
#    'indicated',
#    'bag',
#    'koffee',
#    'kult',
#    'big',
#    'disappointment',
#    'many',
#    'levels'],
#   'neg'),
#  (['waited',
#    'month',
#    'get',
#    'product',
#    'shipped',
#    'ca',
#    'pa',
#    'single',
#    'ice',
#    'pack',
#    'needless',
#    'say',
#    'quite',
#    'warm',
#    'got'],
#   'neg'),
#  (['much',
#    'candy',
#    'squished',
#    'looked',
#    'like',
#    'melted',
#    'one',
#    'point',
#    'many',
#    'wrappers',
#    'looked',
#    'worn',
#    'well'],
#   'neg'),
#  (['love',
#    'big',
#    'train',
#    'chai',
#    'sell',
#    'exact',
#    'chai',
#    'several',
#    'local',
#    'coffee',
#    'shops',
#    'absolutely',
#    'love',
#    'really',
#    'like',
#    'getting',
#    'amazon',
#    'much',
#    'less',
#    'expensive',
#    'ordering',
#    'coffee',
#    'shop',
#    'buy',
#    'milk',
#    'frother',
#    'amazon',
#    'well',
#    'great',
#    'cup',
#    'chai',
#    'call',
#    'christmas',
#    'cup',
#    'delicious'],
#   'pos'),
#  (['really',
#    'excellent',
#    'hot',
#    'cocoa',
#    'mixes',
#    'go',
#    'trouble',
#    'heat',
#    'milk',
#    'stir',
#    'cocoa',
#    'mix',
#    'excellent',
#    'made',
#    'water',
#    'still',
#    'creamy',
#    'deep',
#    'chocolate',
#    'taste',
#    'heating',
#    'water',
#    'easier',
#    'less',
#    'messy',
#    'tried',
#    'mixes',
#    'made',
#    'ghiradelli',
#    'good',
#    'need',
#    'milk',
#    'pain',
#    'make',
#    'one',
#    'cup'],
#   'pos'),
#  (['looking', 'jalapeno', 'version', 'price', 'seemed', 'high', 'also'],
#   'neg'),
#  (['pop', 'need', 'long', 'night'], 'pos'),
#  (['purchased',
#    'several',
#    'trial',
#    'packages',
#    'gourmesso',
#    'coffee',
#    'products',
#    'liked',
#    'idea',
#    'buying',
#    'nespresso',
#    'products',
#    'essentially',
#    'half',
#    'cost',
#    'trial',
#    'see',
#    'equivalent',
#    'nespresso',
#    'line',
#    'espresso',
#    'pixie',
#    'received',
#    'product',
#    'tried',
#    'immediately',
#    'noticed',
#    'volume',
#    'less',
#    'half',
#    'nespresso',
#    'capsules',
#    'tried',
#    'several',
#    'capsules',
#    'result',
#    'followed',
#    'nespresso',
#    'capsules',
#    'fine',
#    'cleaned',
#    'nespresso',
#    'pixie',
#    'rechecked',
#    'appropriate',
#    'volumes',
#    'set',
#    'per',
#    'nespresso',
#    'directions',
#    'still',
#    'get',
#    'result',
#    'gourmesso',
#    'products',
#    'never',
#    'yield',
#    'full',
#    'cup',
#    'like',
#    'nepresso',
#    'products',
#    'disappointed',
#    'product',
#    'order',
#    'get',
#    'full',
#    'size',
#    'cup',
#    'need',
#    'use',
#    '2',
#    'gourmesso',
#    'capsules',
#    'disappointed',
#    'product',
#    'indeed',
#    'equivalent',
#    'nespresso',
#    'products',
#    'claim',
#    'would',
#    'gladly',
#    'signed',
#    'subscription',
#    'product'],
#   'neg'),
#  (['product', 'showed', 'moldy', 'return', 'replace', 'disappointing'], 'neg'),
#  (['waste',
#    'money',
#    'nothing',
#    'simple',
#    'vermicelli',
#    'sweet',
#    'potato',
#    '1',
#    'tbs',
#    'gochuchang',
#    '3',
#    'pieces',
#    'dried',
#    'ginger',
#    'oh',
#    'think',
#    '1',
#    '4',
#    'oz',
#    'beef',
#    'jerky',
#    'may',
#    'imagination',
#    'photo',
#    'even',
#    'close',
#    'product',
#    'received',
#    'lived',
#    'seoul',
#    'three',
#    'years',
#    'naengmyun',
#    'big',
#    'deal',
#    'really',
#    'cheap',
#    'crap',
#    'would',
#    '50',
#    'cents',
#    'make',
#    'home'],
#   'neg'),
#  (['perfect', 'wanted'], 'pos'),
#  (['real', 'thing'], 'pos'),
#  (['amabile',
#    'tasty',
#    'filled',
#    'room',
#    'coffee',
#    'smell',
#    'brewed',
#    'made',
#    'americano',
#    'one',
#    'pod',
#    'good',
#    'made',
#    'lattes',
#    'mochas',
#    '4',
#    'good',
#    'used',
#    'italiano',
#    'pods',
#    'mochas',
#    'morning',
#    'aroma',
#    'brewing',
#    'speak',
#    'kind',
#    'plain',
#    'flavor',
#    'nothing',
#    'special',
#    'shot',
#    'looked',
#    'weak',
#    'first',
#    'oro',
#    'pod',
#    'tried',
#    'day',
#    'good',
#    'made',
#    'americano',
#    'dumped',
#    'sip',
#    'flavor',
#    'well',
#    'foul',
#    'tried',
#    'another',
#    'oro',
#    'pod',
#    'today',
#    'americano',
#    'went',
#    'critically',
#    'sniffing',
#    'pod',
#    'brewing',
#    'yielded',
#    'faint',
#    'present',
#    'smell',
#    'like',
#    'rubber',
#    'americano',
#    'bad',
#    'undrinkable',
#    'checked',
#    'next',
#    'pod',
#    'oro',
#    'bag',
#    'smell',
#    'fainter',
#    'still',
#    'believe',
#    'got',
#    'nailed',
#    'poor',
#    'quality',
#    'control',
#    'maybe',
#    'part',
#    'gasket',
#    'something',
#    'pod',
#    'hesitant',
#    'plastic',
#    'pods',
#    'give',
#    'concern',
#    'life',
#    'machine',
#    'everything',
#    'stiff',
#    'insertion',
#    'ejection',
#    'unlike',
#    'smooth',
#    'operation',
#    'aluminum',
#    'pods',
#    'price',
#    'versus',
#    'nespresso',
#    'pods',
#    'opinion',
#    'great',
#    'enough',
#    'counter',
#    'potential',
#    'extra',
#    'wear',
#    'machine',
#    'replacement',
#    'cost',
#    'something',
#    'breaks',
#    'edit',
#    'tried',
#    'decaffinato',
#    'sniffed',
#    'pod',
#    'first',
#    'foul',
#    'rubber',
#    'smell',
#    'brew'],
#   'neg'),
#  (['gives', 'lot', 'stomach', 'cramps', 'pain', 'like', 'period'], 'neg'),
#  (['taste', 'amazing'], 'pos'),
#  (['would',
#    'fine',
#    'dressing',
#    'pancakes',
#    'taste',
#    'good',
#    'mixed',
#    'water',
#    '2',
#    'recipes',
#    'break',
#    'new',
#    'syrup',
#    'factor',
#    'two',
#    'expensive',
#    'pecan',
#    'butter',
#    'coconut',
#    'truffles',
#    'utensils',
#    'completely',
#    'dry',
#    'product',
#    'could',
#    'introduced',
#    'water',
#    'treats',
#    'second',
#    'time',
#    'happened',
#    'mixed',
#    'smaller',
#    'batch',
#    'kirkland',
#    'brand',
#    'syrup',
#    'cupboard',
#    'came',
#    'together',
#    'perfectly',
#    'false',
#    'claims',
#    'pure',
#    'syrup',
#    'cost',
#    '30',
#    'ingredients',
#    'counting',
#    'syrup',
#    'cost',
#    'hours',
#    'frustration',
#    'highly',
#    'disappointed',
#    'product',
#    'would',
#    'removed',
#    'amazon',
#    'listings',
#    'possible'],
#   'neg'),
#  (['terrible', 'however', 'every', 'flavor', 'fantastic'], 'neg'),
#  (['used',
#    'tea',
#    'years',
#    'suddenly',
#    'left',
#    'store',
#    'shelves',
#    'bought',
#    'amazon',
#    'since',
#    'love',
#    'big',
#    'time'],
#   'pos'),
#  (['doubts',
#    'good',
#    'could',
#    'possibly',
#    'surprise',
#    'amazing',
#    'even',
#    'look',
#    'potato',
#    'chips',
#    'anymore',
#    'taste',
#    'great',
#    'lot',
#    'less',
#    'calories',
#    'competitors'],
#   'pos'),
#  (['made',
#    'decision',
#    'go',
#    'wild',
#    'planet',
#    'based',
#    'ethical',
#    'concerns',
#    'nice',
#    'tuna',
#    'actually',
#    'tasted',
#    'lot',
#    'better',
#    'regular',
#    'tuna',
#    'bachelor',
#    'lunches',
#    'lazy',
#    'make',
#    'sandwich',
#    'ate',
#    'surprisingly',
#    'good',
#    'stuff',
#    'gross',
#    'chicken',
#    'sea',
#    'whatever'],
#   'pos'),
#  (['two',
#    'diabetics',
#    'home',
#    'tried',
#    'every',
#    'type',
#    'sweetener',
#    'drawn',
#    'stevia',
#    'natural',
#    'honestly',
#    'say',
#    'kal',
#    'brand',
#    'one',
#    'raise',
#    'blood',
#    'glucose',
#    'levels',
#    'aftertaste',
#    'highly',
#    'concentrated',
#    'need',
#    'little',
#    'bit',
#    'really',
#    'tastes',
#    'sweet',
#    'use',
#    'much',
#    'bitter',
#    'stunning',
#    'add',
#    'much',
#    'start',
#    'small',
#    'go',
#    'love',
#    'shaker',
#    'bottle',
#    'make',
#    'flavored',
#    'water',
#    'add',
#    'cereal',
#    'smoothies',
#    'easily',
#    'use',
#    'anything',
#    'else',
#    'love'],
#   'pos'),
#  (['product',
#    'contains',
#    'artificial',
#    'sweetener',
#    'way',
#    'know',
#    'research',
#    'product',
#    'ingredients',
#    'labeling',
#    'nutritional',
#    'info',
#    'included',
#    'box',
#    'packaging',
#    'could',
#    'possibly',
#    'grossest',
#    'thing',
#    'ever',
#    'tasted'],
#   'neg'),
#  (['never',
#    'better',
#    'gin',
#    'tonic',
#    'really',
#    'like',
#    'fact',
#    'high',
#    'fructose',
#    'corn',
#    'syrup'],
#   'pos'),
#  (['disappointed',
#    'item',
#    'listed',
#    'pods',
#    'keurig',
#    'instead',
#    'received',
#    'round',
#    'coffee',
#    'bags',
#    'know',
#    'trust',
#    'order',
#    'amazon',
#    'differentiate',
#    'items',
#    'unhappy'],
#   'neg'),
#  (['love',
#    'form',
#    'reese',
#    'peanut',
#    'butter',
#    'candy',
#    'much',
#    'prefer',
#    'individually',
#    'wrapped',
#    'small',
#    'bars',
#    'seem',
#    'produce',
#    'around',
#    'halloween',
#    'time',
#    'convenient',
#    'stay',
#    'fresh',
#    'longer',
#    'large',
#    'bar',
#    'would',
#    'never',
#    'eat',
#    'much',
#    'one',
#    'sitting',
#    'still',
#    'reese',
#    'love'],
#   'pos'),
#  (['love', 'chai', 'tea'], 'pos'),
#  (['thank'], 'pos'),
#  (['tasty', 'bad', 'also', 'fill', 'expect'], 'pos'),
#  (['bought',
#    'original',
#    'version',
#    'loved',
#    'ordered',
#    'got',
#    'new',
#    'improved',
#    'version',
#    'hated',
#    'went',
#    '3',
#    'ingredients',
#    '16',
#    'including',
#    'natural',
#    'flavor',
#    'buy',
#    'switching',
#    'nuco'],
#   'neg'),
#  (['buyer',
#    'beware',
#    '3',
#    'packs',
#    'bread',
#    'pictured',
#    'orders',
#    'received',
#    '2',
#    'loafs',
#    'pack',
#    '4',
#    'hamburger',
#    'buns',
#    'see',
#    'description',
#    'state',
#    'feel',
#    'little',
#    'tricked',
#    'item',
#    'bread',
#    'good'],
#   'neg'),
#  (['one',
#    'star',
#    'high',
#    'carbon',
#    'footprint',
#    'water',
#    'source',
#    'fiji',
#    'shipped',
#    'amazon',
#    'warehouses',
#    'north',
#    'america',
#    'bad',
#    'enough',
#    'shipped',
#    'individuals',
#    'via',
#    'air',
#    'prime',
#    'shipments',
#    'water',
#    'heavy',
#    'making',
#    'long',
#    'journey',
#    'even',
#    'carbon',
#    'intensive',
#    'packaging',
#    'sure',
#    'plastic',
#    'bottles',
#    'recycled',
#    'many',
#    'recycling',
#    'better',
#    'sending',
#    'landfill',
#    'ending',
#    'ocean',
#    'google',
#    'garbage',
#    'patch',
#    'still',
#    'requires',
#    'resources',
#    'form',
#    'energy',
#    'see',
#    'carbon',
#    'footprint',
#    'bit',
#    'expensive',
#    'get',
#    'priorities',
#    'order',
#    'people',
#    'placing',
#    'order',
#    'days',
#    'advance',
#    'drinking',
#    'water',
#    'costs',
#    'much',
#    'gasoline',
#    'something',
#    'must',
#    'seriously',
#    'wrong',
#    'totally',
#    'get',
#    'convenience',
#    'factor',
#    'picking',
#    'bottle',
#    'quickie',
#    'mart',
#    'even',
#    'picking',
#    'case',
#    'supermarket',
#    'road',
#    'trip',
#    'something',
#    'get',
#    'people',
#    'investing',
#    'filter',
#    'purifier',
#    'house',
#    'instead',
#    'pay',
#    'time',
#    'little',
#    'rant',
#    'quality',
#    'fiji',
#    'water',
#    'fine',
#    'though',
#    'think',
#    'significantly',
#    'better',
#    'tap',
#    'water'],
#   'neg'),
#  (['like',
#    'coffee',
#    'house',
#    'coffee',
#    'even',
#    'decaf',
#    'wonderful',
#    'guilt',
#    'free',
#    'italian',
#    'roast'],
#   'pos'),
#  (['soup',
#    'never',
#    'gets',
#    'old',
#    'curious',
#    'seems',
#    'like',
#    'would',
#    'become',
#    'monotonous',
#    'cups',
#    'tasty',
#    'great',
#    'texture',
#    'goes',
#    'well',
#    'additions',
#    'accompaniments',
#    'often',
#    'put',
#    'dollop',
#    'sour',
#    'cream',
#    'top',
#    'eat',
#    'tortilla',
#    'chips',
#    'always',
#    'add',
#    'dashes',
#    'tabasco',
#    'tasty',
#    'filling',
#    'especially',
#    'cold',
#    'day',
#    'already',
#    'ordered',
#    'devoured',
#    'two',
#    'cases',
#    'continue',
#    'restock',
#    'makes',
#    'delicious',
#    'convenient',
#    'lunchtime',
#    'staple'],
#   'pos'),
#  (['ordered',
#    'today',
#    'someone',
#    'valentine',
#    'day',
#    'showed',
#    'dead',
#    'ridiculous'],
#   'neg'),
#  (['looking',
#    'stevia',
#    'sweetener',
#    'stevia',
#    'product',
#    'even',
#    'though',
#    'marketed',
#    'nustevia',
#    'product',
#    'adds',
#    'erythritol',
#    'sweetener',
#    'wtf',
#    'wanted',
#    'artifical',
#    'sweeteners',
#    'would',
#    'stick',
#    'aspartamine'],
#   'neg'),
#  (['great', 'item'], 'pos'),
#  (['horrible',
#    'ordered',
#    'nov',
#    '21',
#    'delivered',
#    'dec',
#    '4th',
#    'chocolate',
#    'coating',
#    'dry',
#    'flaking',
#    'sad'],
#   'neg'),
#  (['spam', 'emails', 'salt', 'discolored'], 'neg'),
#  (['wanted',
#    'like',
#    'organic',
#    'pasta',
#    'etc',
#    'needs',
#    'stronger',
#    'cheese',
#    'nature',
#    'mac',
#    'cheese',
#    'bland',
#    'little',
#    'kids',
#    'love',
#    'made',
#    'real',
#    'cheddar',
#    'cheese',
#    'cheese',
#    'flavor',
#    'texture',
#    'fine',
#    'like',
#    'whole',
#    'grained',
#    'pasta',
#    'strong',
#    'flavor',
#    'whole',
#    'grains',
#    'retain',
#    'much',
#    'aldente',
#    'texture',
#    'like',
#    'whole',
#    'grained',
#    'pasta',
#    'lacking',
#    'cheddar',
#    'flavor',
#    'sticking',
#    'v',
#    'shells',
#    'make',
#    'using',
#    'good',
#    'multi',
#    'grain',
#    'pasta',
#    'barilla',
#    'really',
#    'sharp',
#    'cheddar',
#    'sorry',
#    'annie'],
#   'neg'),
#  (['wanted',
#    'authentic',
#    'fruit',
#    'cake',
#    'lot',
#    'chemical',
#    'additives',
#    'tastes',
#    'like',
#    'cardboard',
#    'wish',
#    'would',
#    'paid',
#    'closer',
#    'attention',
#    'ingredients',
#    'purchased',
#    'terrible',
#    'better',
#    'cheap',
#    'fruitcake',
#    'grocery',
#    'store'],
#   'neg'),
#  (['work',
#    'kuerig',
#    'coffees',
#    'work',
#    'fine',
#    'foil',
#    'top',
#    'appears',
#    'questionable',
#    'kuerig',
#    'punches',
#    'large',
#    'hole',
#    'top',
#    'cup',
#    'end',
#    'grounds',
#    'coffee',
#    'water',
#    'leakage',
#    'end',
#    'cup',
#    'delivery'],
#   'neg'),
#  (['mayo',
#    'extremely',
#    'bitter',
#    'time',
#    'extremely',
#    'sour',
#    'flavor',
#    'detected',
#    'tried',
#    'sandwich',
#    'meats',
#    'vegetables',
#    'eat',
#    'anything',
#    'eat',
#    'anything',
#    'ann',
#    'mary'],
#   'neg'),
#  (['oatmeal',
#    'horrible',
#    'got',
#    'another',
#    'box',
#    'premium',
#    'regular',
#    'oatmeal',
#    'delicious',
#    'loved',
#    'much',
#    'costco',
#    'box',
#    'premium',
#    'organic',
#    'oatmeal',
#    'didnt',
#    'hesitate',
#    'buy',
#    'agree',
#    'reviewers',
#    'could',
#    'make',
#    'something',
#    'bad',
#    'save',
#    'money',
#    'incredibly',
#    'disappointed',
#    'even',
#    'think',
#    'force',
#    'finish',
#    'box'],
#   'neg'),
#  (['oh',
#    'god',
#    'best',
#    'new',
#    'food',
#    'ever',
#    'brought',
#    'life',
#    'would',
#    'eat',
#    'anything',
#    'still',
#    'eat',
#    'must',
#    'laced',
#    'tomato',
#    'goodness',
#    'reusable',
#    'carafe',
#    'say',
#    'oh',
#    'god',
#    'new',
#    'favorite',
#    'company',
#    'thought',
#    'next',
#    'day',
#    'woke',
#    'swelling',
#    'face',
#    'covered',
#    'hives',
#    'allergies',
#    'going',
#    'nuts',
#    'checked',
#    'msg',
#    'found',
#    'none',
#    'label',
#    'laced',
#    'msg',
#    'hidden',
#    'listing',
#    'citric',
#    'acid',
#    'company',
#    'go',
#    'way',
#    'hide',
#    'ingredients',
#    'makes',
#    'sick',
#    'would',
#    'screw',
#    'otherwise',
#    'great',
#    'product',
#    'lies',
#    'misrepresentations',
#    'made',
#    'citrus',
#    'acid',
#    'produced',
#    'aspergillus',
#    'niger',
#    'black',
#    'mold',
#    'closing',
#    'laced',
#    'something',
#    'msg'],
#   'neg'),
#  (['product', 'close', 'code', 'date'], 'neg'),
#  (['great',
#    'tasting',
#    'candy',
#    'reasonable',
#    'price',
#    'hard',
#    'find',
#    'store',
#    'get',
#    'twelve',
#    'family',
#    'loves'],
#   'pos'),
#  (['quality', 'cinnamon', 'tea', 'thoroughly', 'enjoy', 'cup'], 'pos'),
#  (['thinking',
#    'great',
#    'get',
#    'well',
#    'gift',
#    'friend',
#    'cold',
#    'bamboo',
#    'box',
#    'nice',
#    'addition',
#    'used',
#    'tea',
#    'collection',
#    'mom',
#    'transferred',
#    'teas',
#    'restaurant',
#    'quality',
#    'selection',
#    'box',
#    'offer',
#    'guests',
#    'come'],
#   'pos'),
#  (['came',
#    'went',
#    'fast',
#    'really',
#    'enjoyed',
#    'snack',
#    'purchase',
#    'near',
#    'future'],
#   'pos'),
#  (['crackers',
#    'become',
#    'staple',
#    'house',
#    'lunch',
#    'complete',
#    'without',
#    'taste',
#    'great',
#    'alone',
#    'sardines'],
#   'pos'),
#  (['great'], 'pos'),
#  (['buy',
#    '1',
#    'teaspoon',
#    'made',
#    'ill',
#    'entire',
#    'day',
#    'research',
#    'found',
#    'supposed',
#    'even',
#    'eat',
#    'raw',
#    'maca',
#    'sending',
#    'back',
#    'ordering',
#    'gelantinized',
#    'maca',
#    'powder',
#    'safe',
#    'eat',
#    'shame',
#    'company',
#    'selling',
#    'stuff',
#    'eat',
#    'raw'],
#   'neg'),
#  (['taste',
#    'disgusting',
#    'terrible',
#    'texture',
#    'literally',
#    'made',
#    'tongue',
#    'numb',
#    'nauseated',
#    'hour',
#    'ate',
#    'one',
#    'eaten',
#    'sugar',
#    'years',
#    'used',
#    'things',
#    'sweet',
#    'eat',
#    'real',
#    'food'],
#   'neg'),
#  (['opposed',
#    'change',
#    'oppose',
#    'change',
#    'change',
#    'needed',
#    'first',
#    'place',
#    'disappointed',
#    'necco',
#    'misguided',
#    'decision',
#    'change',
#    'classic',
#    'sweethearts',
#    'conversation',
#    'hearts',
#    'great',
#    'traditional',
#    'candy',
#    'gross',
#    'changed',
#    'flavors',
#    'eliminated',
#    'white',
#    'ones',
#    'together',
#    'luck',
#    'would',
#    'favorites',
#    'changed',
#    'nice',
#    'crunchy',
#    'texture',
#    'soft',
#    'disintegrating',
#    'mess',
#    'bleck',
#    'huge',
#    'mistake',
#    'change',
#    'trusty',
#    'classic',
#    'make',
#    'new',
#    'candy'],
#   'neg'),
#  (['fun', 'product', 'wrapped', 'two', 'decorative', 'mugs', 'big', 'hit'],
#   'pos'),
#  (['could',
#    'rate',
#    'lower',
#    'one',
#    'would',
#    'soda',
#    'flavors',
#    'pretty',
#    'much',
#    'taste',
#    'also',
#    'fizziest',
#    'soda',
#    'ever',
#    'want',
#    'belch',
#    'drink'],
#   'neg'),
#  (['awesome'], 'pos'),
#  (['yummy', 'yummy', 'fresh', 'delicious'], 'pos'),
#  (['package',
#    'arrived',
#    'crumbs',
#    'due',
#    'packaged',
#    '24',
#    'bottles',
#    'water',
#    'want',
#    'bags',
#    'cookies',
#    'replaced'],
#   'neg'),
#  (['forcing',
#    'drink',
#    'since',
#    'spent',
#    'money',
#    'tastes',
#    'nothing',
#    'like',
#    'quality',
#    'matcha',
#    'powder',
#    'sure',
#    'grade',
#    'poor',
#    'quality'],
#   'neg'),
#  (['much', 'flavor', 'pistachios'], 'neg'),
#  (['love',
#    'cup',
#    'coffee',
#    'everyone',
#    'else',
#    'coffee',
#    'usually',
#    'agree',
#    'acid',
#    'reduced',
#    'fine',
#    'actually',
#    'really',
#    'tastes',
#    'good'],
#   'pos'),
#  (['happy',
#    'people',
#    'say',
#    'sour',
#    'true',
#    'mouth',
#    'puckering',
#    'teeth',
#    'enamel',
#    'eroding',
#    'sour',
#    'definitely',
#    'lemony',
#    'tasting',
#    'like',
#    'lemon',
#    'drops',
#    'taste',
#    'exactly',
#    'way',
#    'remember',
#    'lemon',
#    'drops',
#    'childhood',
#    'tasting',
#    'mine',
#    'arrived',
#    'fine',
#    'shape',
#    'sugar',
#    'sanding',
#    'intact',
#    'keep',
#    'jar',
#    'desk',
#    'sticking',
#    'together',
#    'broken',
#    'anything',
#    'like',
#    'great',
#    'dry',
#    'throat'],
#   'pos'),
#  (['almond',
#    'syrup',
#    'hard',
#    'come',
#    'days',
#    'starbucks',
#    'coffee',
#    'places',
#    'might',
#    'want',
#    'steamed',
#    'milk',
#    'italian',
#    'soda',
#    'orgeat',
#    'almond',
#    'syrup',
#    'glad',
#    'found',
#    'amazon',
#    'absolute',
#    'favorite',
#    'flavor',
#    'make',
#    'almond',
#    'italian',
#    'sodas',
#    'adding',
#    'pellegrino',
#    'add',
#    'half',
#    'half',
#    'coconut',
#    'creamer',
#    'cream',
#    'soda',
#    'steam',
#    'milk',
#    'add',
#    'syrup',
#    'almond',
#    'steamer',
#    'yummy'],
#   'pos'),
#  (['broiled',
#    'steak',
#    'seasoning',
#    'salt',
#    'even',
#    'say',
#    'bottle',
#    'going',
#    'return',
#    'stuff',
#    'may',
#    'taste',
#    'ok',
#    'real',
#    'deal'],
#   'neg'),
#  (['supposedly',
#    'liquifies',
#    'cold',
#    'water',
#    'hot',
#    'clumps',
#    'break',
#    'total',
#    'waste'],
#   'neg'),
#  (['hydrogenated', 'oils'], 'neg'),
#  (['yummy',
#    'packets',
#    'sugar',
#    'free',
#    'hot',
#    'chocolate',
#    'mix',
#    'swiss',
#    'miss',
#    'quality',
#    'works',
#    'glad',
#    'found',
#    'amazon',
#    'costco',
#    'longer',
#    'carries'],
#   'pos'),
#  (['cookies', 'broken', 'disappointed'], 'neg'),
#  (['ew', 'smells'], 'neg'),
#  (['colors', 'like', 'pastel', 'otherwise', 'good', 'product'], 'pos'),
#  (['took',
#    'long',
#    'receive',
#    'ten',
#    'pods',
#    'use',
#    '16',
#    'pods',
#    'disappointed'],
#   'neg'),
#  (['coffee',
#    'one',
#    'best',
#    'decaf',
#    'bold',
#    'coffee',
#    'available',
#    'green',
#    'mountain',
#    'dark',
#    'magic',
#    'thought',
#    'good'],
#   'pos'),
#  (['terrible', 'unusable'], 'neg'),
#  (['ever',
#    'frozen',
#    'thawed',
#    'cup',
#    'yogurt',
#    'maybe',
#    'mashed',
#    'jello',
#    'added',
#    'bit',
#    'water',
#    'left',
#    'cup',
#    'milk',
#    'tried',
#    'mix',
#    'solid',
#    'back',
#    'liquid',
#    'suppose',
#    'sound',
#    'fairly',
#    'revolting',
#    'pretty',
#    'accurately',
#    'summarize',
#    'texture',
#    'whipped',
#    'peanut',
#    'spread',
#    'wet',
#    'gelatinous',
#    'mushy',
#    'time',
#    'spread',
#    'across',
#    'piece',
#    'toast',
#    'even',
#    'first',
#    'taste',
#    'thought',
#    'actually',
#    'putting',
#    'mouth',
#    'made',
#    'feel',
#    'slightly',
#    'nauseous',
#    'entirely',
#    'fair',
#    'flavor',
#    'bad',
#    'fact',
#    'mild',
#    'faintly',
#    'peanutty',
#    'taste',
#    'mostly',
#    'background',
#    'note',
#    'slushy',
#    'watery',
#    'nothingness',
#    'stood',
#    'primary',
#    'flavor',
#    'tried',
#    'great',
#    'number',
#    'zero',
#    'calorie',
#    'products',
#    'lifetime',
#    'think',
#    'quite',
#    'obviously',
#    'empty',
#    'one'],
#   'neg'),
#  (['best',
#    'hot',
#    'salsa',
#    'ever',
#    'however',
#    '13',
#    'price',
#    'tag',
#    'ridiculous',
#    'definitely',
#    'worth',
#    'get',
#    'pain',
#    'good',
#    'website',
#    'half',
#    'used',
#    'get',
#    'walmart',
#    '4',
#    'removed',
#    'searching',
#    'different',
#    'reasonably',
# ...
#    'totally',
#    'liquid',
#    'left',
#    'overnight',
#    'air',
#    'conditioned',
#    '72',
#    'degrees',
#    'kitchen',
#    'bottom',
#    'shelf',
#    'coolest',
#    'see',
#    'woule',
#    'happen',
#    'still',
#    'completely',
#    'clear',
#    'liquid',
#    'solidified',
#    'even',
#    'little',
#    'bit',
#    'highly',
#    'doubt',
#    'product',
#    'says',
#    'company',
#    'seems',
#    'little',
#    'sketchy',
#    'looked',
#    'address',
#    'phone',
#    'number',
#    'website',
#    'suspect',
#    'address',
#    'even',
#    'company',
#    'shipping',
#    'location',
#    'like',
#    'p',
#    'box',
#    'something',
#    'website',
#    'simplistic',
#    'professional',
#    'looking',
#    'thinking',
#    'buying',
#    'aware',
#    'things',
#    'probably',
#    'coin',
#    'toss',
#    'whether',
#    'recieve',
#    'good',
#    'product',
#    'returning',
#    'going',
#    'back',
#    'good',
#    'ole',
#    'carrington',
#    'worth',
#    '4'],
#   'neg'),
#  (['second',
#    'time',
#    'ordered',
#    'business',
#    'like',
#    'cracker',
#    'hummus',
#    'plate',
#    'cheese',
#    'plates',
#    'issue',
#    'crackers',
#    'broken',
#    'small',
#    'pieces',
#    'presentation',
#    'wise',
#    'cant',
#    'use',
#    'dont',
#    'waste',
#    'time',
#    'gave',
#    'second',
#    'chance',
#    'thinking',
#    'wouldve',
#    'different',
#    'nope'],
#   'neg'),
#  (['bottles',
#    'match',
#    'planning',
#    'give',
#    'gift',
#    'suitable',
#    'gift',
#    'first',
#    'picture',
#    'sifferent',
#    'click',
#    'item',
#    'would',
#    'noticed',
#    'would',
#    'purchased'],
#   'neg'),
#  (['item',
#    'packaged',
#    'perfect',
#    'got',
#    'quick',
#    'great',
#    'product',
#    'use',
#    'allergic',
#    'gluten',
#    'still',
#    'want',
#    'able',
#    'eat',
#    'delicious',
#    'normal',
#    'food',
#    'made',
#    'great',
#    'biscuits'],
#   'pos'),
#  (['needed',
#    'sauce',
#    'mexican',
#    'dish',
#    'find',
#    'grocery',
#    'store',
#    'first',
#    'open',
#    'broke',
#    'bottle',
#    'second',
#    'sauce',
#    'rock',
#    'solid',
#    'thank',
#    'goodness',
#    'needed',
#    '1',
#    '4',
#    'cup',
#    'recipe',
#    'could',
#    'squeeze',
#    'threw',
#    'away',
#    'rest',
#    'dish',
#    'good',
#    'want',
#    'buy',
#    'sauce',
#    'seller'],
#   'neg'),
#  (['family',
#    'loves',
#    'stuff',
#    'found',
#    'cheaper',
#    'jolly',
#    'time',
#    'website',
#    'though',
#    'even',
#    'customise',
#    'order',
#    'happy',
#    'get',
#    'online',
#    'get',
#    'town'],
#   'pos'),
#  (['brown',
#    'dead',
#    'spots',
#    '3',
#    'roses',
#    'disappointing',
#    'money',
#    'also',
#    'came',
#    'wide',
#    'mouth',
#    'vase',
#    'keep',
#    'roses',
#    'together',
#    'nicely',
#    'would',
#    'rather',
#    'gotten',
#    'grocery',
#    'store',
#    'nicer',
#    'arrangements',
#    'cheaper',
#    'think',
#    'next',
#    'time',
#    'see',
#    'buying'],
#   'neg'),
#  (['bought',
#    'thinking',
#    'multipack',
#    '12',
#    '00',
#    'one',
#    'bag',
#    'could',
#    'bought',
#    'local',
#    'drugstore',
#    '4',
#    '99',
#    'warning',
#    'others',
#    'read',
#    'product',
#    'description',
#    'carefully',
#    'regret',
#    'rate',
#    'product',
#    '1',
#    'star',
#    'high',
#    'price',
#    'anybody',
#    'want',
#    'whine',
#    'suppose',
#    'rate',
#    'product',
#    'write',
#    'review'],
#   'neg'),
#  (['tea',
#    'one',
#    'awful',
#    'things',
#    'ever',
#    'tasted',
#    'way',
#    'tastes',
#    'like',
#    'green',
#    'tea',
#    'would',
#    'give',
#    'negative',
#    'stars',
#    'could'],
#   'neg'),
#  (['like', 'lingonberries', 'love', 'product'], 'pos'),
#  (['awful'], 'neg'),
#  (['weird',
#    'concept',
#    'powdered',
#    'peanut',
#    'butter',
#    'perfect',
#    'addition',
#    'shakes',
#    'thank'],
#   'pos'),
#  (['using',
#    'time',
#    'really',
#    'like',
#    'flavor',
#    'consistency',
#    'make',
#    'chocolate',
#    'milk',
#    'go',
#    'cutting',
#    'carb',
#    'sweet',
#    'craves',
#    'use',
#    'raw',
#    'milk',
#    'local',
#    'dairy',
#    'stevia',
#    'coconut',
#    'milk',
#    'course',
#    'cacao',
#    'taste',
#    'blend',
#    'imbibe',
#    'yum',
#    'course',
#    'raw',
#    'organic',
#    'cacao',
#    'makes',
#    'tops'],
#   'pos'),
#  (['old', 'dried', 'cups', 'completely', 'empty'], 'neg'),
#  (['sound',
#    'bacon',
#    'maple',
#    'sounded',
#    'good',
#    'thought',
#    'suckers',
#    'would',
#    'tasty',
#    'terrible',
#    'taste',
#    'like',
#    'cigarette',
#    'ashes',
#    'got',
#    '10',
#    'even',
#    'eat',
#    'one',
#    'awful'],
#   'neg'),
#  (['great', 'stomach', 'disorder', 'cant', 'eat', 'much', 'great'], 'pos'),
#  (['love',
#    'lollipops',
#    'nice',
#    'huge',
#    'bag',
#    'road',
#    'trips',
#    'definitely',
#    'ordering'],
#   'pos'),
#  (['received', 'melted'], 'neg'),
#  (['making',
#    'home',
#    'made',
#    'mead',
#    'perfect',
#    'smell',
#    'flavor',
#    'excellent',
#    'buying',
#    'stakich'],
#   'pos'),
#  (['eat',
#    'three',
#    'five',
#    'times',
#    'week',
#    'tired',
#    'going',
#    'local',
#    'supermarket',
#    'able',
#    'pick',
#    'one',
#    'two',
#    'packages',
#    'nice',
#    'getting',
#    'monthly',
#    'supply',
#    'mailed',
#    'door'],
#   'pos'),
#  (['delicious'], 'pos'),
#  (['bought',
#    'product',
#    'awhile',
#    'back',
#    'disputing',
#    'benefits',
#    'buyers',
#    'must',
#    'aware',
#    'macau',
#    'contaminated',
#    'mercury',
#    'lead',
#    'made',
#    'mistake',
#    'buying',
#    'product',
#    'verifying',
#    'mercury',
#    'lead',
#    'free',
#    'putting',
#    'shakes',
#    'daily',
#    'knew',
#    'something',
#    'right',
#    'feeling',
#    'normal',
#    'sudden',
#    'bouts',
#    'fatigue',
#    'numerous',
#    'doctors',
#    'visits',
#    'doctor',
#    'tested',
#    'metal',
#    'poisoning',
#    'found',
#    'due',
#    'maca',
#    'contaminated',
#    'mercury',
#    'year',
#    'still',
#    'dealing',
#    'side',
#    'effects',
#    'since',
#    'moment',
#    'stopped',
#    'adding',
#    'maca',
#    'shakes',
#    'levels',
#    'going',
#    'take',
#    'long',
#    'time',
#    'get',
#    'system',
#    'woman',
#    'take',
#    'maca',
#    'hormonal',
#    'balance',
#    'increase',
#    'fertility',
#    'careful',
#    'contaminated',
#    'may',
#    'able',
#    'get',
#    'pregnant',
#    'mercury',
#    'cause',
#    'infertility',
#    'even',
#    'able',
#    'conceive',
#    'want',
#    'high',
#    'mercury',
#    'levels',
#    'harmful',
#    'development',
#    'baby',
#    'decide',
#    'take',
#    'maca',
#    'please',
#    'make',
#    'sure',
#    'says',
#    'states',
#    'certified',
#    'mercury',
#    'lead',
#    'free',
#    'wish',
#    'would',
#    'know',
#    'check',
#    'purchasing',
#    'supplier',
#    'maca',
#    'contaminated',
#    'still',
#    'suffeering',
#    'due',
#    'poisoning'],
#   'neg'),
#  (['love'], 'pos'),
#  (['ok', 'arrived', 'little', 'stale', 'though'], 'pos'),
#  (['preface',
#    'review',
#    'fact',
#    'typically',
#    'tea',
#    'drinker',
#    'drink',
#    'coffee',
#    'form',
#    'flavored',
#    'drink',
#    'like',
#    'mocha',
#    'vanilla',
#    'latte',
#    'tried',
#    'cappaccino',
#    'english',
#    'toffee',
#    'hills',
#    'bros',
#    'love',
#    'coffee',
#    'flavor',
#    'however',
#    'subtle',
#    'think',
#    'like',
#    'wonderful',
#    'hint',
#    'english',
#    'toffee',
#    'fantastic',
#    'drink',
#    'prepared',
#    'mine',
#    'following',
#    'manner',
#    'instead',
#    'using',
#    'entire',
#    '8',
#    'oz',
#    'boiling',
#    'water',
#    'used',
#    '4',
#    'oz',
#    'used',
#    '4',
#    'oz',
#    'frothed',
#    'vanilla',
#    'soy',
#    'milk',
#    'gave',
#    'drink',
#    'beautiful',
#    'richness',
#    'also',
#    'nice',
#    'froth',
#    'similar',
#    'would',
#    'get',
#    'big',
#    'coffee',
#    'shop',
#    'small',
#    'fraction',
#    'cost',
#    'sweet',
#    'one',
#    'things',
#    'would',
#    'drink',
#    'time',
#    'special',
#    'treat',
#    'recommend',
#    'enough',
#    'receive',
#    'sample',
#    'influenster',
#    'free',
#    'review',
#    'purposes',
#    'however',
#    'reviews',
#    'completely',
#    'truthful',
#    'unbiased',
#    'would',
#    'never',
#    'say',
#    'liked',
#    'something',
#    'love',
#    'stuff',
#    'concern',
#    'calories',
#    '120',
#    'however',
#    'treat',
#    'bad',
#    'also',
#    'using',
#    'replace',
#    'drink',
#    'starbucks',
#    'saving',
#    'money',
#    'calories',
#    'suppose',
#    'mocha',
#    'starbucks',
#    'try',
#    'love',
#    'cozycapp'],
#   'pos'),
#  (['everyone',
#    'work',
#    'loves',
#    'included',
#    'really',
#    'beat',
#    'combination',
#    'peanutbutter',
#    'pretzel',
#    'chocolate',
#    'caramel',
#    'seriously',
#    'addictive'],
#   'pos'),
#  (['golazo',
#    'easy',
#    'drink',
#    'crash',
#    'love',
#    'natural',
#    'ingredients',
#    'strongly',
#    'carbonated',
#    'give',
#    'shakes',
#    'lot',
#    'energy',
#    'drinks',
#    'highly',
#    'recommend'],
#   'pos'),
#  (['extremely',
#    'picky',
#    '9',
#    'year',
#    'old',
#    'loves',
#    'taste',
#    'much',
#    'better',
#    'regular',
#    'granola',
#    'bars',
#    'plus',
#    'great',
#    'ingredients',
#    'non',
#    'gmo',
#    'project',
#    'approved',
#    'go',
#    'wrong',
#    'oh',
#    'great',
#    'price',
#    'local',
#    'health',
#    'food',
#    'store',
#    'sells',
#    '5',
#    '99',
#    'plus',
#    'tax',
#    'must',
#    'buy'],
#   'pos'),
#  (['orbit',
#    'gum',
#    'tasty',
#    'long',
#    'lasting',
#    'go',
#    'lot',
#    'gum',
#    'several',
#    'different',
#    'brands',
#    'one',
#    'one',
#    'better',
#    'packs'],
#   'pos'),
#  (['tastes', 'like', 'rc', 'cola', 'coca', 'cola', 'zero', 'fooled', 'fool'],
#   'neg'),
#  (['great'], 'pos'),
#  (['ended',
#    'throwing',
#    'instead',
#    'finishing',
#    'mix',
#    'well',
#    'mixed',
#    'sticky',
#    'quality',
#    'even',
#    'know',
#    'explain',
#    'taste',
#    'great',
#    'either'],
#   'neg'),
#  (['water',
#    'must',
#    'set',
#    'sun',
#    'cause',
#    'plastic',
#    'taste',
#    'ended',
#    'using',
#    'feed',
#    'houseplants',
#    'coffee',
#    'maker'],
#   'neg'),
#  (['gone'], 'pos'),
#  (['taste',
#    'unpleasant',
#    'taste',
#    'like',
#    'caramel',
#    'corn',
#    'cannot',
#    'express',
#    'reaction',
#    'anything',
#    'disgust',
#    'taste'],
#   'neg'),
#  (['excellent', 'exactly', 'expected'], 'pos'),
#  (['giving',
#    '1',
#    'star',
#    'taste',
#    'horrible',
#    'actually',
#    'thought',
#    'read',
#    'good',
#    'purchased',
#    'infuser',
#    'comes',
#    'tea',
#    'appropriate',
#    'could',
#    'tell',
#    'first',
#    'glance',
#    'going',
#    'work',
#    'regular',
#    'loose',
#    'tea',
#    'drinker',
#    'already',
#    'infuser',
#    'get',
#    'amount',
#    'grit',
#    'leaves',
#    'floating',
#    'cup',
#    'problem',
#    'tea',
#    'live',
#    'claim',
#    'could',
#    'drinking',
#    'lipton',
#    'noticeable',
#    'difference',
#    'walking',
#    '2',
#    '3',
#    'miles',
#    'per',
#    'day',
#    'drinking',
#    'water',
#    'eating',
#    'salads',
#    'expected',
#    'stomach',
#    'go',
#    'huge',
#    'stomach',
#    'expectations',
#    'unreasonable',
#    'kind',
#    'stomach',
#    'suck',
#    'say',
#    'yep',
#    'want',
#    'belly',
#    'look',
#    'like',
#    'let',
#    'breath',
#    'cry',
#    'get',
#    'point',
#    'tea',
#    'work',
#    'seriously'],
#   'neg'),
#  (['bought',
#    'since',
#    'scandinavia',
#    'get',
#    'really',
#    'strong',
#    'licorice',
#    'taste',
#    'barely',
#    'taste',
#    'even',
#    'weaker',
#    'panda',
#    'licorice'],
#   'neg'),
#  (['candy', 'expired'], 'neg'),
#  (['love',
#    'cookies',
#    'received',
#    'cookies',
#    'crushed',
#    'wouldnt',
#    'recommend',
#    'anyone',
#    'else',
#    'buying',
#    'cookies'],
#   'neg'),
#  (['happy',
#    'see',
#    'item',
#    'website',
#    'finally',
#    'received',
#    'bag',
#    'disappointed',
#    'sichuan',
#    'peppercorns',
#    'old',
#    'flavor',
#    'recommend',
#    'anyone',
#    'really',
#    'looking',
#    'real',
#    'taste'],
#   'neg'),
#  (['perfect', 'start', 'finish'], 'pos'),
#  (['organic', 'tastes', 'like', 'original', 'great', 'product'], 'pos'),
#  (['arrived',
#    'melted',
#    'live',
#    'south',
#    'community',
#    'mail',
#    'room',
#    'air',
#    'conditioned',
#    'damaged',
#    'transit',
#    'sad'],
#   'neg'),
#  (['received',
#    'product',
#    'october',
#    '20th',
#    '2010',
#    'far',
#    '20',
#    'days',
#    'tried',
#    'product',
#    'found',
#    'easy',
#    'way',
#    'take',
#    'product',
#    'take',
#    'half',
#    'spoon',
#    'powder',
#    'mouth',
#    'chew',
#    'put',
#    'fruit',
#    'drink',
#    'felt',
#    'energy',
#    'taking',
#    'product',
#    'nothing',
#    'concret',
#    'yet'],
#   'pos'),
#  (['save',
#    'money',
#    'sorry',
#    'best',
#    'trappists',
#    'need',
#    'go',
#    'back',
#    'fruitcake',
#    'school',
#    'forget',
#    'ingredients',
#    'taste',
#    'thing',
#    'taste',
#    'like',
#    'chewing',
#    'damp',
#    'cardboard',
#    'stuff',
#    'inside',
#    'wife',
#    'son',
#    'give',
#    'mess',
#    'grade',
#    'high'],
#   'neg'),
#  (['best', 'hot', 'mustard', 'anywhere'], 'pos'),
#  (['hands',
#    'worst',
#    'coffee',
#    'ever',
#    'purchased',
#    'tried',
#    'lot',
#    'known',
#    'organic',
#    'flavor',
#    'would',
#    'steered',
#    'clear',
#    'bad',
#    'ground',
#    'probably',
#    '3',
#    '5lbs',
#    'gave',
#    'college',
#    'student',
#    'attempt',
#    'save',
#    'money',
#    'consume',
#    'anything',
#    'cheap',
#    'think',
#    'even',
#    'regretting',
#    'soul',
#    'coffee',
#    'produces',
#    'brown',
#    'liquid',
#    'looks',
#    'like',
#    'coffee',
#    'might',
#    'well',
#    'chopped',
#    'roots',
#    'brown',
#    'water',
#    'tried',
#    'making',
#    'stronger',
#    'give',
#    'flavor',
#    'went',
#    'bitter',
#    'side',
#    'bad',
#    'flavor',
#    'save'],
#   'neg'),
#  (['good', 'decaf', 'would', 'buy'], 'pos'),
#  (['awesome',
#    'tastes',
#    'sweet',
#    'smells',
#    'great',
#    'trying',
#    '8th',
#    'cup',
#    'coffee',
#    'fits',
#    'perfectly'],
#   'pos'),
#  (['time',
#    'oil',
#    'oozed',
#    'got',
#    'everything',
#    'kept',
#    'one',
#    'pack',
#    'center',
#    'console',
#    'jeep',
#    'leaked',
#    'kept',
#    'another',
#    'pack',
#    'front',
#    'pocket',
#    'lunch',
#    'cooler',
#    'leaked',
#    'oil',
#    'gum',
#    'ok',
#    'fresh',
#    'guess',
#    'chew',
#    'right',
#    'away',
#    'breaks',
#    'pack',
#    'never',
#    'issue',
#    'wrigley',
#    '5',
#    'gum'],
#   'neg'),
#  (['like', 'photo', 'mistake', 'buying', 'plant', 'online'], 'neg'),
#  (['great',
#    'deal',
#    'tastes',
#    'amazing',
#    'great',
#    'coffee',
#    'italian',
#    'sodas',
#    'tea',
#    'whatever',
#    'would',
#    'like',
#    'nice',
#    'vanilla',
#    'flavor',
#    'without',
#    'sweet'],
#   'pos'),
#  (['chips', 'best', 'everybody', 'tasted', 'loved'], 'pos'),
#  (['tried',
#    'recommendation',
#    'could',
#    'tell',
#    'anything',
#    'perhaps',
#    'hyped',
#    'felt',
#    'different',
#    'aftger',
#    '2',
#    'months',
#    'trying'],
#   'neg'),
#  (['love',
#    'speculoos',
#    'instead',
#    'cookies',
#    'jars',
#    'cookie',
#    'spread',
#    'sent'],
#   'neg'),
#  (['purely', 'disgusting'], 'neg'),
#  (['great'], 'pos'),
#  (['could',
#    'use',
#    'product',
#    'due',
#    'fact',
#    'bag',
#    'everywhere',
#    'thru',
#    'box'],
#   'neg'),
#  (['sooo', 'good'], 'pos'),
#  (['great', 'kentucky', 'mules'], 'pos'),
#  (['mini',
#    'cheese',
#    'rounds',
#    'take',
#    'place',
#    'regular',
#    'crackers',
#    'fits',
#    'right',
#    'wheat',
#    'free',
#    'life',
#    'style',
#    'tastes',
#    'great',
#    'time'],
#   'pos'),
#  (['graham',
#    'crackers',
#    'remember',
#    'changed',
#    'recipe',
#    'incorporate',
#    'whole',
#    'grains',
#    'quality',
#    'poor',
#    'even',
#    'break',
#    'crackers',
#    'half',
#    'anymore',
#    'without',
#    'crumbling',
#    'fingers',
#    'first',
#    'thought',
#    'got',
#    'bad',
#    'box',
#    'okay',
#    'second',
#    'bad',
#    'box',
#    'third',
#    'research',
#    'online',
#    'definitely',
#    'first',
#    'one',
#    'notice',
#    'poor',
#    'quality',
#    'recipe',
#    'changes',
#    'anybody',
#    'got',
#    'good',
#    'alternative',
#    'graham',
#    'cracker'],
#   'neg'),
#  (['servicew',
#    'great',
#    'price',
#    'charged',
#    'line',
#    'close',
#    '40',
#    '00',
#    'dollars',
#    'box',
#    'gum',
#    'sy',
#    'marenberg'],
#   'neg'),
#  (['product',
#    'china',
#    'means',
#    'thanks',
#    'buy',
#    'quaker',
#    'oats',
#    'come',
#    'never',
#    'buy',
#    'dole'],
#   'neg'),
#  (['love', 'buy'], 'pos'),
#  (['best',
#    'enjoying',
#    'unusual',
#    'combination',
#    'hot',
#    'sweet',
#    'lollipop',
#    'fun',
#    'knocking',
#    'peoples',
#    'socks',
#    'tell',
#    'hot',
#    'hot',
#    'love',
#    'fun',
#    'snack'],
#   'pos'),
#  (['described'], 'pos'),
#  ...]

# %%
len(labeled_reviews)
# Out:
# 809640
